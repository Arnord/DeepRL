# %%
import sys
sys.path.append('..')

# %%
import pandas as pd
import random
import numpy as np
from continuous_BCQ.utils import ReplayBuffer

# %%
df = pd.read_csv("df_thickener1_20220522_change.csv")

# %%
df
# Out:
#                  time     feed_c      out_c      feed_f       out_f  \
# 0     2021/6/24 22:45   7.062875  65.524767    0.570965  120.045326
# 1     2021/6/24 22:50   9.820479  65.541320  153.008470  120.580674
# 2     2021/6/24 22:55   8.771818  64.324850  594.833913  128.955535
# 3     2021/6/24 23:00   5.454403  64.658912    0.569209  115.166352
# 4     2021/6/24 23:05   4.459571  64.014458    0.575706  117.597771
# ...               ...        ...        ...         ...         ...
# 9950    2022/5/7 9:50  33.020739  59.366599  601.963274  146.562356
# 9951    2022/5/7 9:55  29.091299  60.463238  679.524404  136.653616
# 9952   2022/5/7 10:00  26.692466  59.308527  601.825201  157.848585
# 9953   2022/5/7 10:05  28.122638  59.329402  612.676073  148.789828
# 9954   2022/5/7 10:10  28.742416  60.005657  700.122260  138.264618
#
#        pressure  out_f_setting  out_c_setting    reward     error  sum_error  \
# 0     56.274189     120.000000           65.5 -0.000613 -0.024767  -0.024767
# 1     56.245093     120.000000           65.5 -0.001707 -0.041320  -0.058657
# 2     55.393874     120.000000           65.5 -1.380978  1.175150   1.134090
# 3     55.373869     120.000000           65.5 -0.707429  0.841088   1.634952
# 4     53.587357     120.000000           65.5 -2.206836  1.485542   2.630008
# ...         ...            ...            ...       ...       ...        ...
# 9950  51.578216     140.399994           62.0 -6.934803  2.633401   7.138373
# 9951  50.474077     140.399994           62.0 -2.361637  1.536762   6.533623
# 9952  51.421173     140.399994           62.0 -7.244026  2.691473   7.265009
# 9953  51.545893     140.399994           62.0 -7.132092  2.670598   7.756104
# 9954  51.887671     140.399994           62.0 -3.977403  1.994343   7.423616
#
#       done
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9950     0
# 9951     0
# 9952     0
# 9953     0
# 9954     0
#
# [9955 rows x 12 columns]

# %%
order = ["feed_c", "out_c", "feed_f", "out_f", "pressure", "error", "sum_error", "out_c_setting", "reward", "out_f_setting", "done"]
df = df[order]

# %%
df
# Out:
#          feed_c      out_c      feed_f       out_f   pressure     error  \
# 0      7.062875  65.524767    0.570965  120.045326  56.274189 -0.024767
# 1      9.820479  65.541320  153.008470  120.580674  56.245093 -0.041320
# 2      8.771818  64.324850  594.833913  128.955535  55.393874  1.175150
# 3      5.454403  64.658912    0.569209  115.166352  55.373869  0.841088
# 4      4.459571  64.014458    0.575706  117.597771  53.587357  1.485542
# ...         ...        ...         ...         ...        ...       ...
# 9950  33.020739  59.366599  601.963274  146.562356  51.578216  2.633401
# 9951  29.091299  60.463238  679.524404  136.653616  50.474077  1.536762
# 9952  26.692466  59.308527  601.825201  157.848585  51.421173  2.691473
# 9953  28.122638  59.329402  612.676073  148.789828  51.545893  2.670598
# 9954  28.742416  60.005657  700.122260  138.264618  51.887671  1.994343
#
#       sum_error  out_c_setting    reward  out_f_setting  done
# 0     -0.024767           65.5 -0.000613     120.000000     0
# 1     -0.058657           65.5 -0.001707     120.000000     0
# 2      1.134090           65.5 -1.380978     120.000000     0
# 3      1.634952           65.5 -0.707429     120.000000     0
# 4      2.630008           65.5 -2.206836     120.000000     0
# ...         ...            ...       ...            ...   ...
# 9950   7.138373           62.0 -6.934803     140.399994     0
# 9951   6.533623           62.0 -2.361637     140.399994     0
# 9952   7.265009           62.0 -7.244026     140.399994     0
# 9953   7.756104           62.0 -7.132092     140.399994     0
# 9954   7.423616           62.0 -3.977403     140.399994     0
#
# [9955 rows x 11 columns]

# %%
#"name": ["feed_c", "out_c", "feed_f", "out_f", "out_f_setting", "pressure", "reward"]

# %%
df_1 = df

# %%
df_1
# Out:
#          feed_c      out_c      feed_f       out_f   pressure     error  \
# 0      7.062875  65.524767    0.570965  120.045326  56.274189 -0.024767
# 1      9.820479  65.541320  153.008470  120.580674  56.245093 -0.041320
# 2      8.771818  64.324850  594.833913  128.955535  55.393874  1.175150
# 3      5.454403  64.658912    0.569209  115.166352  55.373869  0.841088
# 4      4.459571  64.014458    0.575706  117.597771  53.587357  1.485542
# ...         ...        ...         ...         ...        ...       ...
# 9950  33.020739  59.366599  601.963274  146.562356  51.578216  2.633401
# 9951  29.091299  60.463238  679.524404  136.653616  50.474077  1.536762
# 9952  26.692466  59.308527  601.825201  157.848585  51.421173  2.691473
# 9953  28.122638  59.329402  612.676073  148.789828  51.545893  2.670598
# 9954  28.742416  60.005657  700.122260  138.264618  51.887671  1.994343
#
#       sum_error  out_c_setting    reward  out_f_setting  done
# 0     -0.024767           65.5 -0.000613     120.000000     0
# 1     -0.058657           65.5 -0.001707     120.000000     0
# 2      1.134090           65.5 -1.380978     120.000000     0
# 3      1.634952           65.5 -0.707429     120.000000     0
# 4      2.630008           65.5 -2.206836     120.000000     0
# ...         ...            ...       ...            ...   ...
# 9950   7.138373           62.0 -6.934803     140.399994     0
# 9951   6.533623           62.0 -2.361637     140.399994     0
# 9952   7.265009           62.0 -7.244026     140.399994     0
# 9953   7.756104           62.0 -7.132092     140.399994     0
# 9954   7.423616           62.0 -3.977403     140.399994     0
#
# [9955 rows x 11 columns]

# %% [markdown]
# ## 标准化

# %%
df_zscore = df_1.copy()
done_o = df_zscore["done"]
df_zscores = (df_zscore - df_zscore.mean()) / df_zscore.std()
df_zscores['done'] = done_o
df_zscores
# Out:
#         feed_c     out_c    feed_f     out_f  pressure     error  sum_error  \
# 0    -2.663300  1.886335 -2.346427 -0.975395  1.051124 -1.014885  -1.034217
# 1    -2.294279  1.893862 -1.666733 -0.951392  1.047244 -1.022135  -1.039032
# 2    -2.434610  1.340644  0.303294 -0.575907  0.933738 -0.489393  -0.869559
# 3    -2.878544  1.492566 -2.346435 -1.194142  0.931071 -0.635692  -0.798393
# 4    -3.011672  1.199486 -2.346406 -1.085130  0.692849 -0.353460  -0.657009
# ...        ...       ...       ...       ...       ...       ...        ...
# 9950  0.810364 -0.914238  0.335082  0.213491  0.424941  0.149234  -0.016431
# 9951  0.284529 -0.415516  0.680915 -0.230765  0.277711 -0.331029  -0.102358
# 9952 -0.036481 -0.940648  0.334467  0.719507  0.404001  0.174666   0.001562
# 9953  0.154903 -0.931154  0.382849  0.313359  0.420631  0.165524   0.071340
# 9954  0.237842 -0.623611  0.772757 -0.158536  0.466206 -0.130635   0.024098
#
#       out_c_setting    reward  out_f_setting  done
# 0          1.084978  0.849627      -1.038786     0
# 1          1.084978  0.849538      -1.038786     0
# 2          1.084978  0.737602      -1.038786     0
# 3          1.084978  0.792264      -1.038786     0
# 4          1.084978  0.670578      -1.038786     0
# ...             ...       ...            ...   ...
# 9950      -0.989608  0.286874      -0.038719     0
# 9951      -0.989608  0.658015      -0.038719     0
# 9952      -0.989608  0.261779      -0.038719     0
# 9953      -0.989608  0.270863      -0.038719     0
# 9954      -0.989608  0.526886      -0.038719     0
#
# [9955 rows x 11 columns]

# %%
df_zscore_mean = pd.DataFrame(df_zscore.mean()).stack().unstack(0)
df_zscore_mean.to_csv("df_thickener_zscore_mean.csv", index=False)

df_zscore_std = pd.DataFrame(df_zscore.std()).stack().unstack(0)
df_zscore_std.to_csv("df_thickener_zscore_std.csv", index=False)

# %% [markdown]
# ## 数据集两两绑定（state和next_state）

# %%
df_zscores_single = [x for x in range(0, len(df_zscores), 2)]
len(df_zscores_single)
# Out:
# 4978

# %% [markdown]
# ## 划分验证集和训练集（差集）-------两两绑定

# %%
df_zscores_single_eval = random.sample(df_zscores_single, 1000)

# %%
len(df_zscores_single_eval)
# Out:
# 1000

# %%
df_zscores_single_train = list(set(df_zscores_single) - set(df_zscores_single_eval))

# %%
len(df_zscores_single_train)
# Out:
# 3978

# %%
data = df_zscores.values

# %%
print(data[0])
data[0][0:3]
# Out:
# [-2.66329984  1.88633454 -2.34642718 -0.97539465  1.0511237  -1.0148855
#  -1.03421695  1.08497778  0.84962664 -1.03878587  0.        ]
# array([-2.66329984,  1.88633454, -2.34642718])

# %%
state_dim = 8
action_dim = 1

# %%
replay_buffer_train = ReplayBuffer(state_dim, action_dim, device="cpu")
replay_buffer_eval = ReplayBuffer(state_dim, action_dim ,device="cpu")

# %%
for t in range(0, len(data)-1 , 2):   
    print(t)
    if t in df_zscores_single_train:
        state = data[t][0:-3]
        action = data[t][-2]
        next_state = data[t+1][0:-3]
        reward = data[t+1][-3]
        done = data[t+1][-1]
        replay_buffer_train.add(state, action, next_state, reward, done)
        print("replay_buffer_train_add", t)
    elif t in df_zscores_single_eval:
        state = data[t][0:-3]
        action = data[t][-2]
        next_state = data[t+1][0:-3]
        reward = data[t+1][-3]
        done = data[t+1][-1]
        replay_buffer_eval.add(state, action, next_state, reward, done)
        print("replay_buffer_eval_add", t)
    else:
        pass
# Out:
# 0
# replay_buffer_train_add 0
# 2
# replay_buffer_train_add 2
# 4
# replay_buffer_train_add 4
# 6
# replay_buffer_train_add 6
# 8
# replay_buffer_train_add 8
# 10
# replay_buffer_train_add 10
# 12
# replay_buffer_train_add 12
# 14
# replay_buffer_train_add 14
# 16
# replay_buffer_train_add 16
# 18
# replay_buffer_train_add 18
# 20
# replay_buffer_train_add 20
# 22
# replay_buffer_train_add 22
# 24
# replay_buffer_eval_add 24
# 26
# replay_buffer_train_add 26
# 28
# replay_buffer_eval_add 28
# 30
# replay_buffer_eval_add 30
# 32
# replay_buffer_train_add 32
# 34
# replay_buffer_train_add 34
# 36
# replay_buffer_train_add 36
# 38
# replay_buffer_train_add 38
# 40
# replay_buffer_train_add 40
# 42
# replay_buffer_eval_add 42
# 44
# replay_buffer_train_add 44
# 46
# replay_buffer_eval_add 46
# 48
# replay_buffer_train_add 48
# 50
# replay_buffer_train_add 50
# 52
# replay_buffer_train_add 52
# 54
# replay_buffer_train_add 54
# 56
# replay_buffer_eval_add 56
# 58
# replay_buffer_eval_add 58
# 60
# replay_buffer_train_add 60
# 62
# replay_buffer_train_add 62
# 64
# replay_buffer_eval_add 64
# 66
# replay_buffer_train_add 66
# 68
# replay_buffer_eval_add 68
# 70
# replay_buffer_train_add 70
# 72
# replay_buffer_train_add 72
# 74
# replay_buffer_eval_add 74
# 76
# replay_buffer_train_add 76
# 78
# replay_buffer_train_add 78
# 80
# replay_buffer_train_add 80
# 82
# replay_buffer_train_add 82
# 84
# replay_buffer_train_add 84
# 86
# replay_buffer_train_add 86
# 88
# replay_buffer_train_add 88
# 90
# replay_buffer_eval_add 90
# 92
# replay_buffer_train_add 92
# 94
# replay_buffer_train_add 94
# 96
# replay_buffer_train_add 96
# 98
# replay_buffer_train_add 98
# 100
# replay_buffer_eval_add 100
# 102
# replay_buffer_train_add 102
# 104
# replay_buffer_eval_add 104
# 106
# replay_buffer_train_add 106
# 108
# replay_buffer_train_add 108
# 110
# replay_buffer_train_add 110
# 112
# replay_buffer_train_add 112
# 114
# replay_buffer_eval_add 114
# 116
# replay_buffer_train_add 116
# 118
# replay_buffer_train_add 118
# 120
# replay_buffer_eval_add 120
# 122
# replay_buffer_train_add 122
# 124
# replay_buffer_train_add 124
# 126
# replay_buffer_train_add 126
# 128
# replay_buffer_eval_add 128
# 130
# replay_buffer_eval_add 130
# 132
# replay_buffer_train_add 132
# 134
# replay_buffer_train_add 134
# 136
# replay_buffer_train_add 136
# 138
# replay_buffer_train_add 138
# 140
# replay_buffer_train_add 140
# 142
# replay_buffer_train_add 142
# 144
# replay_buffer_train_add 144
# 146
# replay_buffer_train_add 146
# 148
# replay_buffer_eval_add 148
# 150
# replay_buffer_train_add 150
# 152
# replay_buffer_train_add 152
# 154
# replay_buffer_train_add 154
# 156
# replay_buffer_eval_add 156
# 158
# replay_buffer_train_add 158
# 160
# replay_buffer_eval_add 160
# 162
# replay_buffer_train_add 162
# 164
# replay_buffer_train_add 164
# 166
# replay_buffer_train_add 166
# 168
# replay_buffer_train_add 168
# 170
# replay_buffer_eval_add 170
# 172
# replay_buffer_eval_add 172
# 174
# replay_buffer_train_add 174
# 176
# replay_buffer_train_add 176
# 178
# replay_buffer_train_add 178
# 180
# replay_buffer_train_add 180
# 182
# replay_buffer_train_add 182
# 184
# replay_buffer_train_add 184
# 186
# replay_buffer_train_add 186
# 188
# replay_buffer_train_add 188
# 190
# replay_buffer_train_add 190
# 192
# replay_buffer_eval_add 192
# 194
# replay_buffer_train_add 194
# 196
# replay_buffer_train_add 196
# 198
# replay_buffer_train_add 198
# 200
# replay_buffer_train_add 200
# 202
# replay_buffer_train_add 202
# 204
# replay_buffer_train_add 204
# 206
# replay_buffer_train_add 206
# 208
# replay_buffer_train_add 208
# 210
# replay_buffer_train_add 210
# 212
# replay_buffer_train_add 212
# 214
# replay_buffer_train_add 214
# 216
# replay_buffer_train_add 216
# 218
# replay_buffer_train_add 218
# 220
# replay_buffer_train_add 220
# 222
# replay_buffer_train_add 222
# 224
# replay_buffer_train_add 224
# 226
# replay_buffer_train_add 226
# 228
# replay_buffer_train_add 228
# 230
# replay_buffer_train_add 230
# 232
# replay_buffer_eval_add 232
# 234
# replay_buffer_train_add 234
# 236
# replay_buffer_train_add 236
# 238
# replay_buffer_train_add 238
# 240
# replay_buffer_train_add 240
# 242
# replay_buffer_train_add 242
# 244
# replay_buffer_train_add 244
# 246
# replay_buffer_eval_add 246
# 248
# replay_buffer_train_add 248
# 250
# replay_buffer_train_add 250
# 252
# replay_buffer_train_add 252
# 254
# replay_buffer_train_add 254
# 256
# replay_buffer_train_add 256
# 258
# replay_buffer_eval_add 258
# 260
# replay_buffer_eval_add 260
# 262
# replay_buffer_train_add 262
# 264
# replay_buffer_eval_add 264
# 266
# replay_buffer_train_add 266
# 268
# replay_buffer_eval_add 268
# 270
# replay_buffer_train_add 270
# 272
# replay_buffer_train_add 272
# 274
# replay_buffer_train_add 274
# 276
# replay_buffer_train_add 276
# 278
# replay_buffer_train_add 278
# 280
# replay_buffer_train_add 280
# 282
# replay_buffer_eval_add 282
# 284
# replay_buffer_train_add 284
# 286
# replay_buffer_train_add 286
# 288
# replay_buffer_train_add 288
# 290
# replay_buffer_train_add 290
# 292
# replay_buffer_train_add 292
# 294
# replay_buffer_train_add 294
# 296
# replay_buffer_train_add 296
# 298
# replay_buffer_train_add 298
# 300
# replay_buffer_eval_add 300
# 302
# replay_buffer_train_add 302
# 304
# replay_buffer_train_add 304
# 306
# replay_buffer_eval_add 306
# 308
# replay_buffer_train_add 308
# 310
# replay_buffer_train_add 310
# 312
# replay_buffer_train_add 312
# 314
# replay_buffer_train_add 314
# 316
# replay_buffer_train_add 316
# 318
# replay_buffer_train_add 318
# 320
# replay_buffer_eval_add 320
# 322
# replay_buffer_train_add 322
# 324
# replay_buffer_train_add 324
# 326
# replay_buffer_train_add 326
# 328
# replay_buffer_eval_add 328
# 330
# replay_buffer_train_add 330
# 332
# replay_buffer_train_add 332
# 334
# replay_buffer_eval_add 334
# 336
# replay_buffer_train_add 336
# 338
# replay_buffer_train_add 338
# 340
# replay_buffer_eval_add 340
# 342
# replay_buffer_train_add 342
# 344
# replay_buffer_train_add 344
# 346
# replay_buffer_train_add 346
# 348
# replay_buffer_eval_add 348
# 350
# replay_buffer_eval_add 350
# 352
# replay_buffer_train_add 352
# 354
# replay_buffer_train_add 354
# 356
# replay_buffer_train_add 356
# 358
# replay_buffer_train_add 358
# 360
# replay_buffer_train_add 360
# 362
# replay_buffer_train_add 362
# 364
# replay_buffer_train_add 364
# 366
# replay_buffer_train_add 366
# 368
# replay_buffer_train_add 368
# 370
# replay_buffer_train_add 370
# 372
# replay_buffer_train_add 372
# 374
# replay_buffer_eval_add 374
# 376
# replay_buffer_eval_add 376
# 378
# replay_buffer_eval_add 378
# 380
# replay_buffer_train_add 380
# 382
# replay_buffer_train_add 382
# 384
# replay_buffer_train_add 384
# 386
# replay_buffer_train_add 386
# 388
# replay_buffer_train_add 388
# 390
# replay_buffer_train_add 390
# 392
# replay_buffer_train_add 392
# 394
# replay_buffer_train_add 394
# 396
# replay_buffer_eval_add 396
# 398
# replay_buffer_eval_add 398
# 400
# replay_buffer_train_add 400
# 402
# replay_buffer_eval_add 402
# 404
# replay_buffer_train_add 404
# 406
# replay_buffer_train_add 406
# 408
# replay_buffer_train_add 408
# 410
# replay_buffer_train_add 410
# 412
# replay_buffer_train_add 412
# 414
# replay_buffer_train_add 414
# 416
# replay_buffer_train_add 416
# 418
# replay_buffer_eval_add 418
# 420
# replay_buffer_train_add 420
# 422
# replay_buffer_train_add 422
# 424
# replay_buffer_train_add 424
# 426
# replay_buffer_eval_add 426
# 428
# replay_buffer_train_add 428
# 430
# replay_buffer_train_add 430
# 432
# replay_buffer_train_add 432
# 434
# replay_buffer_train_add 434
# 436
# replay_buffer_train_add 436
# 438
# replay_buffer_eval_add 438
# 440
# replay_buffer_train_add 440
# 442
# replay_buffer_eval_add 442
# 444
# replay_buffer_train_add 444
# 446
# replay_buffer_train_add 446
# 448
# replay_buffer_train_add 448
# 450
# replay_buffer_train_add 450
# 452
# replay_buffer_train_add 452
# 454
# replay_buffer_train_add 454
# 456
# replay_buffer_eval_add 456
# 458
# replay_buffer_train_add 458
# 460
# replay_buffer_train_add 460
# 462
# replay_buffer_train_add 462
# 464
# replay_buffer_eval_add 464
# 466
# replay_buffer_train_add 466
# 468
# replay_buffer_train_add 468
# 470
# replay_buffer_eval_add 470
# 472
# replay_buffer_train_add 472
# 474
# replay_buffer_train_add 474
# 476
# replay_buffer_train_add 476
# 478
# replay_buffer_train_add 478
# 480
# replay_buffer_eval_add 480
# 482
# replay_buffer_train_add 482
# 484
# replay_buffer_train_add 484
# 486
# replay_buffer_train_add 486
# 488
# replay_buffer_train_add 488
# 490
# replay_buffer_train_add 490
# 492
# replay_buffer_train_add 492
# 494
# replay_buffer_train_add 494
# 496
# replay_buffer_train_add 496
# 498
# replay_buffer_train_add 498
# 500
# replay_buffer_train_add 500
# 502
# replay_buffer_train_add 502
# 504
# replay_buffer_eval_add 504
# 506
# replay_buffer_train_add 506
# 508
# replay_buffer_eval_add 508
# 510
# replay_buffer_train_add 510
# 512
# replay_buffer_train_add 512
# 514
# replay_buffer_eval_add 514
# 516
# replay_buffer_eval_add 516
# 518
# replay_buffer_train_add 518
# 520
# replay_buffer_train_add 520
# 522
# replay_buffer_train_add 522
# 524
# replay_buffer_train_add 524
# 526
# replay_buffer_train_add 526
# 528
# replay_buffer_train_add 528
# 530
# replay_buffer_eval_add 530
# 532
# replay_buffer_train_add 532
# 534
# replay_buffer_eval_add 534
# 536
# replay_buffer_train_add 536
# 538
# replay_buffer_train_add 538
# 540
# replay_buffer_train_add 540
# 542
# replay_buffer_train_add 542
# 544
# replay_buffer_train_add 544
# 546
# replay_buffer_train_add 546
# 548
# replay_buffer_train_add 548
# 550
# replay_buffer_train_add 550
# 552
# replay_buffer_eval_add 552
# 554
# replay_buffer_train_add 554
# 556
# replay_buffer_train_add 556
# 558
# replay_buffer_train_add 558
# 560
# replay_buffer_train_add 560
# 562
# replay_buffer_train_add 562
# 564
# replay_buffer_train_add 564
# 566
# replay_buffer_train_add 566
# 568
# replay_buffer_train_add 568
# 570
# replay_buffer_train_add 570
# 572
# replay_buffer_eval_add 572
# 574
# replay_buffer_train_add 574
# 576
# replay_buffer_train_add 576
# 578
# replay_buffer_eval_add 578
# 580
# replay_buffer_train_add 580
# 582
# replay_buffer_train_add 582
# 584
# replay_buffer_train_add 584
# 586
# replay_buffer_train_add 586
# 588
# replay_buffer_train_add 588
# 590
# replay_buffer_train_add 590
# 592
# replay_buffer_eval_add 592
# 594
# replay_buffer_train_add 594
# 596
# replay_buffer_train_add 596
# 598
# replay_buffer_train_add 598
# 600
# replay_buffer_train_add 600
# 602
# replay_buffer_eval_add 602
# 604
# replay_buffer_eval_add 604
# 606
# replay_buffer_eval_add 606
# 608
# replay_buffer_train_add 608
# 610
# replay_buffer_train_add 610
# 612
# replay_buffer_train_add 612
# 614
# replay_buffer_train_add 614
# 616
# replay_buffer_train_add 616
# 618
# replay_buffer_train_add 618
# 620
# replay_buffer_train_add 620
# 622
# replay_buffer_train_add 622
# 624
# replay_buffer_train_add 624
# 626
# replay_buffer_train_add 626
# 628
# replay_buffer_train_add 628
# 630
# replay_buffer_eval_add 630
# 632
# replay_buffer_train_add 632
# 634
# replay_buffer_train_add 634
# 636
# replay_buffer_eval_add 636
# 638
# replay_buffer_train_add 638
# 640
# replay_buffer_train_add 640
# 642
# replay_buffer_train_add 642
# 644
# replay_buffer_train_add 644
# 646
# replay_buffer_train_add 646
# 648
# replay_buffer_eval_add 648
# 650
# replay_buffer_eval_add 650
# 652
# replay_buffer_train_add 652
# 654
# replay_buffer_train_add 654
# 656
# replay_buffer_train_add 656
# 658
# replay_buffer_train_add 658
# 660
# replay_buffer_train_add 660
# 662
# replay_buffer_train_add 662
# 664
# replay_buffer_train_add 664
# 666
# replay_buffer_train_add 666
# 668
# replay_buffer_eval_add 668
# 670
# replay_buffer_train_add 670
# 672
# replay_buffer_train_add 672
# 674
# replay_buffer_train_add 674
# 676
# replay_buffer_train_add 676
# 678
# replay_buffer_eval_add 678
# 680
# replay_buffer_eval_add 680
# 682
# replay_buffer_train_add 682
# 684
# replay_buffer_train_add 684
# 686
# replay_buffer_train_add 686
# 688
# replay_buffer_train_add 688
# 690
# replay_buffer_train_add 690
# 692
# replay_buffer_train_add 692
# 694
# replay_buffer_eval_add 694
# 696
# replay_buffer_eval_add 696
# 698
# replay_buffer_train_add 698
# 700
# replay_buffer_train_add 700
# 702
# replay_buffer_train_add 702
# 704
# replay_buffer_eval_add 704
# 706
# replay_buffer_train_add 706
# 708
# replay_buffer_train_add 708
# 710
# replay_buffer_train_add 710
# 712
# replay_buffer_train_add 712
# 714
# replay_buffer_train_add 714
# 716
# replay_buffer_eval_add 716
# 718
# replay_buffer_train_add 718
# 720
# replay_buffer_train_add 720
# 722
# replay_buffer_train_add 722
# 724
# replay_buffer_eval_add 724
# 726
# replay_buffer_train_add 726
# 728
# replay_buffer_train_add 728
# 730
# replay_buffer_eval_add 730
# 732
# replay_buffer_train_add 732
# 734
# replay_buffer_train_add 734
# 736
# replay_buffer_train_add 736
# 738
# replay_buffer_train_add 738
# 740
# replay_buffer_train_add 740
# 742
# replay_buffer_train_add 742
# 744
# replay_buffer_train_add 744
# 746
# replay_buffer_train_add 746
# 748
# replay_buffer_train_add 748
# 750
# replay_buffer_train_add 750
# 752
# replay_buffer_train_add 752
# 754
# replay_buffer_train_add 754
# 756
# replay_buffer_train_add 756
# 758
# replay_buffer_eval_add 758
# 760
# replay_buffer_train_add 760
# 762
# replay_buffer_train_add 762
# 764
# replay_buffer_train_add 764
# 766
# replay_buffer_train_add 766
# 768
# replay_buffer_train_add 768
# 770
# replay_buffer_train_add 770
# 772
# replay_buffer_eval_add 772
# 774
# replay_buffer_train_add 774
# 776
# replay_buffer_train_add 776
# 778
# replay_buffer_eval_add 778
# 780
# replay_buffer_eval_add 780
# 782
# replay_buffer_train_add 782
# 784
# replay_buffer_train_add 784
# 786
# replay_buffer_train_add 786
# 788
# replay_buffer_train_add 788
# 790
# replay_buffer_train_add 790
# 792
# replay_buffer_train_add 792
# 794
# replay_buffer_train_add 794
# 796
# replay_buffer_train_add 796
# 798
# replay_buffer_train_add 798
# 800
# replay_buffer_train_add 800
# 802
# replay_buffer_train_add 802
# 804
# replay_buffer_train_add 804
# 806
# replay_buffer_train_add 806
# 808
# replay_buffer_train_add 808
# 810
# replay_buffer_train_add 810
# 812
# replay_buffer_eval_add 812
# 814
# replay_buffer_train_add 814
# 816
# replay_buffer_train_add 816
# 818
# replay_buffer_train_add 818
# 820
# replay_buffer_train_add 820
# 822
# replay_buffer_train_add 822
# 824
# replay_buffer_train_add 824
# 826
# replay_buffer_train_add 826
# 828
# replay_buffer_train_add 828
# 830
# replay_buffer_eval_add 830
# 832
# replay_buffer_train_add 832
# 834
# replay_buffer_train_add 834
# 836
# replay_buffer_train_add 836
# 838
# replay_buffer_train_add 838
# 840
# replay_buffer_train_add 840
# 842
# replay_buffer_eval_add 842
# 844
# replay_buffer_train_add 844
# 846
# replay_buffer_train_add 846
# 848
# replay_buffer_eval_add 848
# 850
# replay_buffer_train_add 850
# 852
# replay_buffer_train_add 852
# 854
# replay_buffer_train_add 854
# 856
# replay_buffer_train_add 856
# 858
# replay_buffer_train_add 858
# 860
# replay_buffer_train_add 860
# 862
# replay_buffer_eval_add 862
# 864
# replay_buffer_eval_add 864
# 866
# replay_buffer_train_add 866
# 868
# replay_buffer_train_add 868
# 870
# replay_buffer_train_add 870
# 872
# replay_buffer_train_add 872
# 874
# replay_buffer_eval_add 874
# 876
# replay_buffer_eval_add 876
# 878
# replay_buffer_train_add 878
# 880
# replay_buffer_train_add 880
# 882
# replay_buffer_train_add 882
# 884
# replay_buffer_train_add 884
# 886
# replay_buffer_train_add 886
# 888
# replay_buffer_eval_add 888
# 890
# replay_buffer_eval_add 890
# 892
# replay_buffer_train_add 892
# 894
# replay_buffer_train_add 894
# 896
# replay_buffer_train_add 896
# 898
# replay_buffer_eval_add 898
# 900
# replay_buffer_train_add 900
# 902
# replay_buffer_train_add 902
# 904
# replay_buffer_train_add 904
# 906
# replay_buffer_eval_add 906
# 908
# replay_buffer_eval_add 908
# 910
# replay_buffer_eval_add 910
# 912
# replay_buffer_eval_add 912
# 914
# replay_buffer_train_add 914
# 916
# replay_buffer_train_add 916
# 918
# replay_buffer_train_add 918
# 920
# replay_buffer_train_add 920
# 922
# replay_buffer_train_add 922
# 924
# replay_buffer_train_add 924
# 926
# replay_buffer_eval_add 926
# 928
# replay_buffer_train_add 928
# 930
# replay_buffer_train_add 930
# 932
# replay_buffer_train_add 932
# 934
# replay_buffer_train_add 934
# 936
# replay_buffer_train_add 936
# 938
# replay_buffer_train_add 938
# 940
# replay_buffer_train_add 940
# 942
# replay_buffer_train_add 942
# 944
# replay_buffer_train_add 944
# 946
# replay_buffer_train_add 946
# 948
# replay_buffer_train_add 948
# 950
# replay_buffer_train_add 950
# 952
# replay_buffer_train_add 952
# 954
# replay_buffer_train_add 954
# 956
# replay_buffer_train_add 956
# 958
# replay_buffer_train_add 958
# 960
# replay_buffer_train_add 960
# 962
# replay_buffer_train_add 962
# 964
# replay_buffer_train_add 964
# 966
# replay_buffer_train_add 966
# 968
# replay_buffer_train_add 968
# 970
# replay_buffer_train_add 970
# 972
# replay_buffer_train_add 972
# 974
# replay_buffer_train_add 974
# 976
# replay_buffer_train_add 976
# 978
# replay_buffer_train_add 978
# 980
# replay_buffer_train_add 980
# 982
# replay_buffer_eval_add 982
# 984
# replay_buffer_train_add 984
# 986
# replay_buffer_eval_add 986
# 988
# replay_buffer_train_add 988
# 990
# replay_buffer_eval_add 990
# 992
# replay_buffer_eval_add 992
# 994
# replay_buffer_train_add 994
# 996
# replay_buffer_eval_add 996
# 998
# replay_buffer_train_add 998
# 1000
# replay_buffer_train_add 1000
# 1002
# replay_buffer_train_add 1002
# 1004
# replay_buffer_train_add 1004
# 1006
# replay_buffer_train_add 1006
# 1008
# replay_buffer_train_add 1008
# 1010
# replay_buffer_train_add 1010
# 1012
# replay_buffer_eval_add 1012
# 1014
# replay_buffer_train_add 1014
# 1016
# replay_buffer_train_add 1016
# 1018
# replay_buffer_train_add 1018
# 1020
# replay_buffer_train_add 1020
# 1022
# replay_buffer_train_add 1022
# 1024
# replay_buffer_eval_add 1024
# 1026
# replay_buffer_train_add 1026
# 1028
# replay_buffer_train_add 1028
# 1030
# replay_buffer_train_add 1030
# 1032
# replay_buffer_train_add 1032
# 1034
# replay_buffer_train_add 1034
# 1036
# replay_buffer_train_add 1036
# 1038
# replay_buffer_train_add 1038
# 1040
# replay_buffer_train_add 1040
# 1042
# replay_buffer_train_add 1042
# 1044
# replay_buffer_train_add 1044
# 1046
# replay_buffer_eval_add 1046
# 1048
# replay_buffer_train_add 1048
# 1050
# replay_buffer_train_add 1050
# 1052
# replay_buffer_train_add 1052
# 1054
# replay_buffer_train_add 1054
# 1056
# replay_buffer_train_add 1056
# 1058
# replay_buffer_train_add 1058
# 1060
# replay_buffer_train_add 1060
# 1062
# replay_buffer_train_add 1062
# 1064
# replay_buffer_train_add 1064
# 1066
# replay_buffer_train_add 1066
# 1068
# replay_buffer_eval_add 1068
# 1070
# replay_buffer_train_add 1070
# 1072
# replay_buffer_train_add 1072
# 1074
# replay_buffer_train_add 1074
# 1076
# replay_buffer_eval_add 1076
# 1078
# replay_buffer_eval_add 1078
# 1080
# replay_buffer_train_add 1080
# 1082
# replay_buffer_train_add 1082
# 1084
# replay_buffer_train_add 1084
# 1086
# replay_buffer_train_add 1086
# 1088
# replay_buffer_eval_add 1088
# 1090
# replay_buffer_train_add 1090
# 1092
# replay_buffer_train_add 1092
# 1094
# replay_buffer_train_add 1094
# 1096
# replay_buffer_eval_add 1096
# 1098
# replay_buffer_train_add 1098
# 1100
# replay_buffer_eval_add 1100
# 1102
# replay_buffer_train_add 1102
# 1104
# replay_buffer_train_add 1104
# 1106
# replay_buffer_eval_add 1106
# 1108
# replay_buffer_train_add 1108
# 1110
# replay_buffer_train_add 1110
# 1112
# replay_buffer_train_add 1112
# 1114
# replay_buffer_eval_add 1114
# 1116
# replay_buffer_train_add 1116
# 1118
# replay_buffer_train_add 1118
# 1120
# replay_buffer_train_add 1120
# 1122
# replay_buffer_train_add 1122
# 1124
# replay_buffer_eval_add 1124
# 1126
# replay_buffer_train_add 1126
# 1128
# replay_buffer_train_add 1128
# 1130
# replay_buffer_eval_add 1130
# 1132
# replay_buffer_train_add 1132
# 1134
# replay_buffer_train_add 1134
# 1136
# replay_buffer_eval_add 1136
# 1138
# replay_buffer_train_add 1138
# 1140
# replay_buffer_train_add 1140
# 1142
# replay_buffer_train_add 1142
# 1144
# replay_buffer_train_add 1144
# 1146
# replay_buffer_eval_add 1146
# 1148
# replay_buffer_train_add 1148
# 1150
# replay_buffer_train_add 1150
# 1152
# replay_buffer_train_add 1152
# 1154
# replay_buffer_train_add 1154
# 1156
# replay_buffer_train_add 1156
# 1158
# replay_buffer_train_add 1158
# 1160
# replay_buffer_train_add 1160
# 1162
# replay_buffer_train_add 1162
# 1164
# replay_buffer_train_add 1164
# 1166
# replay_buffer_train_add 1166
# 1168
# replay_buffer_train_add 1168
# 1170
# replay_buffer_train_add 1170
# 1172
# replay_buffer_train_add 1172
# 1174
# replay_buffer_train_add 1174
# 1176
# replay_buffer_train_add 1176
# 1178
# replay_buffer_train_add 1178
# 1180
# replay_buffer_train_add 1180
# 1182
# replay_buffer_train_add 1182
# 1184
# replay_buffer_train_add 1184
# 1186
# replay_buffer_train_add 1186
# 1188
# replay_buffer_eval_add 1188
# 1190
# replay_buffer_train_add 1190
# 1192
# replay_buffer_train_add 1192
# 1194
# replay_buffer_train_add 1194
# 1196
# replay_buffer_train_add 1196
# 1198
# replay_buffer_train_add 1198
# 1200
# replay_buffer_train_add 1200
# 1202
# replay_buffer_eval_add 1202
# 1204
# replay_buffer_train_add 1204
# 1206
# replay_buffer_train_add 1206
# 1208
# replay_buffer_train_add 1208
# 1210
# replay_buffer_eval_add 1210
# 1212
# replay_buffer_train_add 1212
# 1214
# replay_buffer_train_add 1214
# 1216
# replay_buffer_eval_add 1216
# 1218
# replay_buffer_train_add 1218
# 1220
# replay_buffer_train_add 1220
# 1222
# replay_buffer_train_add 1222
# 1224
# replay_buffer_train_add 1224
# 1226
# replay_buffer_train_add 1226
# 1228
# replay_buffer_train_add 1228
# 1230
# replay_buffer_train_add 1230
# 1232
# replay_buffer_train_add 1232
# 1234
# replay_buffer_train_add 1234
# 1236
# replay_buffer_train_add 1236
# 1238
# replay_buffer_train_add 1238
# 1240
# replay_buffer_eval_add 1240
# 1242
# replay_buffer_eval_add 1242
# 1244
# replay_buffer_eval_add 1244
# 1246
# replay_buffer_train_add 1246
# 1248
# replay_buffer_train_add 1248
# 1250
# replay_buffer_train_add 1250
# 1252
# replay_buffer_train_add 1252
# 1254
# replay_buffer_eval_add 1254
# 1256
# replay_buffer_train_add 1256
# 1258
# replay_buffer_train_add 1258
# 1260
# replay_buffer_train_add 1260
# 1262
# replay_buffer_train_add 1262
# 1264
# replay_buffer_eval_add 1264
# 1266
# replay_buffer_train_add 1266
# 1268
# replay_buffer_train_add 1268
# 1270
# replay_buffer_eval_add 1270
# 1272
# replay_buffer_train_add 1272
# 1274
# replay_buffer_train_add 1274
# 1276
# replay_buffer_train_add 1276
# 1278
# replay_buffer_train_add 1278
# 1280
# replay_buffer_train_add 1280
# 1282
# replay_buffer_train_add 1282
# 1284
# replay_buffer_train_add 1284
# 1286
# replay_buffer_train_add 1286
# 1288
# replay_buffer_train_add 1288
# 1290
# replay_buffer_train_add 1290
# 1292
# replay_buffer_eval_add 1292
# 1294
# replay_buffer_train_add 1294
# 1296
# replay_buffer_train_add 1296
# 1298
# replay_buffer_train_add 1298
# 1300
# replay_buffer_train_add 1300
# 1302
# replay_buffer_train_add 1302
# 1304
# replay_buffer_train_add 1304
# 1306
# replay_buffer_eval_add 1306
# 1308
# replay_buffer_train_add 1308
# 1310
# replay_buffer_train_add 1310
# 1312
# replay_buffer_eval_add 1312
# 1314
# replay_buffer_train_add 1314
# 1316
# replay_buffer_train_add 1316
# 1318
# replay_buffer_train_add 1318
# 1320
# replay_buffer_train_add 1320
# 1322
# replay_buffer_train_add 1322
# 1324
# replay_buffer_eval_add 1324
# 1326
# replay_buffer_train_add 1326
# 1328
# replay_buffer_train_add 1328
# 1330
# replay_buffer_eval_add 1330
# 1332
# replay_buffer_train_add 1332
# 1334
# replay_buffer_train_add 1334
# 1336
# replay_buffer_train_add 1336
# 1338
# replay_buffer_train_add 1338
# 1340
# replay_buffer_train_add 1340
# 1342
# replay_buffer_train_add 1342
# 1344
# replay_buffer_train_add 1344
# 1346
# replay_buffer_train_add 1346
# 1348
# replay_buffer_train_add 1348
# 1350
# replay_buffer_eval_add 1350
# 1352
# replay_buffer_train_add 1352
# 1354
# replay_buffer_train_add 1354
# 1356
# replay_buffer_eval_add 1356
# 1358
# replay_buffer_train_add 1358
# 1360
# replay_buffer_train_add 1360
# 1362
# replay_buffer_train_add 1362
# 1364
# replay_buffer_train_add 1364
# 1366
# replay_buffer_train_add 1366
# 1368
# replay_buffer_train_add 1368
# 1370
# replay_buffer_train_add 1370
# 1372
# replay_buffer_train_add 1372
# 1374
# replay_buffer_train_add 1374
# 1376
# replay_buffer_train_add 1376
# 1378
# replay_buffer_train_add 1378
# 1380
# replay_buffer_train_add 1380
# 1382
# replay_buffer_train_add 1382
# 1384
# replay_buffer_train_add 1384
# 1386
# replay_buffer_train_add 1386
# 1388
# replay_buffer_eval_add 1388
# 1390
# replay_buffer_eval_add 1390
# 1392
# replay_buffer_train_add 1392
# 1394
# replay_buffer_eval_add 1394
# 1396
# replay_buffer_train_add 1396
# 1398
# replay_buffer_train_add 1398
# 1400
# replay_buffer_eval_add 1400
# 1402
# replay_buffer_train_add 1402
# 1404
# replay_buffer_eval_add 1404
# 1406
# replay_buffer_train_add 1406
# 1408
# replay_buffer_train_add 1408
# 1410
# replay_buffer_train_add 1410
# 1412
# replay_buffer_eval_add 1412
# 1414
# replay_buffer_train_add 1414
# 1416
# replay_buffer_train_add 1416
# 1418
# replay_buffer_train_add 1418
# 1420
# replay_buffer_train_add 1420
# 1422
# replay_buffer_train_add 1422
# 1424
# replay_buffer_train_add 1424
# 1426
# replay_buffer_train_add 1426
# 1428
# replay_buffer_train_add 1428
# 1430
# replay_buffer_eval_add 1430
# 1432
# replay_buffer_train_add 1432
# 1434
# replay_buffer_train_add 1434
# 1436
# replay_buffer_train_add 1436
# 1438
# replay_buffer_train_add 1438
# 1440
# replay_buffer_train_add 1440
# 1442
# replay_buffer_eval_add 1442
# 1444
# replay_buffer_eval_add 1444
# 1446
# replay_buffer_train_add 1446
# 1448
# replay_buffer_train_add 1448
# 1450
# replay_buffer_train_add 1450
# 1452
# replay_buffer_train_add 1452
# 1454
# replay_buffer_train_add 1454
# 1456
# replay_buffer_train_add 1456
# 1458
# replay_buffer_train_add 1458
# 1460
# replay_buffer_train_add 1460
# 1462
# replay_buffer_train_add 1462
# 1464
# replay_buffer_train_add 1464
# 1466
# replay_buffer_train_add 1466
# 1468
# replay_buffer_eval_add 1468
# 1470
# replay_buffer_eval_add 1470
# 1472
# replay_buffer_train_add 1472
# 1474
# replay_buffer_train_add 1474
# 1476
# replay_buffer_train_add 1476
# 1478
# replay_buffer_train_add 1478
# 1480
# replay_buffer_train_add 1480
# 1482
# replay_buffer_train_add 1482
# 1484
# replay_buffer_train_add 1484
# 1486
# replay_buffer_train_add 1486
# 1488
# replay_buffer_train_add 1488
# 1490
# replay_buffer_train_add 1490
# 1492
# replay_buffer_train_add 1492
# 1494
# replay_buffer_eval_add 1494
# 1496
# replay_buffer_train_add 1496
# 1498
# replay_buffer_train_add 1498
# 1500
# replay_buffer_train_add 1500
# 1502
# replay_buffer_eval_add 1502
# 1504
# replay_buffer_train_add 1504
# 1506
# replay_buffer_eval_add 1506
# 1508
# replay_buffer_train_add 1508
# 1510
# replay_buffer_eval_add 1510
# 1512
# replay_buffer_eval_add 1512
# 1514
# replay_buffer_train_add 1514
# 1516
# replay_buffer_train_add 1516
# 1518
# replay_buffer_train_add 1518
# 1520
# replay_buffer_train_add 1520
# 1522
# replay_buffer_eval_add 1522
# 1524
# replay_buffer_train_add 1524
# 1526
# replay_buffer_eval_add 1526
# 1528
# replay_buffer_train_add 1528
# 1530
# replay_buffer_train_add 1530
# 1532
# replay_buffer_train_add 1532
# 1534
# replay_buffer_train_add 1534
# 1536
# replay_buffer_train_add 1536
# 1538
# replay_buffer_eval_add 1538
# 1540
# replay_buffer_eval_add 1540
# 1542
# replay_buffer_train_add 1542
# 1544
# replay_buffer_eval_add 1544
# 1546
# replay_buffer_train_add 1546
# 1548
# replay_buffer_train_add 1548
# 1550
# replay_buffer_eval_add 1550
# 1552
# replay_buffer_train_add 1552
# 1554
# replay_buffer_train_add 1554
# 1556
# replay_buffer_eval_add 1556
# 1558
# replay_buffer_eval_add 1558
# 1560
# replay_buffer_train_add 1560
# 1562
# replay_buffer_train_add 1562
# 1564
# replay_buffer_train_add 1564
# 1566
# replay_buffer_train_add 1566
# 1568
# replay_buffer_train_add 1568
# 1570
# replay_buffer_train_add 1570
# 1572
# replay_buffer_train_add 1572
# 1574
# replay_buffer_train_add 1574
# 1576
# replay_buffer_train_add 1576
# 1578
# replay_buffer_train_add 1578
# 1580
# replay_buffer_train_add 1580
# 1582
# replay_buffer_eval_add 1582
# 1584
# replay_buffer_train_add 1584
# 1586
# replay_buffer_train_add 1586
# 1588
# replay_buffer_train_add 1588
# 1590
# replay_buffer_eval_add 1590
# 1592
# replay_buffer_train_add 1592
# 1594
# replay_buffer_train_add 1594
# 1596
# replay_buffer_train_add 1596
# 1598
# replay_buffer_train_add 1598
# 1600
# replay_buffer_train_add 1600
# 1602
# replay_buffer_train_add 1602
# 1604
# replay_buffer_train_add 1604
# 1606
# replay_buffer_train_add 1606
# 1608
# replay_buffer_eval_add 1608
# 1610
# replay_buffer_train_add 1610
# 1612
# replay_buffer_eval_add 1612
# 1614
# replay_buffer_train_add 1614
# 1616
# replay_buffer_eval_add 1616
# 1618
# replay_buffer_train_add 1618
# 1620
# replay_buffer_train_add 1620
# 1622
# replay_buffer_eval_add 1622
# 1624
# replay_buffer_train_add 1624
# 1626
# replay_buffer_train_add 1626
# 1628
# replay_buffer_train_add 1628
# 1630
# replay_buffer_train_add 1630
# 1632
# replay_buffer_train_add 1632
# 1634
# replay_buffer_train_add 1634
# 1636
# replay_buffer_train_add 1636
# 1638
# replay_buffer_eval_add 1638
# 1640
# replay_buffer_eval_add 1640
# 1642
# replay_buffer_eval_add 1642
# 1644
# replay_buffer_train_add 1644
# 1646
# replay_buffer_train_add 1646
# 1648
# replay_buffer_train_add 1648
# 1650
# replay_buffer_eval_add 1650
# 1652
# replay_buffer_eval_add 1652
# 1654
# replay_buffer_train_add 1654
# 1656
# replay_buffer_train_add 1656
# 1658
# replay_buffer_eval_add 1658
# 1660
# replay_buffer_train_add 1660
# 1662
# replay_buffer_train_add 1662
# 1664
# replay_buffer_train_add 1664
# 1666
# replay_buffer_train_add 1666
# 1668
# replay_buffer_train_add 1668
# 1670
# replay_buffer_train_add 1670
# 1672
# replay_buffer_train_add 1672
# 1674
# replay_buffer_train_add 1674
# 1676
# replay_buffer_eval_add 1676
# 1678
# replay_buffer_eval_add 1678
# 1680
# replay_buffer_train_add 1680
# 1682
# replay_buffer_train_add 1682
# 1684
# replay_buffer_train_add 1684
# 1686
# replay_buffer_train_add 1686
# 1688
# replay_buffer_train_add 1688
# 1690
# replay_buffer_train_add 1690
# 1692
# replay_buffer_train_add 1692
# 1694
# replay_buffer_eval_add 1694
# 1696
# replay_buffer_train_add 1696
# 1698
# replay_buffer_train_add 1698
# 1700
# replay_buffer_train_add 1700
# 1702
# replay_buffer_train_add 1702
# 1704
# replay_buffer_train_add 1704
# 1706
# replay_buffer_train_add 1706
# 1708
# replay_buffer_train_add 1708
# 1710
# replay_buffer_train_add 1710
# 1712
# replay_buffer_train_add 1712
# 1714
# replay_buffer_train_add 1714
# 1716
# replay_buffer_train_add 1716
# 1718
# replay_buffer_eval_add 1718
# 1720
# replay_buffer_train_add 1720
# 1722
# replay_buffer_train_add 1722
# 1724
# replay_buffer_eval_add 1724
# 1726
# replay_buffer_train_add 1726
# 1728
# replay_buffer_train_add 1728
# 1730
# replay_buffer_train_add 1730
# 1732
# replay_buffer_train_add 1732
# 1734
# replay_buffer_train_add 1734
# 1736
# replay_buffer_eval_add 1736
# 1738
# replay_buffer_train_add 1738
# 1740
# replay_buffer_train_add 1740
# 1742
# replay_buffer_train_add 1742
# 1744
# replay_buffer_train_add 1744
# 1746
# replay_buffer_train_add 1746
# 1748
# replay_buffer_train_add 1748
# 1750
# replay_buffer_eval_add 1750
# 1752
# replay_buffer_eval_add 1752
# 1754
# replay_buffer_train_add 1754
# 1756
# replay_buffer_eval_add 1756
# 1758
# replay_buffer_train_add 1758
# 1760
# replay_buffer_train_add 1760
# 1762
# replay_buffer_train_add 1762
# 1764
# replay_buffer_eval_add 1764
# 1766
# replay_buffer_train_add 1766
# 1768
# replay_buffer_train_add 1768
# 1770
# replay_buffer_train_add 1770
# 1772
# replay_buffer_train_add 1772
# 1774
# replay_buffer_train_add 1774
# 1776
# replay_buffer_train_add 1776
# 1778
# replay_buffer_eval_add 1778
# 1780
# replay_buffer_train_add 1780
# 1782
# replay_buffer_eval_add 1782
# 1784
# replay_buffer_train_add 1784
# 1786
# replay_buffer_train_add 1786
# 1788
# replay_buffer_train_add 1788
# 1790
# replay_buffer_train_add 1790
# 1792
# replay_buffer_train_add 1792
# 1794
# replay_buffer_train_add 1794
# 1796
# replay_buffer_train_add 1796
# 1798
# replay_buffer_train_add 1798
# 1800
# replay_buffer_train_add 1800
# 1802
# replay_buffer_eval_add 1802
# 1804
# replay_buffer_train_add 1804
# 1806
# replay_buffer_train_add 1806
# 1808
# replay_buffer_eval_add 1808
# 1810
# replay_buffer_train_add 1810
# 1812
# replay_buffer_eval_add 1812
# 1814
# replay_buffer_eval_add 1814
# 1816
# replay_buffer_eval_add 1816
# 1818
# replay_buffer_train_add 1818
# 1820
# replay_buffer_train_add 1820
# 1822
# replay_buffer_train_add 1822
# 1824
# replay_buffer_train_add 1824
# 1826
# replay_buffer_train_add 1826
# 1828
# replay_buffer_train_add 1828
# 1830
# replay_buffer_train_add 1830
# 1832
# replay_buffer_train_add 1832
# 1834
# replay_buffer_train_add 1834
# 1836
# replay_buffer_train_add 1836
# 1838
# replay_buffer_train_add 1838
# 1840
# replay_buffer_train_add 1840
# 1842
# replay_buffer_train_add 1842
# 1844
# replay_buffer_train_add 1844
# 1846
# replay_buffer_train_add 1846
# 1848
# replay_buffer_eval_add 1848
# 1850
# replay_buffer_train_add 1850
# 1852
# replay_buffer_train_add 1852
# 1854
# replay_buffer_eval_add 1854
# 1856
# replay_buffer_train_add 1856
# 1858
# replay_buffer_eval_add 1858
# 1860
# replay_buffer_train_add 1860
# 1862
# replay_buffer_train_add 1862
# 1864
# replay_buffer_train_add 1864
# 1866
# replay_buffer_train_add 1866
# 1868
# replay_buffer_train_add 1868
# 1870
# replay_buffer_eval_add 1870
# 1872
# replay_buffer_train_add 1872
# 1874
# replay_buffer_train_add 1874
# 1876
# replay_buffer_train_add 1876
# 1878
# replay_buffer_train_add 1878
# 1880
# replay_buffer_train_add 1880
# 1882
# replay_buffer_train_add 1882
# 1884
# replay_buffer_train_add 1884
# 1886
# replay_buffer_train_add 1886
# 1888
# replay_buffer_eval_add 1888
# 1890
# replay_buffer_train_add 1890
# 1892
# replay_buffer_train_add 1892
# 1894
# replay_buffer_train_add 1894
# 1896
# replay_buffer_train_add 1896
# 1898
# replay_buffer_train_add 1898
# 1900
# replay_buffer_train_add 1900
# 1902
# replay_buffer_train_add 1902
# 1904
# replay_buffer_eval_add 1904
# 1906
# replay_buffer_train_add 1906
# 1908
# replay_buffer_train_add 1908
# 1910
# replay_buffer_train_add 1910
# 1912
# replay_buffer_train_add 1912
# 1914
# replay_buffer_train_add 1914
# 1916
# replay_buffer_eval_add 1916
# 1918
# replay_buffer_eval_add 1918
# 1920
# replay_buffer_eval_add 1920
# 1922
# replay_buffer_train_add 1922
# 1924
# replay_buffer_train_add 1924
# 1926
# replay_buffer_train_add 1926
# 1928
# replay_buffer_train_add 1928
# 1930
# replay_buffer_eval_add 1930
# 1932
# replay_buffer_train_add 1932
# 1934
# replay_buffer_train_add 1934
# 1936
# replay_buffer_train_add 1936
# 1938
# replay_buffer_train_add 1938
# 1940
# replay_buffer_train_add 1940
# 1942
# replay_buffer_train_add 1942
# 1944
# replay_buffer_train_add 1944
# 1946
# replay_buffer_eval_add 1946
# 1948
# replay_buffer_train_add 1948
# 1950
# replay_buffer_eval_add 1950
# 1952
# replay_buffer_train_add 1952
# 1954
# replay_buffer_train_add 1954
# 1956
# replay_buffer_train_add 1956
# 1958
# replay_buffer_eval_add 1958
# 1960
# replay_buffer_eval_add 1960
# 1962
# replay_buffer_train_add 1962
# 1964
# replay_buffer_train_add 1964
# 1966
# replay_buffer_train_add 1966
# 1968
# replay_buffer_train_add 1968
# 1970
# replay_buffer_train_add 1970
# 1972
# replay_buffer_train_add 1972
# 1974
# replay_buffer_train_add 1974
# 1976
# replay_buffer_train_add 1976
# 1978
# replay_buffer_train_add 1978
# 1980
# replay_buffer_eval_add 1980
# 1982
# replay_buffer_train_add 1982
# 1984
# replay_buffer_train_add 1984
# 1986
# replay_buffer_train_add 1986
# 1988
# replay_buffer_eval_add 1988
# 1990
# replay_buffer_eval_add 1990
# 1992
# replay_buffer_train_add 1992
# 1994
# replay_buffer_eval_add 1994
# 1996
# replay_buffer_train_add 1996
# 1998
# replay_buffer_train_add 1998
# 2000
# replay_buffer_eval_add 2000
# 2002
# replay_buffer_train_add 2002
# 2004
# replay_buffer_train_add 2004
# 2006
# replay_buffer_train_add 2006
# 2008
# replay_buffer_train_add 2008
# 2010
# replay_buffer_train_add 2010
# 2012
# replay_buffer_train_add 2012
# 2014
# replay_buffer_train_add 2014
# 2016
# replay_buffer_eval_add 2016
# 2018
# replay_buffer_train_add 2018
# 2020
# replay_buffer_eval_add 2020
# 2022
# replay_buffer_train_add 2022
# 2024
# replay_buffer_eval_add 2024
# 2026
# replay_buffer_train_add 2026
# 2028
# replay_buffer_train_add 2028
# 2030
# replay_buffer_train_add 2030
# 2032
# replay_buffer_train_add 2032
# 2034
# replay_buffer_train_add 2034
# 2036
# replay_buffer_train_add 2036
# 2038
# replay_buffer_eval_add 2038
# 2040
# replay_buffer_train_add 2040
# 2042
# replay_buffer_train_add 2042
# 2044
# replay_buffer_train_add 2044
# 2046
# replay_buffer_train_add 2046
# 2048
# replay_buffer_train_add 2048
# 2050
# replay_buffer_train_add 2050
# 2052
# replay_buffer_train_add 2052
# 2054
# replay_buffer_train_add 2054
# 2056
# replay_buffer_train_add 2056
# 2058
# replay_buffer_train_add 2058
# 2060
# replay_buffer_train_add 2060
# 2062
# replay_buffer_train_add 2062
# 2064
# replay_buffer_train_add 2064
# 2066
# replay_buffer_train_add 2066
# 2068
# replay_buffer_train_add 2068
# 2070
# replay_buffer_eval_add 2070
# 2072
# replay_buffer_train_add 2072
# 2074
# replay_buffer_train_add 2074
# 2076
# replay_buffer_eval_add 2076
# 2078
# replay_buffer_train_add 2078
# 2080
# replay_buffer_train_add 2080
# 2082
# replay_buffer_eval_add 2082
# 2084
# replay_buffer_train_add 2084
# 2086
# replay_buffer_train_add 2086
# 2088
# replay_buffer_train_add 2088
# 2090
# replay_buffer_train_add 2090
# 2092
# replay_buffer_train_add 2092
# 2094
# replay_buffer_train_add 2094
# 2096
# replay_buffer_train_add 2096
# 2098
# replay_buffer_train_add 2098
# 2100
# replay_buffer_train_add 2100
# 2102
# replay_buffer_train_add 2102
# 2104
# replay_buffer_eval_add 2104
# 2106
# replay_buffer_eval_add 2106
# 2108
# replay_buffer_eval_add 2108
# 2110
# replay_buffer_eval_add 2110
# 2112
# replay_buffer_train_add 2112
# 2114
# replay_buffer_train_add 2114
# 2116
# replay_buffer_train_add 2116
# 2118
# replay_buffer_train_add 2118
# 2120
# replay_buffer_train_add 2120
# 2122
# replay_buffer_eval_add 2122
# 2124
# replay_buffer_train_add 2124
# 2126
# replay_buffer_train_add 2126
# 2128
# replay_buffer_train_add 2128
# 2130
# replay_buffer_train_add 2130
# 2132
# replay_buffer_train_add 2132
# 2134
# replay_buffer_train_add 2134
# 2136
# replay_buffer_eval_add 2136
# 2138
# replay_buffer_train_add 2138
# 2140
# replay_buffer_train_add 2140
# 2142
# replay_buffer_train_add 2142
# 2144
# replay_buffer_train_add 2144
# 2146
# replay_buffer_train_add 2146
# 2148
# replay_buffer_train_add 2148
# 2150
# replay_buffer_train_add 2150
# 2152
# replay_buffer_train_add 2152
# 2154
# replay_buffer_train_add 2154
# 2156
# replay_buffer_eval_add 2156
# 2158
# replay_buffer_train_add 2158
# 2160
# replay_buffer_train_add 2160
# 2162
# replay_buffer_eval_add 2162
# 2164
# replay_buffer_train_add 2164
# 2166
# replay_buffer_eval_add 2166
# 2168
# replay_buffer_train_add 2168
# 2170
# replay_buffer_train_add 2170
# 2172
# replay_buffer_train_add 2172
# 2174
# replay_buffer_train_add 2174
# 2176
# replay_buffer_train_add 2176
# 2178
# replay_buffer_train_add 2178
# 2180
# replay_buffer_eval_add 2180
# 2182
# replay_buffer_train_add 2182
# 2184
# replay_buffer_train_add 2184
# 2186
# replay_buffer_eval_add 2186
# 2188
# replay_buffer_train_add 2188
# 2190
# replay_buffer_train_add 2190
# 2192
# replay_buffer_eval_add 2192
# 2194
# replay_buffer_train_add 2194
# 2196
# replay_buffer_train_add 2196
# 2198
# replay_buffer_train_add 2198
# 2200
# replay_buffer_train_add 2200
# 2202
# replay_buffer_train_add 2202
# 2204
# replay_buffer_eval_add 2204
# 2206
# replay_buffer_train_add 2206
# 2208
# replay_buffer_train_add 2208
# 2210
# replay_buffer_train_add 2210
# 2212
# replay_buffer_train_add 2212
# 2214
# replay_buffer_train_add 2214
# 2216
# replay_buffer_eval_add 2216
# 2218
# replay_buffer_train_add 2218
# 2220
# replay_buffer_train_add 2220
# 2222
# replay_buffer_train_add 2222
# 2224
# replay_buffer_train_add 2224
# 2226
# replay_buffer_eval_add 2226
# 2228
# replay_buffer_eval_add 2228
# 2230
# replay_buffer_train_add 2230
# 2232
# replay_buffer_train_add 2232
# 2234
# replay_buffer_train_add 2234
# 2236
# replay_buffer_train_add 2236
# 2238
# replay_buffer_eval_add 2238
# 2240
# replay_buffer_eval_add 2240
# 2242
# replay_buffer_train_add 2242
# 2244
# replay_buffer_eval_add 2244
# 2246
# replay_buffer_train_add 2246
# 2248
# replay_buffer_train_add 2248
# 2250
# replay_buffer_train_add 2250
# 2252
# replay_buffer_train_add 2252
# 2254
# replay_buffer_train_add 2254
# 2256
# replay_buffer_train_add 2256
# 2258
# replay_buffer_train_add 2258
# 2260
# replay_buffer_train_add 2260
# 2262
# replay_buffer_train_add 2262
# 2264
# replay_buffer_train_add 2264
# 2266
# replay_buffer_train_add 2266
# 2268
# replay_buffer_eval_add 2268
# 2270
# replay_buffer_train_add 2270
# 2272
# replay_buffer_train_add 2272
# 2274
# replay_buffer_train_add 2274
# 2276
# replay_buffer_eval_add 2276
# 2278
# replay_buffer_eval_add 2278
# 2280
# replay_buffer_train_add 2280
# 2282
# replay_buffer_train_add 2282
# 2284
# replay_buffer_train_add 2284
# 2286
# replay_buffer_train_add 2286
# 2288
# replay_buffer_train_add 2288
# 2290
# replay_buffer_train_add 2290
# 2292
# replay_buffer_train_add 2292
# 2294
# replay_buffer_train_add 2294
# 2296
# replay_buffer_train_add 2296
# 2298
# replay_buffer_train_add 2298
# 2300
# replay_buffer_train_add 2300
# 2302
# replay_buffer_train_add 2302
# 2304
# replay_buffer_train_add 2304
# 2306
# replay_buffer_train_add 2306
# 2308
# replay_buffer_train_add 2308
# 2310
# replay_buffer_train_add 2310
# 2312
# replay_buffer_eval_add 2312
# 2314
# replay_buffer_eval_add 2314
# 2316
# replay_buffer_eval_add 2316
# 2318
# replay_buffer_train_add 2318
# 2320
# replay_buffer_eval_add 2320
# 2322
# replay_buffer_train_add 2322
# 2324
# replay_buffer_train_add 2324
# 2326
# replay_buffer_train_add 2326
# 2328
# replay_buffer_train_add 2328
# 2330
# replay_buffer_train_add 2330
# 2332
# replay_buffer_train_add 2332
# 2334
# replay_buffer_train_add 2334
# 2336
# replay_buffer_eval_add 2336
# 2338
# replay_buffer_train_add 2338
# 2340
# replay_buffer_train_add 2340
# 2342
# replay_buffer_train_add 2342
# 2344
# replay_buffer_train_add 2344
# 2346
# replay_buffer_train_add 2346
# 2348
# replay_buffer_train_add 2348
# 2350
# replay_buffer_train_add 2350
# 2352
# replay_buffer_eval_add 2352
# 2354
# replay_buffer_train_add 2354
# 2356
# replay_buffer_train_add 2356
# 2358
# replay_buffer_train_add 2358
# 2360
# replay_buffer_train_add 2360
# 2362
# replay_buffer_eval_add 2362
# 2364
# replay_buffer_train_add 2364
# 2366
# replay_buffer_train_add 2366
# 2368
# replay_buffer_train_add 2368
# 2370
# replay_buffer_eval_add 2370
# 2372
# replay_buffer_train_add 2372
# 2374
# replay_buffer_eval_add 2374
# 2376
# replay_buffer_train_add 2376
# 2378
# replay_buffer_eval_add 2378
# 2380
# replay_buffer_eval_add 2380
# 2382
# replay_buffer_train_add 2382
# 2384
# replay_buffer_train_add 2384
# 2386
# replay_buffer_train_add 2386
# 2388
# replay_buffer_train_add 2388
# 2390
# replay_buffer_train_add 2390
# 2392
# replay_buffer_train_add 2392
# 2394
# replay_buffer_train_add 2394
# 2396
# replay_buffer_train_add 2396
# 2398
# replay_buffer_train_add 2398
# 2400
# replay_buffer_eval_add 2400
# 2402
# replay_buffer_train_add 2402
# 2404
# replay_buffer_train_add 2404
# 2406
# replay_buffer_train_add 2406
# 2408
# replay_buffer_train_add 2408
# 2410
# replay_buffer_train_add 2410
# 2412
# replay_buffer_eval_add 2412
# 2414
# replay_buffer_train_add 2414
# 2416
# replay_buffer_train_add 2416
# 2418
# replay_buffer_train_add 2418
# 2420
# replay_buffer_eval_add 2420
# 2422
# replay_buffer_train_add 2422
# 2424
# replay_buffer_train_add 2424
# 2426
# replay_buffer_eval_add 2426
# 2428
# replay_buffer_eval_add 2428
# 2430
# replay_buffer_train_add 2430
# 2432
# replay_buffer_train_add 2432
# 2434
# replay_buffer_train_add 2434
# 2436
# replay_buffer_eval_add 2436
# 2438
# replay_buffer_eval_add 2438
# 2440
# replay_buffer_train_add 2440
# 2442
# replay_buffer_train_add 2442
# 2444
# replay_buffer_train_add 2444
# 2446
# replay_buffer_train_add 2446
# 2448
# replay_buffer_train_add 2448
# 2450
# replay_buffer_train_add 2450
# 2452
# replay_buffer_train_add 2452
# 2454
# replay_buffer_train_add 2454
# 2456
# replay_buffer_train_add 2456
# 2458
# replay_buffer_eval_add 2458
# 2460
# replay_buffer_train_add 2460
# 2462
# replay_buffer_train_add 2462
# 2464
# replay_buffer_eval_add 2464
# 2466
# replay_buffer_train_add 2466
# 2468
# replay_buffer_train_add 2468
# 2470
# replay_buffer_train_add 2470
# 2472
# replay_buffer_train_add 2472
# 2474
# replay_buffer_train_add 2474
# 2476
# replay_buffer_eval_add 2476
# 2478
# replay_buffer_eval_add 2478
# 2480
# replay_buffer_train_add 2480
# 2482
# replay_buffer_eval_add 2482
# 2484
# replay_buffer_eval_add 2484
# 2486
# replay_buffer_eval_add 2486
# 2488
# replay_buffer_train_add 2488
# 2490
# replay_buffer_eval_add 2490
# 2492
# replay_buffer_train_add 2492
# 2494
# replay_buffer_train_add 2494
# 2496
# replay_buffer_train_add 2496
# 2498
# replay_buffer_train_add 2498
# 2500
# replay_buffer_eval_add 2500
# 2502
# replay_buffer_train_add 2502
# 2504
# replay_buffer_train_add 2504
# 2506
# replay_buffer_train_add 2506
# 2508
# replay_buffer_train_add 2508
# 2510
# replay_buffer_train_add 2510
# 2512
# replay_buffer_train_add 2512
# 2514
# replay_buffer_eval_add 2514
# 2516
# replay_buffer_train_add 2516
# 2518
# replay_buffer_train_add 2518
# 2520
# replay_buffer_eval_add 2520
# 2522
# replay_buffer_train_add 2522
# 2524
# replay_buffer_eval_add 2524
# 2526
# replay_buffer_train_add 2526
# 2528
# replay_buffer_train_add 2528
# 2530
# replay_buffer_train_add 2530
# 2532
# replay_buffer_train_add 2532
# 2534
# replay_buffer_train_add 2534
# 2536
# replay_buffer_train_add 2536
# 2538
# replay_buffer_train_add 2538
# 2540
# replay_buffer_train_add 2540
# 2542
# replay_buffer_train_add 2542
# 2544
# replay_buffer_train_add 2544
# 2546
# replay_buffer_train_add 2546
# 2548
# replay_buffer_eval_add 2548
# 2550
# replay_buffer_train_add 2550
# 2552
# replay_buffer_train_add 2552
# 2554
# replay_buffer_train_add 2554
# 2556
# replay_buffer_train_add 2556
# 2558
# replay_buffer_eval_add 2558
# 2560
# replay_buffer_eval_add 2560
# 2562
# replay_buffer_train_add 2562
# 2564
# replay_buffer_eval_add 2564
# 2566
# replay_buffer_train_add 2566
# 2568
# replay_buffer_train_add 2568
# 2570
# replay_buffer_train_add 2570
# 2572
# replay_buffer_train_add 2572
# 2574
# replay_buffer_train_add 2574
# 2576
# replay_buffer_train_add 2576
# 2578
# replay_buffer_train_add 2578
# 2580
# replay_buffer_eval_add 2580
# 2582
# replay_buffer_train_add 2582
# 2584
# replay_buffer_eval_add 2584
# 2586
# replay_buffer_train_add 2586
# 2588
# replay_buffer_eval_add 2588
# 2590
# replay_buffer_train_add 2590
# 2592
# replay_buffer_train_add 2592
# 2594
# replay_buffer_train_add 2594
# 2596
# replay_buffer_eval_add 2596
# 2598
# replay_buffer_train_add 2598
# 2600
# replay_buffer_train_add 2600
# 2602
# replay_buffer_train_add 2602
# 2604
# replay_buffer_train_add 2604
# 2606
# replay_buffer_train_add 2606
# 2608
# replay_buffer_train_add 2608
# 2610
# replay_buffer_train_add 2610
# 2612
# replay_buffer_train_add 2612
# 2614
# replay_buffer_train_add 2614
# 2616
# replay_buffer_train_add 2616
# 2618
# replay_buffer_train_add 2618
# 2620
# replay_buffer_eval_add 2620
# 2622
# replay_buffer_train_add 2622
# 2624
# replay_buffer_train_add 2624
# 2626
# replay_buffer_train_add 2626
# 2628
# replay_buffer_train_add 2628
# 2630
# replay_buffer_eval_add 2630
# 2632
# replay_buffer_train_add 2632
# 2634
# replay_buffer_train_add 2634
# 2636
# replay_buffer_train_add 2636
# 2638
# replay_buffer_train_add 2638
# 2640
# replay_buffer_train_add 2640
# 2642
# replay_buffer_train_add 2642
# 2644
# replay_buffer_train_add 2644
# 2646
# replay_buffer_train_add 2646
# 2648
# replay_buffer_train_add 2648
# 2650
# replay_buffer_train_add 2650
# 2652
# replay_buffer_train_add 2652
# 2654
# replay_buffer_train_add 2654
# 2656
# replay_buffer_train_add 2656
# 2658
# replay_buffer_train_add 2658
# 2660
# replay_buffer_train_add 2660
# 2662
# replay_buffer_train_add 2662
# 2664
# replay_buffer_train_add 2664
# 2666
# replay_buffer_eval_add 2666
# 2668
# replay_buffer_train_add 2668
# 2670
# replay_buffer_train_add 2670
# 2672
# replay_buffer_train_add 2672
# 2674
# replay_buffer_train_add 2674
# 2676
# replay_buffer_train_add 2676
# 2678
# replay_buffer_eval_add 2678
# 2680
# replay_buffer_train_add 2680
# 2682
# replay_buffer_eval_add 2682
# 2684
# replay_buffer_train_add 2684
# 2686
# replay_buffer_train_add 2686
# 2688
# replay_buffer_train_add 2688
# 2690
# replay_buffer_train_add 2690
# 2692
# replay_buffer_train_add 2692
# 2694
# replay_buffer_eval_add 2694
# 2696
# replay_buffer_train_add 2696
# 2698
# replay_buffer_train_add 2698
# 2700
# replay_buffer_train_add 2700
# 2702
# replay_buffer_train_add 2702
# 2704
# replay_buffer_train_add 2704
# 2706
# replay_buffer_train_add 2706
# 2708
# replay_buffer_train_add 2708
# 2710
# replay_buffer_train_add 2710
# 2712
# replay_buffer_eval_add 2712
# 2714
# replay_buffer_train_add 2714
# 2716
# replay_buffer_train_add 2716
# 2718
# replay_buffer_train_add 2718
# 2720
# replay_buffer_train_add 2720
# 2722
# replay_buffer_train_add 2722
# 2724
# replay_buffer_train_add 2724
# 2726
# replay_buffer_train_add 2726
# 2728
# replay_buffer_train_add 2728
# 2730
# replay_buffer_train_add 2730
# 2732
# replay_buffer_train_add 2732
# 2734
# replay_buffer_train_add 2734
# 2736
# replay_buffer_eval_add 2736
# 2738
# replay_buffer_eval_add 2738
# 2740
# replay_buffer_train_add 2740
# 2742
# replay_buffer_train_add 2742
# 2744
# replay_buffer_train_add 2744
# 2746
# replay_buffer_train_add 2746
# 2748
# replay_buffer_train_add 2748
# 2750
# replay_buffer_train_add 2750
# 2752
# replay_buffer_train_add 2752
# 2754
# replay_buffer_train_add 2754
# 2756
# replay_buffer_eval_add 2756
# 2758
# replay_buffer_eval_add 2758
# 2760
# replay_buffer_train_add 2760
# 2762
# replay_buffer_eval_add 2762
# 2764
# replay_buffer_train_add 2764
# 2766
# replay_buffer_train_add 2766
# 2768
# replay_buffer_train_add 2768
# 2770
# replay_buffer_train_add 2770
# 2772
# replay_buffer_eval_add 2772
# 2774
# replay_buffer_eval_add 2774
# 2776
# replay_buffer_train_add 2776
# 2778
# replay_buffer_train_add 2778
# 2780
# replay_buffer_train_add 2780
# 2782
# replay_buffer_eval_add 2782
# 2784
# replay_buffer_train_add 2784
# 2786
# replay_buffer_train_add 2786
# 2788
# replay_buffer_train_add 2788
# 2790
# replay_buffer_train_add 2790
# 2792
# replay_buffer_train_add 2792
# 2794
# replay_buffer_train_add 2794
# 2796
# replay_buffer_train_add 2796
# 2798
# replay_buffer_train_add 2798
# 2800
# replay_buffer_train_add 2800
# 2802
# replay_buffer_train_add 2802
# 2804
# replay_buffer_eval_add 2804
# 2806
# replay_buffer_eval_add 2806
# 2808
# replay_buffer_train_add 2808
# 2810
# replay_buffer_train_add 2810
# 2812
# replay_buffer_train_add 2812
# 2814
# replay_buffer_train_add 2814
# 2816
# replay_buffer_train_add 2816
# 2818
# replay_buffer_train_add 2818
# 2820
# replay_buffer_train_add 2820
# 2822
# replay_buffer_train_add 2822
# 2824
# replay_buffer_train_add 2824
# 2826
# replay_buffer_train_add 2826
# 2828
# replay_buffer_train_add 2828
# 2830
# replay_buffer_train_add 2830
# 2832
# replay_buffer_train_add 2832
# 2834
# replay_buffer_train_add 2834
# 2836
# replay_buffer_train_add 2836
# 2838
# replay_buffer_eval_add 2838
# 2840
# replay_buffer_eval_add 2840
# 2842
# replay_buffer_eval_add 2842
# 2844
# replay_buffer_train_add 2844
# 2846
# replay_buffer_train_add 2846
# 2848
# replay_buffer_train_add 2848
# 2850
# replay_buffer_train_add 2850
# 2852
# replay_buffer_train_add 2852
# 2854
# replay_buffer_train_add 2854
# 2856
# replay_buffer_train_add 2856
# 2858
# replay_buffer_train_add 2858
# 2860
# replay_buffer_train_add 2860
# 2862
# replay_buffer_train_add 2862
# 2864
# replay_buffer_eval_add 2864
# 2866
# replay_buffer_eval_add 2866
# 2868
# replay_buffer_train_add 2868
# 2870
# replay_buffer_train_add 2870
# 2872
# replay_buffer_train_add 2872
# 2874
# replay_buffer_train_add 2874
# 2876
# replay_buffer_eval_add 2876
# 2878
# replay_buffer_train_add 2878
# 2880
# replay_buffer_train_add 2880
# 2882
# replay_buffer_train_add 2882
# 2884
# replay_buffer_train_add 2884
# 2886
# replay_buffer_train_add 2886
# 2888
# replay_buffer_train_add 2888
# 2890
# replay_buffer_train_add 2890
# 2892
# replay_buffer_train_add 2892
# 2894
# replay_buffer_train_add 2894
# 2896
# replay_buffer_eval_add 2896
# 2898
# replay_buffer_eval_add 2898
# 2900
# replay_buffer_train_add 2900
# 2902
# replay_buffer_eval_add 2902
# 2904
# replay_buffer_eval_add 2904
# 2906
# ...
# 9008
# replay_buffer_train_add 9008
# 9010
# replay_buffer_train_add 9010
# 9012
# replay_buffer_train_add 9012
# 9014
# replay_buffer_train_add 9014
# 9016
# replay_buffer_train_add 9016
# 9018
# replay_buffer_eval_add 9018
# 9020
# replay_buffer_train_add 9020
# 9022
# replay_buffer_train_add 9022
# 9024
# replay_buffer_eval_add 9024
# 9026
# replay_buffer_train_add 9026
# 9028
# replay_buffer_train_add 9028
# 9030
# replay_buffer_train_add 9030
# 9032
# replay_buffer_train_add 9032
# 9034
# replay_buffer_train_add 9034
# 9036
# replay_buffer_train_add 9036
# 9038
# replay_buffer_eval_add 9038
# 9040
# replay_buffer_train_add 9040
# 9042
# replay_buffer_train_add 9042
# 9044
# replay_buffer_train_add 9044
# 9046
# replay_buffer_eval_add 9046
# 9048
# replay_buffer_eval_add 9048
# 9050
# replay_buffer_train_add 9050
# 9052
# replay_buffer_eval_add 9052
# 9054
# replay_buffer_train_add 9054
# 9056
# replay_buffer_train_add 9056
# 9058
# replay_buffer_train_add 9058
# 9060
# replay_buffer_train_add 9060
# 9062
# replay_buffer_train_add 9062
# 9064
# replay_buffer_train_add 9064
# 9066
# replay_buffer_train_add 9066
# 9068
# replay_buffer_train_add 9068
# 9070
# replay_buffer_train_add 9070
# 9072
# replay_buffer_train_add 9072
# 9074
# replay_buffer_eval_add 9074
# 9076
# replay_buffer_train_add 9076
# 9078
# replay_buffer_train_add 9078
# 9080
# replay_buffer_train_add 9080
# 9082
# replay_buffer_train_add 9082
# 9084
# replay_buffer_train_add 9084
# 9086
# replay_buffer_eval_add 9086
# 9088
# replay_buffer_eval_add 9088
# 9090
# replay_buffer_train_add 9090
# 9092
# replay_buffer_eval_add 9092
# 9094
# replay_buffer_train_add 9094
# 9096
# replay_buffer_train_add 9096
# 9098
# replay_buffer_train_add 9098
# 9100
# replay_buffer_train_add 9100
# 9102
# replay_buffer_train_add 9102
# 9104
# replay_buffer_train_add 9104
# 9106
# replay_buffer_eval_add 9106
# 9108
# replay_buffer_train_add 9108
# 9110
# replay_buffer_train_add 9110
# 9112
# replay_buffer_train_add 9112
# 9114
# replay_buffer_eval_add 9114
# 9116
# replay_buffer_train_add 9116
# 9118
# replay_buffer_eval_add 9118
# 9120
# replay_buffer_train_add 9120
# 9122
# replay_buffer_train_add 9122
# 9124
# replay_buffer_eval_add 9124
# 9126
# replay_buffer_train_add 9126
# 9128
# replay_buffer_eval_add 9128
# 9130
# replay_buffer_train_add 9130
# 9132
# replay_buffer_train_add 9132
# 9134
# replay_buffer_train_add 9134
# 9136
# replay_buffer_train_add 9136
# 9138
# replay_buffer_train_add 9138
# 9140
# replay_buffer_train_add 9140
# 9142
# replay_buffer_train_add 9142
# 9144
# replay_buffer_train_add 9144
# 9146
# replay_buffer_train_add 9146
# 9148
# replay_buffer_eval_add 9148
# 9150
# replay_buffer_train_add 9150
# 9152
# replay_buffer_eval_add 9152
# 9154
# replay_buffer_train_add 9154
# 9156
# replay_buffer_train_add 9156
# 9158
# replay_buffer_train_add 9158
# 9160
# replay_buffer_train_add 9160
# 9162
# replay_buffer_train_add 9162
# 9164
# replay_buffer_train_add 9164
# 9166
# replay_buffer_train_add 9166
# 9168
# replay_buffer_train_add 9168
# 9170
# replay_buffer_train_add 9170
# 9172
# replay_buffer_eval_add 9172
# 9174
# replay_buffer_train_add 9174
# 9176
# replay_buffer_train_add 9176
# 9178
# replay_buffer_train_add 9178
# 9180
# replay_buffer_train_add 9180
# 9182
# replay_buffer_train_add 9182
# 9184
# replay_buffer_train_add 9184
# 9186
# replay_buffer_train_add 9186
# 9188
# replay_buffer_train_add 9188
# 9190
# replay_buffer_eval_add 9190
# 9192
# replay_buffer_train_add 9192
# 9194
# replay_buffer_train_add 9194
# 9196
# replay_buffer_train_add 9196
# 9198
# replay_buffer_train_add 9198
# 9200
# replay_buffer_train_add 9200
# 9202
# replay_buffer_train_add 9202
# 9204
# replay_buffer_train_add 9204
# 9206
# replay_buffer_train_add 9206
# 9208
# replay_buffer_train_add 9208
# 9210
# replay_buffer_train_add 9210
# 9212
# replay_buffer_train_add 9212
# 9214
# replay_buffer_train_add 9214
# 9216
# replay_buffer_train_add 9216
# 9218
# replay_buffer_train_add 9218
# 9220
# replay_buffer_eval_add 9220
# 9222
# replay_buffer_train_add 9222
# 9224
# replay_buffer_eval_add 9224
# 9226
# replay_buffer_train_add 9226
# 9228
# replay_buffer_eval_add 9228
# 9230
# replay_buffer_train_add 9230
# 9232
# replay_buffer_train_add 9232
# 9234
# replay_buffer_train_add 9234
# 9236
# replay_buffer_train_add 9236
# 9238
# replay_buffer_train_add 9238
# 9240
# replay_buffer_train_add 9240
# 9242
# replay_buffer_eval_add 9242
# 9244
# replay_buffer_train_add 9244
# 9246
# replay_buffer_train_add 9246
# 9248
# replay_buffer_train_add 9248
# 9250
# replay_buffer_train_add 9250
# 9252
# replay_buffer_eval_add 9252
# 9254
# replay_buffer_eval_add 9254
# 9256
# replay_buffer_train_add 9256
# 9258
# replay_buffer_train_add 9258
# 9260
# replay_buffer_train_add 9260
# 9262
# replay_buffer_train_add 9262
# 9264
# replay_buffer_train_add 9264
# 9266
# replay_buffer_train_add 9266
# 9268
# replay_buffer_train_add 9268
# 9270
# replay_buffer_train_add 9270
# 9272
# replay_buffer_train_add 9272
# 9274
# replay_buffer_train_add 9274
# 9276
# replay_buffer_train_add 9276
# 9278
# replay_buffer_train_add 9278
# 9280
# replay_buffer_eval_add 9280
# 9282
# replay_buffer_eval_add 9282
# 9284
# replay_buffer_train_add 9284
# 9286
# replay_buffer_train_add 9286
# 9288
# replay_buffer_train_add 9288
# 9290
# replay_buffer_train_add 9290
# 9292
# replay_buffer_train_add 9292
# 9294
# replay_buffer_train_add 9294
# 9296
# replay_buffer_train_add 9296
# 9298
# replay_buffer_train_add 9298
# 9300
# replay_buffer_eval_add 9300
# 9302
# replay_buffer_train_add 9302
# 9304
# replay_buffer_train_add 9304
# 9306
# replay_buffer_train_add 9306
# 9308
# replay_buffer_train_add 9308
# 9310
# replay_buffer_eval_add 9310
# 9312
# replay_buffer_train_add 9312
# 9314
# replay_buffer_train_add 9314
# 9316
# replay_buffer_eval_add 9316
# 9318
# replay_buffer_train_add 9318
# 9320
# replay_buffer_train_add 9320
# 9322
# replay_buffer_train_add 9322
# 9324
# replay_buffer_train_add 9324
# 9326
# replay_buffer_eval_add 9326
# 9328
# replay_buffer_train_add 9328
# 9330
# replay_buffer_train_add 9330
# 9332
# replay_buffer_train_add 9332
# 9334
# replay_buffer_eval_add 9334
# 9336
# replay_buffer_train_add 9336
# 9338
# replay_buffer_train_add 9338
# 9340
# replay_buffer_eval_add 9340
# 9342
# replay_buffer_train_add 9342
# 9344
# replay_buffer_train_add 9344
# 9346
# replay_buffer_train_add 9346
# 9348
# replay_buffer_train_add 9348
# 9350
# replay_buffer_train_add 9350
# 9352
# replay_buffer_train_add 9352
# 9354
# replay_buffer_train_add 9354
# 9356
# replay_buffer_train_add 9356
# 9358
# replay_buffer_train_add 9358
# 9360
# replay_buffer_train_add 9360
# 9362
# replay_buffer_eval_add 9362
# 9364
# replay_buffer_train_add 9364
# 9366
# replay_buffer_train_add 9366
# 9368
# replay_buffer_train_add 9368
# 9370
# replay_buffer_train_add 9370
# 9372
# replay_buffer_eval_add 9372
# 9374
# replay_buffer_train_add 9374
# 9376
# replay_buffer_train_add 9376
# 9378
# replay_buffer_eval_add 9378
# 9380
# replay_buffer_train_add 9380
# 9382
# replay_buffer_train_add 9382
# 9384
# replay_buffer_train_add 9384
# 9386
# replay_buffer_train_add 9386
# 9388
# replay_buffer_train_add 9388
# 9390
# replay_buffer_eval_add 9390
# 9392
# replay_buffer_train_add 9392
# 9394
# replay_buffer_train_add 9394
# 9396
# replay_buffer_train_add 9396
# 9398
# replay_buffer_train_add 9398
# 9400
# replay_buffer_train_add 9400
# 9402
# replay_buffer_train_add 9402
# 9404
# replay_buffer_train_add 9404
# 9406
# replay_buffer_train_add 9406
# 9408
# replay_buffer_train_add 9408
# 9410
# replay_buffer_train_add 9410
# 9412
# replay_buffer_train_add 9412
# 9414
# replay_buffer_eval_add 9414
# 9416
# replay_buffer_train_add 9416
# 9418
# replay_buffer_train_add 9418
# 9420
# replay_buffer_train_add 9420
# 9422
# replay_buffer_train_add 9422
# 9424
# replay_buffer_eval_add 9424
# 9426
# replay_buffer_train_add 9426
# 9428
# replay_buffer_train_add 9428
# 9430
# replay_buffer_train_add 9430
# 9432
# replay_buffer_train_add 9432
# 9434
# replay_buffer_train_add 9434
# 9436
# replay_buffer_eval_add 9436
# 9438
# replay_buffer_train_add 9438
# 9440
# replay_buffer_train_add 9440
# 9442
# replay_buffer_train_add 9442
# 9444
# replay_buffer_train_add 9444
# 9446
# replay_buffer_train_add 9446
# 9448
# replay_buffer_eval_add 9448
# 9450
# replay_buffer_train_add 9450
# 9452
# replay_buffer_train_add 9452
# 9454
# replay_buffer_train_add 9454
# 9456
# replay_buffer_train_add 9456
# 9458
# replay_buffer_train_add 9458
# 9460
# replay_buffer_eval_add 9460
# 9462
# replay_buffer_eval_add 9462
# 9464
# replay_buffer_eval_add 9464
# 9466
# replay_buffer_train_add 9466
# 9468
# replay_buffer_train_add 9468
# 9470
# replay_buffer_eval_add 9470
# 9472
# replay_buffer_eval_add 9472
# 9474
# replay_buffer_train_add 9474
# 9476
# replay_buffer_train_add 9476
# 9478
# replay_buffer_train_add 9478
# 9480
# replay_buffer_eval_add 9480
# 9482
# replay_buffer_train_add 9482
# 9484
# replay_buffer_train_add 9484
# 9486
# replay_buffer_train_add 9486
# 9488
# replay_buffer_eval_add 9488
# 9490
# replay_buffer_train_add 9490
# 9492
# replay_buffer_train_add 9492
# 9494
# replay_buffer_train_add 9494
# 9496
# replay_buffer_train_add 9496
# 9498
# replay_buffer_train_add 9498
# 9500
# replay_buffer_train_add 9500
# 9502
# replay_buffer_eval_add 9502
# 9504
# replay_buffer_train_add 9504
# 9506
# replay_buffer_train_add 9506
# 9508
# replay_buffer_train_add 9508
# 9510
# replay_buffer_train_add 9510
# 9512
# replay_buffer_train_add 9512
# 9514
# replay_buffer_train_add 9514
# 9516
# replay_buffer_eval_add 9516
# 9518
# replay_buffer_eval_add 9518
# 9520
# replay_buffer_eval_add 9520
# 9522
# replay_buffer_eval_add 9522
# 9524
# replay_buffer_eval_add 9524
# 9526
# replay_buffer_train_add 9526
# 9528
# replay_buffer_train_add 9528
# 9530
# replay_buffer_eval_add 9530
# 9532
# replay_buffer_train_add 9532
# 9534
# replay_buffer_train_add 9534
# 9536
# replay_buffer_eval_add 9536
# 9538
# replay_buffer_train_add 9538
# 9540
# replay_buffer_eval_add 9540
# 9542
# replay_buffer_eval_add 9542
# 9544
# replay_buffer_train_add 9544
# 9546
# replay_buffer_train_add 9546
# 9548
# replay_buffer_train_add 9548
# 9550
# replay_buffer_eval_add 9550
# 9552
# replay_buffer_train_add 9552
# 9554
# replay_buffer_eval_add 9554
# 9556
# replay_buffer_train_add 9556
# 9558
# replay_buffer_eval_add 9558
# 9560
# replay_buffer_train_add 9560
# 9562
# replay_buffer_train_add 9562
# 9564
# replay_buffer_eval_add 9564
# 9566
# replay_buffer_train_add 9566
# 9568
# replay_buffer_train_add 9568
# 9570
# replay_buffer_eval_add 9570
# 9572
# replay_buffer_train_add 9572
# 9574
# replay_buffer_train_add 9574
# 9576
# replay_buffer_train_add 9576
# 9578
# replay_buffer_train_add 9578
# 9580
# replay_buffer_train_add 9580
# 9582
# replay_buffer_train_add 9582
# 9584
# replay_buffer_train_add 9584
# 9586
# replay_buffer_train_add 9586
# 9588
# replay_buffer_train_add 9588
# 9590
# replay_buffer_train_add 9590
# 9592
# replay_buffer_train_add 9592
# 9594
# replay_buffer_train_add 9594
# 9596
# replay_buffer_train_add 9596
# 9598
# replay_buffer_train_add 9598
# 9600
# replay_buffer_train_add 9600
# 9602
# replay_buffer_train_add 9602
# 9604
# replay_buffer_train_add 9604
# 9606
# replay_buffer_eval_add 9606
# 9608
# replay_buffer_train_add 9608
# 9610
# replay_buffer_train_add 9610
# 9612
# replay_buffer_train_add 9612
# 9614
# replay_buffer_train_add 9614
# 9616
# replay_buffer_train_add 9616
# 9618
# replay_buffer_eval_add 9618
# 9620
# replay_buffer_train_add 9620
# 9622
# replay_buffer_train_add 9622
# 9624
# replay_buffer_train_add 9624
# 9626
# replay_buffer_train_add 9626
# 9628
# replay_buffer_train_add 9628
# 9630
# replay_buffer_train_add 9630
# 9632
# replay_buffer_eval_add 9632
# 9634
# replay_buffer_train_add 9634
# 9636
# replay_buffer_train_add 9636
# 9638
# replay_buffer_train_add 9638
# 9640
# replay_buffer_train_add 9640
# 9642
# replay_buffer_train_add 9642
# 9644
# replay_buffer_train_add 9644
# 9646
# replay_buffer_train_add 9646
# 9648
# replay_buffer_train_add 9648
# 9650
# replay_buffer_eval_add 9650
# 9652
# replay_buffer_eval_add 9652
# 9654
# replay_buffer_eval_add 9654
# 9656
# replay_buffer_train_add 9656
# 9658
# replay_buffer_train_add 9658
# 9660
# replay_buffer_train_add 9660
# 9662
# replay_buffer_eval_add 9662
# 9664
# replay_buffer_train_add 9664
# 9666
# replay_buffer_train_add 9666
# 9668
# replay_buffer_train_add 9668
# 9670
# replay_buffer_train_add 9670
# 9672
# replay_buffer_train_add 9672
# 9674
# replay_buffer_train_add 9674
# 9676
# replay_buffer_train_add 9676
# 9678
# replay_buffer_train_add 9678
# 9680
# replay_buffer_train_add 9680
# 9682
# replay_buffer_train_add 9682
# 9684
# replay_buffer_train_add 9684
# 9686
# replay_buffer_train_add 9686
# 9688
# replay_buffer_eval_add 9688
# 9690
# replay_buffer_train_add 9690
# 9692
# replay_buffer_train_add 9692
# 9694
# replay_buffer_train_add 9694
# 9696
# replay_buffer_eval_add 9696
# 9698
# replay_buffer_train_add 9698
# 9700
# replay_buffer_train_add 9700
# 9702
# replay_buffer_train_add 9702
# 9704
# replay_buffer_train_add 9704
# 9706
# replay_buffer_train_add 9706
# 9708
# replay_buffer_train_add 9708
# 9710
# replay_buffer_train_add 9710
# 9712
# replay_buffer_train_add 9712
# 9714
# replay_buffer_train_add 9714
# 9716
# replay_buffer_train_add 9716
# 9718
# replay_buffer_train_add 9718
# 9720
# replay_buffer_train_add 9720
# 9722
# replay_buffer_train_add 9722
# 9724
# replay_buffer_train_add 9724
# 9726
# replay_buffer_train_add 9726
# 9728
# replay_buffer_train_add 9728
# 9730
# replay_buffer_train_add 9730
# 9732
# replay_buffer_train_add 9732
# 9734
# replay_buffer_eval_add 9734
# 9736
# replay_buffer_eval_add 9736
# 9738
# replay_buffer_train_add 9738
# 9740
# replay_buffer_train_add 9740
# 9742
# replay_buffer_train_add 9742
# 9744
# replay_buffer_train_add 9744
# 9746
# replay_buffer_eval_add 9746
# 9748
# replay_buffer_eval_add 9748
# 9750
# replay_buffer_train_add 9750
# 9752
# replay_buffer_train_add 9752
# 9754
# replay_buffer_train_add 9754
# 9756
# replay_buffer_train_add 9756
# 9758
# replay_buffer_train_add 9758
# 9760
# replay_buffer_train_add 9760
# 9762
# replay_buffer_train_add 9762
# 9764
# replay_buffer_train_add 9764
# 9766
# replay_buffer_train_add 9766
# 9768
# replay_buffer_train_add 9768
# 9770
# replay_buffer_train_add 9770
# 9772
# replay_buffer_train_add 9772
# 9774
# replay_buffer_train_add 9774
# 9776
# replay_buffer_train_add 9776
# 9778
# replay_buffer_train_add 9778
# 9780
# replay_buffer_train_add 9780
# 9782
# replay_buffer_eval_add 9782
# 9784
# replay_buffer_train_add 9784
# 9786
# replay_buffer_eval_add 9786
# 9788
# replay_buffer_eval_add 9788
# 9790
# replay_buffer_train_add 9790
# 9792
# replay_buffer_train_add 9792
# 9794
# replay_buffer_train_add 9794
# 9796
# replay_buffer_train_add 9796
# 9798
# replay_buffer_train_add 9798
# 9800
# replay_buffer_train_add 9800
# 9802
# replay_buffer_train_add 9802
# 9804
# replay_buffer_train_add 9804
# 9806
# replay_buffer_eval_add 9806
# 9808
# replay_buffer_train_add 9808
# 9810
# replay_buffer_train_add 9810
# 9812
# replay_buffer_train_add 9812
# 9814
# replay_buffer_train_add 9814
# 9816
# replay_buffer_eval_add 9816
# 9818
# replay_buffer_train_add 9818
# 9820
# replay_buffer_train_add 9820
# 9822
# replay_buffer_train_add 9822
# 9824
# replay_buffer_train_add 9824
# 9826
# replay_buffer_train_add 9826
# 9828
# replay_buffer_train_add 9828
# 9830
# replay_buffer_train_add 9830
# 9832
# replay_buffer_train_add 9832
# 9834
# replay_buffer_train_add 9834
# 9836
# replay_buffer_train_add 9836
# 9838
# replay_buffer_eval_add 9838
# 9840
# replay_buffer_train_add 9840
# 9842
# replay_buffer_train_add 9842
# 9844
# replay_buffer_train_add 9844
# 9846
# replay_buffer_train_add 9846
# 9848
# replay_buffer_eval_add 9848
# 9850
# replay_buffer_train_add 9850
# 9852
# replay_buffer_train_add 9852
# 9854
# replay_buffer_train_add 9854
# 9856
# replay_buffer_train_add 9856
# 9858
# replay_buffer_train_add 9858
# 9860
# replay_buffer_train_add 9860
# 9862
# replay_buffer_train_add 9862
# 9864
# replay_buffer_train_add 9864
# 9866
# replay_buffer_train_add 9866
# 9868
# replay_buffer_train_add 9868
# 9870
# replay_buffer_train_add 9870
# 9872
# replay_buffer_train_add 9872
# 9874
# replay_buffer_train_add 9874
# 9876
# replay_buffer_train_add 9876
# 9878
# replay_buffer_eval_add 9878
# 9880
# replay_buffer_train_add 9880
# 9882
# replay_buffer_train_add 9882
# 9884
# replay_buffer_train_add 9884
# 9886
# replay_buffer_train_add 9886
# 9888
# replay_buffer_train_add 9888
# 9890
# replay_buffer_train_add 9890
# 9892
# replay_buffer_train_add 9892
# 9894
# replay_buffer_eval_add 9894
# 9896
# replay_buffer_train_add 9896
# 9898
# replay_buffer_train_add 9898
# 9900
# replay_buffer_train_add 9900
# 9902
# replay_buffer_train_add 9902
# 9904
# replay_buffer_train_add 9904
# 9906
# replay_buffer_train_add 9906
# 9908
# replay_buffer_train_add 9908
# 9910
# replay_buffer_train_add 9910
# 9912
# replay_buffer_train_add 9912
# 9914
# replay_buffer_train_add 9914
# 9916
# replay_buffer_train_add 9916
# 9918
# replay_buffer_train_add 9918
# 9920
# replay_buffer_train_add 9920
# 9922
# replay_buffer_eval_add 9922
# 9924
# replay_buffer_train_add 9924
# 9926
# replay_buffer_train_add 9926
# 9928
# replay_buffer_train_add 9928
# 9930
# replay_buffer_train_add 9930
# 9932
# replay_buffer_train_add 9932
# 9934
# replay_buffer_eval_add 9934
# 9936
# replay_buffer_train_add 9936
# 9938
# replay_buffer_train_add 9938
# 9940
# replay_buffer_train_add 9940
# 9942
# replay_buffer_train_add 9942
# 9944
# replay_buffer_train_add 9944
# 9946
# replay_buffer_train_add 9946
# 9948
# replay_buffer_train_add 9948
# 9950
# replay_buffer_train_add 9950
# 9952
# replay_buffer_train_add 9952

# %%
# # 训练集
# for t in range(len(data_train[:-1])):
#     state = data[t][0:-4]
#     action = data[t][-2]
#     next_state = data[t+1][0:-4]
#     reward = data[t+1][-3]
#     done = data[t][-1]
#     replay_buffer_train.add(state, action, next_state, reward, done)
# # 验证集
# for t in range(len(data_eval[:-1])):
#     state = data[t][0:-4]
#     action = data[t][-2]
#     next_state = data[t+1][0:-4]
#     reward = data[t+1][-3]
#     done = data[t][-1]
#     replay_buffer_eval.add(state, action, next_state, reward, done)

# %%
buffer_name = "replay_buffer_change_1_8"
replay_buffer_train.save(f"./buffers/{buffer_name}_train")
replay_buffer_eval.save(f"./buffers/{buffer_name}_eval")
