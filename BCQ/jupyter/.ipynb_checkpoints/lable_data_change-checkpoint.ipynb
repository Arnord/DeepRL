# %%
import numpy as np
import os
import random
import pandas as pd
import datetime
import math
from math import e
import datetime
from scipy.interpolate import interp1d
import time, datetime
from pandas.core.frame import DataFrame
from db_models import GmsMonitor

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('df_thickener1_20220522_01.csv')
df
# Out:
#                   time     feed_c      out_c      feed_f       out_f  \
# 0      2021/6/24 22:45   7.062875  65.524767    0.570965  120.045326
# 1      2021/6/24 22:50   9.820479  65.541320  153.008470  120.580674
# 2      2021/6/24 22:55   8.771818  64.324850  594.833913  128.955535
# 3      2021/6/24 23:00   5.454403  64.658912    0.569209  115.166352
# 4      2021/6/24 23:05   4.459571  64.014458    0.575706  117.597771
# ...                ...        ...        ...         ...         ...
# 10695    2022/5/7 9:50  33.020739  59.366599  601.963274  146.562356
# 10696    2022/5/7 9:55  29.091299  60.463238  679.524404  136.653616
# 10697   2022/5/7 10:00  26.692466  59.308527  601.825201  157.848585
# 10698   2022/5/7 10:05  28.122638  59.329402  612.676073  148.789828
# 10699   2022/5/7 10:10  28.742416  60.005657  700.122260  138.264618
#
#         pressure  out_f_setting  out_c_setting    reward     error  sum_error  \
# ...

# %%
df['sum_error'] = df['error']
df
# Out:
#                   time     feed_c      out_c      feed_f       out_f  \
# 0      2021/6/24 22:45   7.062875  65.524767    0.570965  120.045326
# 1      2021/6/24 22:50   9.820479  65.541320  153.008470  120.580674
# 2      2021/6/24 22:55   8.771818  64.324850  594.833913  128.955535
# 3      2021/6/24 23:00   5.454403  64.658912    0.569209  115.166352
# 4      2021/6/24 23:05   4.459571  64.014458    0.575706  117.597771
# ...                ...        ...        ...         ...         ...
# 10695    2022/5/7 9:50  33.020739  59.366599  601.963274  146.562356
# 10696    2022/5/7 9:55  29.091299  60.463238  679.524404  136.653616
# 10697   2022/5/7 10:00  26.692466  59.308527  601.825201  157.848585
# 10698   2022/5/7 10:05  28.122638  59.329402  612.676073  148.789828
# 10699   2022/5/7 10:10  28.742416  60.005657  700.122260  138.264618
#
#         pressure  out_f_setting  out_c_setting    reward     error  sum_error  \
# ...

# %%
num = 0
last_done = 0
for i in range(len(df) - 1):
    if i == (len(df)-1):
        break
    # print(i)
    if 300 < (datetime.datetime.strptime(df['time'][i+1], '%Y/%m/%d %H:%M') - datetime.datetime.strptime(df['time'][i], '%Y/%m/%d %H:%M')).seconds:
        #print("time break")
        df['done'][i] = 1
        if num < 15:
            print("df_drop")
            df = df.drop(labels=range(last_done, i))
            df.reset_index(drop=True, inplace=True)
            # print(df)
            last_done = last_done
        else:
            last_done = i 
        num = 0
    else:
        df['sum_error'][i+1] = df['error'][i+1] + 0.7 * df['sum_error'][i]
        if df['sum_error'][i+1] > 50:
            df['sum_error'][i+1] = 50
        elif df['sum_error'][i+1] < -50:
            df['sum_error'][i+1] = -50
        num = num + 1
# Out:
# <ipython-input-20-b4602ede2920>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sum_error'][i+1] = df['error'][i+1] + 0.7 * df['sum_error'][i]
# <ipython-input-20-b4602ede2920>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['done'][i] = 1
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# df_drop
# ...

# %%
df
# Out:
#                  time     feed_c      out_c      feed_f       out_f  \
# 0     2021/6/24 22:45   7.062875  65.524767    0.570965  120.045326
# 1     2021/6/24 22:50   9.820479  65.541320  153.008470  120.580674
# 2     2021/6/24 22:55   8.771818  64.324850  594.833913  128.955535
# 3     2021/6/24 23:00   5.454403  64.658912    0.569209  115.166352
# 4     2021/6/24 23:05   4.459571  64.014458    0.575706  117.597771
# ...               ...        ...        ...         ...         ...
# 9950    2022/5/7 9:50  33.020739  59.366599  601.963274  146.562356
# 9951    2022/5/7 9:55  29.091299  60.463238  679.524404  136.653616
# 9952   2022/5/7 10:00  26.692466  59.308527  601.825201  157.848585
# 9953   2022/5/7 10:05  28.122638  59.329402  612.676073  148.789828
# 9954   2022/5/7 10:10  28.742416  60.005657  700.122260  138.264618
#
#        pressure  out_f_setting  out_c_setting    reward     error  sum_error  \
# ...

# %%
df.to_csv("df_thickener1_20220522_change.csv", index=False)
