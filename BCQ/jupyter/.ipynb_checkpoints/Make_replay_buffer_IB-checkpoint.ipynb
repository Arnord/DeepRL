# %%
import sys
sys.path.append('..')

# %%
import pandas as pd
import random
from continuous_BCQ.utils import ReplayBuffer

# %%
df = pd.read_csv("ibState0_BCQ.csv")

# %%
df['done'] = 0

# %%
df
# Out:
#         delta_v   delta_g   delta_h      p          v           g          h  \
# 0     -0.528512  0.657879  0.902812  100.0  49.471488   56.578786  55.192556
# 1     -0.698547  0.357628 -0.177676  100.0  48.772941   60.155062  54.170649
# 2     -0.816130  0.136517 -0.922066  100.0  47.956811   61.520228  48.867353
# 3     -0.305609  0.829644  0.590679  100.0  47.651202   69.816664  52.264662
# 4      0.224603 -0.277716  0.813354  100.0  47.875805   67.039504  56.942698
# ...         ...       ...       ...    ...        ...         ...        ...
# 99995  0.564367  0.142038 -0.824141  100.0  86.750579  100.000000  95.259922
# 99996 -0.434084  0.778444  0.008475  100.0  86.316494  100.000000  95.308668
# 99997  0.332032  0.441999  0.716492  100.0  86.648527  100.000000  99.429594
# 99998  0.762518 -0.714038 -0.126149  100.0  87.411044   92.859624  98.704046
# 99999 -0.989316  0.865104 -0.371051  100.0  86.421728  100.000000  96.569933
#
#                f            c         cost       reward  done
# 0      19.364891   199.897349   257.992024  -257.992024     0
# 1      17.866010   199.861386   253.459417  -253.459417     0
# 2      17.671323   193.614719   246.628690  -246.628690     0
# 3      14.095990   193.122027   235.409995  -235.409995     0
# 4      20.874034   195.085466   257.707568  -257.707568     0
# ...          ...          ...          ...          ...   ...
# 99995   0.000000  2834.603971  2834.603971 -2834.603971     0
# 99996   0.000000  2824.775183  2824.775183 -2824.775183     0
# 99997   0.000000  2942.391141  2942.391141 -2942.391141     0
# 99998   0.000000  2976.522713  2976.522713 -2976.522713     0
# 99999   0.000000  2951.559049  2951.559049 -2951.559049     0
#
# [100000 rows x 12 columns]

# %%
#"name": ["feed_c", "out_c", "feed_f", "out_f", "out_f_setting", "pressure", "reward"]

# %%
df_1 = df

# %%
df_1
# Out:
#         delta_v   delta_g   delta_h      p          v           g          h  \
# 0     -0.528512  0.657879  0.902812  100.0  49.471488   56.578786  55.192556
# 1     -0.698547  0.357628 -0.177676  100.0  48.772941   60.155062  54.170649
# 2     -0.816130  0.136517 -0.922066  100.0  47.956811   61.520228  48.867353
# 3     -0.305609  0.829644  0.590679  100.0  47.651202   69.816664  52.264662
# 4      0.224603 -0.277716  0.813354  100.0  47.875805   67.039504  56.942698
# ...         ...       ...       ...    ...        ...         ...        ...
# 99995  0.564367  0.142038 -0.824141  100.0  86.750579  100.000000  95.259922
# 99996 -0.434084  0.778444  0.008475  100.0  86.316494  100.000000  95.308668
# 99997  0.332032  0.441999  0.716492  100.0  86.648527  100.000000  99.429594
# 99998  0.762518 -0.714038 -0.126149  100.0  87.411044   92.859624  98.704046
# 99999 -0.989316  0.865104 -0.371051  100.0  86.421728  100.000000  96.569933
#
#                f            c         cost       reward  done
# 0      19.364891   199.897349   257.992024  -257.992024     0
# 1      17.866010   199.861386   253.459417  -253.459417     0
# 2      17.671323   193.614719   246.628690  -246.628690     0
# 3      14.095990   193.122027   235.409995  -235.409995     0
# 4      20.874034   195.085466   257.707568  -257.707568     0
# ...          ...          ...          ...          ...   ...
# 99995   0.000000  2834.603971  2834.603971 -2834.603971     0
# 99996   0.000000  2824.775183  2824.775183 -2824.775183     0
# 99997   0.000000  2942.391141  2942.391141 -2942.391141     0
# 99998   0.000000  2976.522713  2976.522713 -2976.522713     0
# 99999   0.000000  2951.559049  2951.559049 -2951.559049     0
#
# [100000 rows x 12 columns]

# %% [markdown]
# ## 标准化

# %%
df_zscore = df_1.copy()
df_zscores = (df_zscore - df_zscore.mean()) / df_zscore.std()
df_zscores['done'] = 0
df_zscores['p'] = 0
df_zscores
# df_zscores = df_zscores.drop(df_zscores.index[-1])
# Out:
#         delta_v   delta_g   delta_h  p         v         g         h  \
# 0     -0.913138  1.133570  1.563799  0  0.493552  0.156572  0.100227
# 1     -1.207712  0.613823 -0.311679  0  0.468203  0.272560  0.065234
# 2     -1.411418  0.231071 -1.603770  0  0.438587  0.316836 -0.116366
# 3     -0.526971  1.430903  1.022007  0  0.427498  0.585910 -0.000032
# 4      0.391588 -0.485983  1.408521  0  0.435648  0.495840  0.160157
# ...         ...       ...       ... ..       ...       ...       ...
# 99995  0.980209  0.240629 -1.433795  0  1.846335  1.564834  1.472253
# 99996 -0.749548  1.342273  0.011436  0  1.830583  1.564834  1.473922
# 99997  0.577703  0.759873  1.240390  0  1.842632  1.564834  1.615035
# 99998  1.323493 -1.241274 -0.222240  0  1.870302  1.333254  1.590190
# 99999 -1.711453  1.492287 -0.647334  0  1.834402  1.564834  1.517112
#
#               f         c      cost    reward  done
# 0     -0.801515 -0.265491 -0.574955  0.574955     0
# 1     -0.824579 -0.265550 -0.583126  0.583126     0
# 2     -0.827574 -0.275746 -0.595440  0.595440     0
# 3     -0.882588 -0.276550 -0.615665  0.615665     0
# 4     -0.778294 -0.273345 -0.575468  0.575468     0
# ...         ...       ...       ...       ...   ...
# 99995 -1.099482  4.034799  4.070016 -4.070016     0
# 99996 -1.099482  4.018757  4.052297 -4.052297     0
# 99997 -1.099482  4.210726  4.264328 -4.264328     0
# 99998 -1.099482  4.266435  4.325859 -4.325859     0
# 99999 -1.099482  4.225690  4.280856 -4.280856     0
#
# [100000 rows x 12 columns]

# %% [markdown]
# ## 数据集两两绑定（state和next_state）

# %%
df_zscores_single = [x for x in range(0, len(df_zscores), 2)]
len(df_zscores_single)
# Out:
# 50000

# %% [markdown]
# ## 划分验证集和训练集（差集）-------两两绑定

# %%
df_zscores_single_eval = random.sample(df_zscores_single, 12500)

# %%
len(df_zscores_single_eval)
# Out:
# 12500

# %%
df_zscores_single_train = list(set(df_zscores_single) - set(df_zscores_single_eval))

# %%
len(df_zscores_single_train)
# Out:
# 37500

# %%
data = df_zscores.values

# %%
print(data[0])
data[0][0:3]
# Out:
# [-0.91313793  1.13357046  1.56379925  0.          0.49355201  0.15657169
#   0.1002274  -0.8015153  -0.26549136 -0.574955    0.574955    0.        ]
# array([-0.91313793,  1.13357046,  1.56379925])

# %%
state_dim = 6
action_dim = 3

# %%
replay_buffer_train = ReplayBuffer(state_dim, action_dim, device="cpu")
replay_buffer_eval = ReplayBuffer(state_dim, action_dim ,device="cpu")

# %%
for t in range(0, len(data), 2):
    print(t)
    if t in df_zscores_single_train:
        state = data[t][3:-3]
        action = data[t][0:3]
        next_state = data[t+1][3:-3]
        reward = data[t+1][-2]
        done = data[t+1][-1]
        replay_buffer_train.add(state, action, next_state, reward, done)
        print("replay_buffer_train_add", t)
    elif t in df_zscores_single_eval:
        state = data[t][3:-3]
        action = data[t][0:3]
        next_state = data[t+1][3:-3]
        reward = data[t+1][-2]
        done = data[t+1][-1]
        replay_buffer_eval.add(state, action, next_state, reward, done)
        print("replay_buffer_eval_add", t)
    else:
        pass
# Out:
# 0
# replay_buffer_eval_add 0
# 2
# replay_buffer_train_add 2
# 4
# replay_buffer_train_add 4
# 6
# replay_buffer_train_add 6
# 8
# replay_buffer_train_add 8
# 10
# replay_buffer_train_add 10
# 12
# replay_buffer_train_add 12
# 14
# replay_buffer_eval_add 14
# 16
# replay_buffer_eval_add 16
# 18
# replay_buffer_train_add 18
# 20
# replay_buffer_train_add 20
# 22
# replay_buffer_train_add 22
# 24
# replay_buffer_eval_add 24
# 26
# replay_buffer_train_add 26
# 28
# replay_buffer_eval_add 28
# 30
# replay_buffer_train_add 30
# 32
# replay_buffer_train_add 32
# 34
# replay_buffer_train_add 34
# 36
# replay_buffer_eval_add 36
# 38
# replay_buffer_train_add 38
# 40
# replay_buffer_train_add 40
# 42
# replay_buffer_train_add 42
# 44
# replay_buffer_train_add 44
# 46
# replay_buffer_eval_add 46
# 48
# replay_buffer_train_add 48
# 50
# replay_buffer_train_add 50
# 52
# replay_buffer_train_add 52
# 54
# replay_buffer_train_add 54
# 56
# replay_buffer_train_add 56
# 58
# replay_buffer_eval_add 58
# 60
# replay_buffer_train_add 60
# 62
# replay_buffer_train_add 62
# 64
# replay_buffer_train_add 64
# 66
# replay_buffer_train_add 66
# 68
# replay_buffer_train_add 68
# 70
# replay_buffer_train_add 70
# 72
# replay_buffer_train_add 72
# 74
# replay_buffer_eval_add 74
# 76
# replay_buffer_train_add 76
# 78
# replay_buffer_train_add 78
# 80
# replay_buffer_eval_add 80
# 82
# replay_buffer_train_add 82
# 84
# replay_buffer_eval_add 84
# 86
# replay_buffer_train_add 86
# 88
# replay_buffer_train_add 88
# 90
# replay_buffer_train_add 90
# 92
# replay_buffer_train_add 92
# 94
# replay_buffer_train_add 94
# 96
# replay_buffer_train_add 96
# 98
# replay_buffer_train_add 98
# 100
# replay_buffer_train_add 100
# 102
# replay_buffer_train_add 102
# 104
# replay_buffer_train_add 104
# 106
# replay_buffer_train_add 106
# 108
# replay_buffer_train_add 108
# 110
# replay_buffer_train_add 110
# 112
# replay_buffer_train_add 112
# 114
# replay_buffer_train_add 114
# 116
# replay_buffer_train_add 116
# 118
# replay_buffer_train_add 118
# 120
# replay_buffer_train_add 120
# 122
# replay_buffer_train_add 122
# 124
# replay_buffer_train_add 124
# 126
# replay_buffer_train_add 126
# 128
# replay_buffer_train_add 128
# 130
# replay_buffer_train_add 130
# 132
# replay_buffer_train_add 132
# 134
# replay_buffer_eval_add 134
# 136
# replay_buffer_eval_add 136
# 138
# replay_buffer_train_add 138
# 140
# replay_buffer_train_add 140
# 142
# replay_buffer_train_add 142
# 144
# replay_buffer_eval_add 144
# 146
# replay_buffer_train_add 146
# 148
# replay_buffer_train_add 148
# 150
# replay_buffer_train_add 150
# 152
# replay_buffer_train_add 152
# 154
# replay_buffer_eval_add 154
# 156
# replay_buffer_train_add 156
# 158
# replay_buffer_train_add 158
# 160
# replay_buffer_train_add 160
# 162
# replay_buffer_train_add 162
# 164
# replay_buffer_train_add 164
# 166
# replay_buffer_train_add 166
# 168
# replay_buffer_train_add 168
# 170
# replay_buffer_train_add 170
# 172
# replay_buffer_train_add 172
# 174
# replay_buffer_train_add 174
# 176
# replay_buffer_train_add 176
# 178
# replay_buffer_train_add 178
# 180
# replay_buffer_train_add 180
# 182
# replay_buffer_train_add 182
# 184
# replay_buffer_train_add 184
# 186
# replay_buffer_eval_add 186
# 188
# replay_buffer_train_add 188
# 190
# replay_buffer_train_add 190
# 192
# replay_buffer_train_add 192
# 194
# replay_buffer_eval_add 194
# 196
# replay_buffer_train_add 196
# 198
# replay_buffer_train_add 198
# 200
# replay_buffer_train_add 200
# 202
# replay_buffer_train_add 202
# 204
# replay_buffer_train_add 204
# 206
# replay_buffer_train_add 206
# 208
# replay_buffer_train_add 208
# 210
# replay_buffer_train_add 210
# 212
# replay_buffer_train_add 212
# 214
# replay_buffer_train_add 214
# 216
# replay_buffer_train_add 216
# 218
# replay_buffer_train_add 218
# 220
# replay_buffer_train_add 220
# 222
# replay_buffer_train_add 222
# 224
# replay_buffer_eval_add 224
# 226
# replay_buffer_train_add 226
# 228
# replay_buffer_eval_add 228
# 230
# replay_buffer_eval_add 230
# 232
# replay_buffer_train_add 232
# 234
# replay_buffer_train_add 234
# 236
# replay_buffer_eval_add 236
# 238
# replay_buffer_train_add 238
# 240
# replay_buffer_train_add 240
# 242
# replay_buffer_train_add 242
# 244
# replay_buffer_train_add 244
# 246
# replay_buffer_eval_add 246
# 248
# replay_buffer_eval_add 248
# 250
# replay_buffer_train_add 250
# 252
# replay_buffer_eval_add 252
# 254
# replay_buffer_train_add 254
# 256
# replay_buffer_train_add 256
# 258
# replay_buffer_train_add 258
# 260
# replay_buffer_eval_add 260
# 262
# replay_buffer_train_add 262
# 264
# replay_buffer_eval_add 264
# 266
# replay_buffer_train_add 266
# 268
# replay_buffer_eval_add 268
# 270
# replay_buffer_train_add 270
# 272
# replay_buffer_train_add 272
# 274
# replay_buffer_train_add 274
# 276
# replay_buffer_train_add 276
# 278
# replay_buffer_train_add 278
# 280
# replay_buffer_eval_add 280
# 282
# replay_buffer_eval_add 282
# 284
# replay_buffer_train_add 284
# 286
# replay_buffer_train_add 286
# 288
# replay_buffer_train_add 288
# 290
# replay_buffer_train_add 290
# 292
# replay_buffer_train_add 292
# 294
# replay_buffer_train_add 294
# 296
# replay_buffer_train_add 296
# 298
# replay_buffer_train_add 298
# 300
# replay_buffer_train_add 300
# 302
# replay_buffer_train_add 302
# 304
# replay_buffer_train_add 304
# 306
# replay_buffer_eval_add 306
# 308
# replay_buffer_eval_add 308
# 310
# replay_buffer_eval_add 310
# 312
# replay_buffer_train_add 312
# 314
# replay_buffer_eval_add 314
# 316
# replay_buffer_train_add 316
# 318
# replay_buffer_eval_add 318
# 320
# replay_buffer_train_add 320
# 322
# replay_buffer_train_add 322
# 324
# replay_buffer_eval_add 324
# 326
# replay_buffer_eval_add 326
# 328
# replay_buffer_train_add 328
# 330
# replay_buffer_train_add 330
# 332
# replay_buffer_train_add 332
# 334
# replay_buffer_eval_add 334
# 336
# replay_buffer_eval_add 336
# 338
# replay_buffer_train_add 338
# 340
# replay_buffer_eval_add 340
# 342
# replay_buffer_train_add 342
# 344
# replay_buffer_train_add 344
# 346
# replay_buffer_eval_add 346
# 348
# replay_buffer_train_add 348
# 350
# replay_buffer_train_add 350
# 352
# replay_buffer_train_add 352
# 354
# replay_buffer_train_add 354
# 356
# replay_buffer_train_add 356
# 358
# replay_buffer_train_add 358
# 360
# replay_buffer_train_add 360
# 362
# replay_buffer_eval_add 362
# 364
# replay_buffer_train_add 364
# 366
# replay_buffer_eval_add 366
# 368
# replay_buffer_eval_add 368
# 370
# replay_buffer_train_add 370
# 372
# replay_buffer_eval_add 372
# 374
# replay_buffer_eval_add 374
# 376
# replay_buffer_eval_add 376
# 378
# replay_buffer_train_add 378
# 380
# replay_buffer_train_add 380
# 382
# replay_buffer_train_add 382
# 384
# replay_buffer_train_add 384
# 386
# replay_buffer_train_add 386
# 388
# replay_buffer_train_add 388
# 390
# replay_buffer_eval_add 390
# 392
# replay_buffer_train_add 392
# 394
# replay_buffer_eval_add 394
# 396
# replay_buffer_eval_add 396
# 398
# replay_buffer_eval_add 398
# 400
# replay_buffer_train_add 400
# 402
# replay_buffer_train_add 402
# 404
# replay_buffer_eval_add 404
# 406
# replay_buffer_train_add 406
# 408
# replay_buffer_train_add 408
# 410
# replay_buffer_train_add 410
# 412
# replay_buffer_train_add 412
# 414
# replay_buffer_train_add 414
# 416
# replay_buffer_eval_add 416
# 418
# replay_buffer_train_add 418
# 420
# replay_buffer_train_add 420
# 422
# replay_buffer_train_add 422
# 424
# replay_buffer_eval_add 424
# 426
# replay_buffer_eval_add 426
# 428
# replay_buffer_train_add 428
# 430
# replay_buffer_train_add 430
# 432
# replay_buffer_eval_add 432
# 434
# replay_buffer_train_add 434
# 436
# replay_buffer_train_add 436
# 438
# replay_buffer_train_add 438
# 440
# replay_buffer_train_add 440
# 442
# replay_buffer_train_add 442
# 444
# replay_buffer_train_add 444
# 446
# replay_buffer_train_add 446
# 448
# replay_buffer_train_add 448
# 450
# replay_buffer_eval_add 450
# 452
# replay_buffer_train_add 452
# 454
# replay_buffer_eval_add 454
# 456
# replay_buffer_eval_add 456
# 458
# replay_buffer_train_add 458
# 460
# replay_buffer_eval_add 460
# 462
# replay_buffer_train_add 462
# 464
# replay_buffer_train_add 464
# 466
# replay_buffer_train_add 466
# 468
# replay_buffer_train_add 468
# 470
# replay_buffer_eval_add 470
# 472
# replay_buffer_train_add 472
# 474
# replay_buffer_train_add 474
# 476
# replay_buffer_eval_add 476
# 478
# replay_buffer_train_add 478
# 480
# replay_buffer_eval_add 480
# 482
# replay_buffer_train_add 482
# 484
# replay_buffer_eval_add 484
# 486
# replay_buffer_eval_add 486
# 488
# replay_buffer_eval_add 488
# 490
# replay_buffer_train_add 490
# 492
# replay_buffer_eval_add 492
# 494
# replay_buffer_train_add 494
# 496
# replay_buffer_train_add 496
# 498
# replay_buffer_eval_add 498
# 500
# replay_buffer_train_add 500
# 502
# replay_buffer_eval_add 502
# 504
# replay_buffer_train_add 504
# 506
# replay_buffer_eval_add 506
# 508
# replay_buffer_eval_add 508
# 510
# replay_buffer_train_add 510
# 512
# replay_buffer_eval_add 512
# 514
# replay_buffer_eval_add 514
# 516
# replay_buffer_train_add 516
# 518
# replay_buffer_eval_add 518
# 520
# replay_buffer_train_add 520
# 522
# replay_buffer_eval_add 522
# 524
# replay_buffer_train_add 524
# 526
# replay_buffer_eval_add 526
# 528
# replay_buffer_train_add 528
# 530
# replay_buffer_eval_add 530
# 532
# replay_buffer_train_add 532
# 534
# replay_buffer_train_add 534
# 536
# replay_buffer_train_add 536
# 538
# replay_buffer_train_add 538
# 540
# replay_buffer_eval_add 540
# 542
# replay_buffer_train_add 542
# 544
# replay_buffer_train_add 544
# 546
# replay_buffer_train_add 546
# 548
# replay_buffer_train_add 548
# 550
# replay_buffer_train_add 550
# 552
# replay_buffer_train_add 552
# 554
# replay_buffer_train_add 554
# 556
# replay_buffer_train_add 556
# 558
# replay_buffer_train_add 558
# 560
# replay_buffer_train_add 560
# 562
# replay_buffer_eval_add 562
# 564
# replay_buffer_eval_add 564
# 566
# replay_buffer_eval_add 566
# 568
# replay_buffer_train_add 568
# 570
# replay_buffer_train_add 570
# 572
# replay_buffer_train_add 572
# 574
# replay_buffer_train_add 574
# 576
# replay_buffer_train_add 576
# 578
# replay_buffer_train_add 578
# 580
# replay_buffer_train_add 580
# 582
# replay_buffer_train_add 582
# 584
# replay_buffer_train_add 584
# 586
# replay_buffer_train_add 586
# 588
# replay_buffer_eval_add 588
# 590
# replay_buffer_train_add 590
# 592
# replay_buffer_eval_add 592
# 594
# replay_buffer_train_add 594
# 596
# replay_buffer_eval_add 596
# 598
# replay_buffer_train_add 598
# 600
# replay_buffer_train_add 600
# 602
# replay_buffer_train_add 602
# 604
# replay_buffer_train_add 604
# 606
# replay_buffer_train_add 606
# 608
# replay_buffer_train_add 608
# 610
# replay_buffer_eval_add 610
# 612
# replay_buffer_eval_add 612
# 614
# replay_buffer_train_add 614
# 616
# replay_buffer_train_add 616
# 618
# replay_buffer_train_add 618
# 620
# replay_buffer_eval_add 620
# 622
# replay_buffer_train_add 622
# 624
# replay_buffer_train_add 624
# 626
# replay_buffer_eval_add 626
# 628
# replay_buffer_train_add 628
# 630
# replay_buffer_train_add 630
# 632
# replay_buffer_train_add 632
# 634
# replay_buffer_train_add 634
# 636
# replay_buffer_eval_add 636
# 638
# replay_buffer_train_add 638
# 640
# replay_buffer_train_add 640
# 642
# replay_buffer_train_add 642
# 644
# replay_buffer_eval_add 644
# 646
# replay_buffer_train_add 646
# 648
# replay_buffer_eval_add 648
# 650
# replay_buffer_eval_add 650
# 652
# replay_buffer_train_add 652
# 654
# replay_buffer_train_add 654
# 656
# replay_buffer_train_add 656
# 658
# replay_buffer_train_add 658
# 660
# replay_buffer_train_add 660
# 662
# replay_buffer_train_add 662
# 664
# replay_buffer_train_add 664
# 666
# replay_buffer_eval_add 666
# 668
# replay_buffer_eval_add 668
# 670
# replay_buffer_train_add 670
# 672
# replay_buffer_train_add 672
# 674
# replay_buffer_train_add 674
# 676
# replay_buffer_eval_add 676
# 678
# replay_buffer_eval_add 678
# 680
# replay_buffer_train_add 680
# 682
# replay_buffer_train_add 682
# 684
# replay_buffer_train_add 684
# 686
# replay_buffer_train_add 686
# 688
# replay_buffer_train_add 688
# 690
# replay_buffer_train_add 690
# 692
# replay_buffer_train_add 692
# 694
# replay_buffer_train_add 694
# 696
# replay_buffer_eval_add 696
# 698
# replay_buffer_train_add 698
# 700
# replay_buffer_train_add 700
# 702
# replay_buffer_train_add 702
# 704
# replay_buffer_train_add 704
# 706
# replay_buffer_train_add 706
# 708
# replay_buffer_train_add 708
# 710
# replay_buffer_train_add 710
# 712
# replay_buffer_train_add 712
# 714
# replay_buffer_train_add 714
# 716
# replay_buffer_train_add 716
# 718
# replay_buffer_train_add 718
# 720
# replay_buffer_train_add 720
# 722
# replay_buffer_train_add 722
# 724
# replay_buffer_train_add 724
# 726
# replay_buffer_train_add 726
# 728
# replay_buffer_train_add 728
# 730
# replay_buffer_train_add 730
# 732
# replay_buffer_train_add 732
# 734
# replay_buffer_train_add 734
# 736
# replay_buffer_eval_add 736
# 738
# replay_buffer_eval_add 738
# 740
# replay_buffer_eval_add 740
# 742
# replay_buffer_train_add 742
# 744
# replay_buffer_eval_add 744
# 746
# replay_buffer_train_add 746
# 748
# replay_buffer_train_add 748
# 750
# replay_buffer_train_add 750
# 752
# replay_buffer_train_add 752
# 754
# replay_buffer_eval_add 754
# 756
# replay_buffer_train_add 756
# 758
# replay_buffer_train_add 758
# 760
# replay_buffer_train_add 760
# 762
# replay_buffer_train_add 762
# 764
# replay_buffer_train_add 764
# 766
# replay_buffer_eval_add 766
# 768
# replay_buffer_train_add 768
# 770
# replay_buffer_train_add 770
# 772
# replay_buffer_eval_add 772
# 774
# replay_buffer_train_add 774
# 776
# replay_buffer_eval_add 776
# 778
# replay_buffer_train_add 778
# 780
# replay_buffer_train_add 780
# 782
# replay_buffer_train_add 782
# 784
# replay_buffer_eval_add 784
# 786
# replay_buffer_train_add 786
# 788
# replay_buffer_train_add 788
# 790
# replay_buffer_eval_add 790
# 792
# replay_buffer_train_add 792
# 794
# replay_buffer_train_add 794
# 796
# replay_buffer_eval_add 796
# 798
# replay_buffer_train_add 798
# 800
# replay_buffer_eval_add 800
# 802
# replay_buffer_train_add 802
# 804
# replay_buffer_train_add 804
# 806
# replay_buffer_train_add 806
# 808
# replay_buffer_train_add 808
# 810
# replay_buffer_train_add 810
# 812
# replay_buffer_train_add 812
# 814
# replay_buffer_train_add 814
# 816
# replay_buffer_eval_add 816
# 818
# replay_buffer_eval_add 818
# 820
# replay_buffer_train_add 820
# 822
# replay_buffer_train_add 822
# 824
# replay_buffer_eval_add 824
# 826
# replay_buffer_eval_add 826
# 828
# replay_buffer_train_add 828
# 830
# replay_buffer_train_add 830
# 832
# replay_buffer_train_add 832
# 834
# replay_buffer_train_add 834
# 836
# replay_buffer_train_add 836
# 838
# replay_buffer_train_add 838
# 840
# replay_buffer_train_add 840
# 842
# replay_buffer_train_add 842
# 844
# replay_buffer_train_add 844
# 846
# replay_buffer_train_add 846
# 848
# replay_buffer_train_add 848
# 850
# replay_buffer_train_add 850
# 852
# replay_buffer_train_add 852
# 854
# replay_buffer_eval_add 854
# 856
# replay_buffer_train_add 856
# 858
# replay_buffer_train_add 858
# 860
# replay_buffer_eval_add 860
# 862
# replay_buffer_train_add 862
# 864
# replay_buffer_train_add 864
# 866
# replay_buffer_eval_add 866
# 868
# replay_buffer_train_add 868
# 870
# replay_buffer_train_add 870
# 872
# replay_buffer_train_add 872
# 874
# replay_buffer_train_add 874
# 876
# replay_buffer_train_add 876
# 878
# replay_buffer_train_add 878
# 880
# replay_buffer_eval_add 880
# 882
# replay_buffer_train_add 882
# 884
# replay_buffer_train_add 884
# 886
# replay_buffer_train_add 886
# 888
# replay_buffer_eval_add 888
# 890
# replay_buffer_train_add 890
# 892
# replay_buffer_train_add 892
# 894
# replay_buffer_train_add 894
# 896
# replay_buffer_eval_add 896
# 898
# replay_buffer_train_add 898
# 900
# replay_buffer_train_add 900
# 902
# replay_buffer_eval_add 902
# 904
# replay_buffer_train_add 904
# 906
# replay_buffer_train_add 906
# 908
# replay_buffer_train_add 908
# 910
# replay_buffer_train_add 910
# 912
# replay_buffer_train_add 912
# 914
# replay_buffer_train_add 914
# 916
# replay_buffer_train_add 916
# 918
# replay_buffer_train_add 918
# 920
# replay_buffer_eval_add 920
# 922
# replay_buffer_train_add 922
# 924
# replay_buffer_eval_add 924
# 926
# replay_buffer_eval_add 926
# 928
# replay_buffer_eval_add 928
# 930
# replay_buffer_train_add 930
# 932
# replay_buffer_train_add 932
# 934
# replay_buffer_train_add 934
# 936
# replay_buffer_eval_add 936
# 938
# replay_buffer_train_add 938
# 940
# replay_buffer_train_add 940
# 942
# replay_buffer_eval_add 942
# 944
# replay_buffer_train_add 944
# 946
# replay_buffer_train_add 946
# 948
# replay_buffer_train_add 948
# 950
# replay_buffer_train_add 950
# 952
# replay_buffer_train_add 952
# 954
# replay_buffer_train_add 954
# 956
# replay_buffer_train_add 956
# 958
# replay_buffer_train_add 958
# 960
# replay_buffer_eval_add 960
# 962
# replay_buffer_train_add 962
# 964
# replay_buffer_train_add 964
# 966
# replay_buffer_train_add 966
# 968
# replay_buffer_train_add 968
# 970
# replay_buffer_train_add 970
# 972
# replay_buffer_train_add 972
# 974
# replay_buffer_train_add 974
# 976
# replay_buffer_train_add 976
# 978
# replay_buffer_eval_add 978
# 980
# replay_buffer_eval_add 980
# 982
# replay_buffer_train_add 982
# 984
# replay_buffer_eval_add 984
# 986
# replay_buffer_eval_add 986
# 988
# replay_buffer_train_add 988
# 990
# replay_buffer_train_add 990
# 992
# replay_buffer_train_add 992
# 994
# replay_buffer_train_add 994
# 996
# replay_buffer_train_add 996
# 998
# replay_buffer_eval_add 998
# 1000
# replay_buffer_eval_add 1000
# 1002
# replay_buffer_train_add 1002
# 1004
# replay_buffer_train_add 1004
# 1006
# replay_buffer_train_add 1006
# 1008
# replay_buffer_train_add 1008
# 1010
# replay_buffer_eval_add 1010
# 1012
# replay_buffer_train_add 1012
# 1014
# replay_buffer_train_add 1014
# 1016
# replay_buffer_eval_add 1016
# 1018
# replay_buffer_train_add 1018
# 1020
# replay_buffer_train_add 1020
# 1022
# replay_buffer_train_add 1022
# 1024
# replay_buffer_train_add 1024
# 1026
# replay_buffer_eval_add 1026
# 1028
# replay_buffer_train_add 1028
# 1030
# replay_buffer_eval_add 1030
# 1032
# replay_buffer_eval_add 1032
# 1034
# replay_buffer_train_add 1034
# 1036
# replay_buffer_train_add 1036
# 1038
# replay_buffer_train_add 1038
# 1040
# replay_buffer_train_add 1040
# 1042
# replay_buffer_train_add 1042
# 1044
# replay_buffer_train_add 1044
# 1046
# replay_buffer_eval_add 1046
# 1048
# replay_buffer_eval_add 1048
# 1050
# replay_buffer_train_add 1050
# 1052
# replay_buffer_eval_add 1052
# 1054
# replay_buffer_train_add 1054
# 1056
# replay_buffer_train_add 1056
# 1058
# replay_buffer_train_add 1058
# 1060
# replay_buffer_train_add 1060
# 1062
# replay_buffer_train_add 1062
# 1064
# replay_buffer_train_add 1064
# 1066
# replay_buffer_train_add 1066
# 1068
# replay_buffer_train_add 1068
# 1070
# replay_buffer_train_add 1070
# 1072
# replay_buffer_eval_add 1072
# 1074
# replay_buffer_train_add 1074
# 1076
# replay_buffer_train_add 1076
# 1078
# replay_buffer_train_add 1078
# 1080
# replay_buffer_train_add 1080
# 1082
# replay_buffer_train_add 1082
# 1084
# replay_buffer_eval_add 1084
# 1086
# replay_buffer_train_add 1086
# 1088
# replay_buffer_train_add 1088
# 1090
# replay_buffer_train_add 1090
# 1092
# replay_buffer_train_add 1092
# 1094
# replay_buffer_eval_add 1094
# 1096
# replay_buffer_train_add 1096
# 1098
# replay_buffer_train_add 1098
# 1100
# replay_buffer_eval_add 1100
# 1102
# replay_buffer_eval_add 1102
# 1104
# replay_buffer_train_add 1104
# 1106
# replay_buffer_train_add 1106
# 1108
# replay_buffer_eval_add 1108
# 1110
# replay_buffer_eval_add 1110
# 1112
# replay_buffer_train_add 1112
# 1114
# replay_buffer_train_add 1114
# 1116
# replay_buffer_eval_add 1116
# 1118
# replay_buffer_train_add 1118
# 1120
# replay_buffer_train_add 1120
# 1122
# replay_buffer_train_add 1122
# 1124
# replay_buffer_train_add 1124
# 1126
# replay_buffer_train_add 1126
# 1128
# replay_buffer_eval_add 1128
# 1130
# replay_buffer_train_add 1130
# 1132
# replay_buffer_train_add 1132
# 1134
# replay_buffer_train_add 1134
# 1136
# replay_buffer_train_add 1136
# 1138
# replay_buffer_train_add 1138
# 1140
# replay_buffer_train_add 1140
# 1142
# replay_buffer_train_add 1142
# 1144
# replay_buffer_train_add 1144
# 1146
# replay_buffer_eval_add 1146
# 1148
# replay_buffer_train_add 1148
# 1150
# replay_buffer_eval_add 1150
# 1152
# replay_buffer_eval_add 1152
# 1154
# replay_buffer_eval_add 1154
# 1156
# replay_buffer_train_add 1156
# 1158
# replay_buffer_train_add 1158
# 1160
# replay_buffer_eval_add 1160
# 1162
# replay_buffer_eval_add 1162
# 1164
# replay_buffer_train_add 1164
# 1166
# replay_buffer_train_add 1166
# 1168
# replay_buffer_train_add 1168
# 1170
# replay_buffer_eval_add 1170
# 1172
# replay_buffer_train_add 1172
# 1174
# replay_buffer_eval_add 1174
# 1176
# replay_buffer_train_add 1176
# 1178
# replay_buffer_train_add 1178
# 1180
# replay_buffer_train_add 1180
# 1182
# replay_buffer_train_add 1182
# 1184
# replay_buffer_train_add 1184
# 1186
# replay_buffer_train_add 1186
# 1188
# replay_buffer_eval_add 1188
# 1190
# replay_buffer_eval_add 1190
# 1192
# replay_buffer_train_add 1192
# 1194
# replay_buffer_eval_add 1194
# 1196
# replay_buffer_train_add 1196
# 1198
# replay_buffer_eval_add 1198
# 1200
# replay_buffer_train_add 1200
# 1202
# replay_buffer_train_add 1202
# 1204
# replay_buffer_train_add 1204
# 1206
# replay_buffer_train_add 1206
# 1208
# replay_buffer_train_add 1208
# 1210
# replay_buffer_train_add 1210
# 1212
# replay_buffer_eval_add 1212
# 1214
# replay_buffer_train_add 1214
# 1216
# replay_buffer_train_add 1216
# 1218
# replay_buffer_train_add 1218
# 1220
# replay_buffer_eval_add 1220
# 1222
# replay_buffer_train_add 1222
# 1224
# replay_buffer_train_add 1224
# 1226
# replay_buffer_train_add 1226
# 1228
# replay_buffer_train_add 1228
# 1230
# replay_buffer_train_add 1230
# 1232
# replay_buffer_train_add 1232
# 1234
# replay_buffer_eval_add 1234
# 1236
# replay_buffer_train_add 1236
# 1238
# replay_buffer_train_add 1238
# 1240
# replay_buffer_eval_add 1240
# 1242
# replay_buffer_train_add 1242
# 1244
# replay_buffer_train_add 1244
# 1246
# replay_buffer_train_add 1246
# 1248
# replay_buffer_train_add 1248
# 1250
# replay_buffer_eval_add 1250
# 1252
# replay_buffer_eval_add 1252
# 1254
# replay_buffer_eval_add 1254
# 1256
# replay_buffer_eval_add 1256
# 1258
# replay_buffer_train_add 1258
# 1260
# replay_buffer_train_add 1260
# 1262
# replay_buffer_train_add 1262
# 1264
# replay_buffer_eval_add 1264
# 1266
# replay_buffer_train_add 1266
# 1268
# replay_buffer_eval_add 1268
# 1270
# replay_buffer_train_add 1270
# 1272
# replay_buffer_train_add 1272
# 1274
# replay_buffer_train_add 1274
# 1276
# replay_buffer_eval_add 1276
# 1278
# replay_buffer_train_add 1278
# 1280
# replay_buffer_eval_add 1280
# 1282
# replay_buffer_train_add 1282
# 1284
# replay_buffer_train_add 1284
# 1286
# replay_buffer_train_add 1286
# 1288
# replay_buffer_train_add 1288
# 1290
# replay_buffer_train_add 1290
# 1292
# replay_buffer_eval_add 1292
# 1294
# replay_buffer_train_add 1294
# 1296
# replay_buffer_train_add 1296
# 1298
# replay_buffer_train_add 1298
# 1300
# replay_buffer_train_add 1300
# 1302
# replay_buffer_train_add 1302
# 1304
# replay_buffer_train_add 1304
# 1306
# replay_buffer_train_add 1306
# 1308
# replay_buffer_eval_add 1308
# 1310
# replay_buffer_train_add 1310
# 1312
# replay_buffer_eval_add 1312
# 1314
# replay_buffer_train_add 1314
# 1316
# replay_buffer_train_add 1316
# 1318
# replay_buffer_train_add 1318
# 1320
# replay_buffer_train_add 1320
# 1322
# replay_buffer_eval_add 1322
# 1324
# replay_buffer_train_add 1324
# 1326
# replay_buffer_train_add 1326
# 1328
# replay_buffer_train_add 1328
# 1330
# replay_buffer_eval_add 1330
# 1332
# replay_buffer_train_add 1332
# 1334
# replay_buffer_eval_add 1334
# 1336
# replay_buffer_train_add 1336
# 1338
# replay_buffer_train_add 1338
# 1340
# replay_buffer_eval_add 1340
# 1342
# replay_buffer_eval_add 1342
# 1344
# replay_buffer_eval_add 1344
# 1346
# replay_buffer_train_add 1346
# 1348
# replay_buffer_eval_add 1348
# 1350
# replay_buffer_eval_add 1350
# 1352
# replay_buffer_train_add 1352
# 1354
# replay_buffer_train_add 1354
# 1356
# replay_buffer_eval_add 1356
# 1358
# replay_buffer_eval_add 1358
# 1360
# replay_buffer_train_add 1360
# 1362
# replay_buffer_train_add 1362
# 1364
# replay_buffer_train_add 1364
# 1366
# replay_buffer_eval_add 1366
# 1368
# replay_buffer_train_add 1368
# 1370
# replay_buffer_train_add 1370
# 1372
# replay_buffer_train_add 1372
# 1374
# replay_buffer_train_add 1374
# 1376
# replay_buffer_train_add 1376
# 1378
# replay_buffer_eval_add 1378
# 1380
# replay_buffer_train_add 1380
# 1382
# replay_buffer_train_add 1382
# 1384
# replay_buffer_train_add 1384
# 1386
# replay_buffer_train_add 1386
# 1388
# replay_buffer_eval_add 1388
# 1390
# replay_buffer_train_add 1390
# 1392
# replay_buffer_train_add 1392
# 1394
# replay_buffer_train_add 1394
# 1396
# replay_buffer_train_add 1396
# 1398
# replay_buffer_eval_add 1398
# 1400
# replay_buffer_train_add 1400
# 1402
# replay_buffer_train_add 1402
# 1404
# replay_buffer_train_add 1404
# 1406
# replay_buffer_train_add 1406
# 1408
# replay_buffer_train_add 1408
# 1410
# replay_buffer_train_add 1410
# 1412
# replay_buffer_eval_add 1412
# 1414
# replay_buffer_train_add 1414
# 1416
# replay_buffer_train_add 1416
# 1418
# replay_buffer_train_add 1418
# 1420
# replay_buffer_train_add 1420
# 1422
# replay_buffer_eval_add 1422
# 1424
# replay_buffer_train_add 1424
# 1426
# replay_buffer_train_add 1426
# 1428
# replay_buffer_eval_add 1428
# 1430
# replay_buffer_train_add 1430
# 1432
# replay_buffer_train_add 1432
# 1434
# replay_buffer_train_add 1434
# 1436
# replay_buffer_train_add 1436
# 1438
# replay_buffer_eval_add 1438
# 1440
# replay_buffer_train_add 1440
# 1442
# replay_buffer_train_add 1442
# 1444
# replay_buffer_train_add 1444
# 1446
# replay_buffer_train_add 1446
# 1448
# replay_buffer_eval_add 1448
# 1450
# replay_buffer_train_add 1450
# 1452
# replay_buffer_train_add 1452
# 1454
# replay_buffer_train_add 1454
# 1456
# replay_buffer_eval_add 1456
# 1458
# replay_buffer_eval_add 1458
# 1460
# replay_buffer_eval_add 1460
# 1462
# replay_buffer_train_add 1462
# 1464
# replay_buffer_train_add 1464
# 1466
# replay_buffer_eval_add 1466
# 1468
# replay_buffer_train_add 1468
# 1470
# replay_buffer_train_add 1470
# 1472
# replay_buffer_train_add 1472
# 1474
# replay_buffer_train_add 1474
# 1476
# replay_buffer_eval_add 1476
# 1478
# replay_buffer_train_add 1478
# 1480
# replay_buffer_train_add 1480
# 1482
# replay_buffer_train_add 1482
# 1484
# replay_buffer_train_add 1484
# 1486
# replay_buffer_train_add 1486
# 1488
# replay_buffer_train_add 1488
# 1490
# replay_buffer_train_add 1490
# 1492
# replay_buffer_train_add 1492
# 1494
# replay_buffer_eval_add 1494
# 1496
# replay_buffer_eval_add 1496
# 1498
# replay_buffer_train_add 1498
# 1500
# replay_buffer_train_add 1500
# 1502
# replay_buffer_eval_add 1502
# 1504
# replay_buffer_eval_add 1504
# 1506
# replay_buffer_train_add 1506
# 1508
# replay_buffer_train_add 1508
# 1510
# replay_buffer_train_add 1510
# 1512
# replay_buffer_train_add 1512
# 1514
# replay_buffer_train_add 1514
# 1516
# replay_buffer_eval_add 1516
# 1518
# replay_buffer_train_add 1518
# 1520
# replay_buffer_train_add 1520
# 1522
# replay_buffer_eval_add 1522
# 1524
# replay_buffer_train_add 1524
# 1526
# replay_buffer_eval_add 1526
# 1528
# replay_buffer_train_add 1528
# 1530
# replay_buffer_eval_add 1530
# 1532
# replay_buffer_train_add 1532
# 1534
# replay_buffer_train_add 1534
# 1536
# replay_buffer_train_add 1536
# 1538
# replay_buffer_train_add 1538
# 1540
# replay_buffer_train_add 1540
# 1542
# replay_buffer_train_add 1542
# 1544
# replay_buffer_train_add 1544
# 1546
# replay_buffer_train_add 1546
# 1548
# replay_buffer_train_add 1548
# 1550
# replay_buffer_train_add 1550
# 1552
# replay_buffer_train_add 1552
# 1554
# replay_buffer_train_add 1554
# 1556
# replay_buffer_train_add 1556
# 1558
# replay_buffer_train_add 1558
# 1560
# replay_buffer_train_add 1560
# 1562
# replay_buffer_train_add 1562
# 1564
# replay_buffer_eval_add 1564
# 1566
# replay_buffer_train_add 1566
# 1568
# replay_buffer_train_add 1568
# 1570
# replay_buffer_eval_add 1570
# 1572
# replay_buffer_eval_add 1572
# 1574
# replay_buffer_eval_add 1574
# 1576
# replay_buffer_train_add 1576
# 1578
# replay_buffer_train_add 1578
# 1580
# replay_buffer_train_add 1580
# 1582
# replay_buffer_eval_add 1582
# 1584
# replay_buffer_train_add 1584
# 1586
# replay_buffer_train_add 1586
# 1588
# replay_buffer_eval_add 1588
# 1590
# replay_buffer_train_add 1590
# 1592
# replay_buffer_train_add 1592
# 1594
# replay_buffer_train_add 1594
# 1596
# replay_buffer_train_add 1596
# 1598
# replay_buffer_train_add 1598
# 1600
# replay_buffer_train_add 1600
# 1602
# replay_buffer_train_add 1602
# 1604
# replay_buffer_train_add 1604
# 1606
# replay_buffer_eval_add 1606
# 1608
# replay_buffer_train_add 1608
# 1610
# replay_buffer_train_add 1610
# 1612
# replay_buffer_train_add 1612
# 1614
# replay_buffer_eval_add 1614
# 1616
# replay_buffer_train_add 1616
# 1618
# replay_buffer_train_add 1618
# 1620
# replay_buffer_train_add 1620
# 1622
# replay_buffer_eval_add 1622
# 1624
# replay_buffer_train_add 1624
# 1626
# replay_buffer_train_add 1626
# 1628
# replay_buffer_train_add 1628
# 1630
# replay_buffer_train_add 1630
# 1632
# replay_buffer_train_add 1632
# 1634
# replay_buffer_train_add 1634
# 1636
# replay_buffer_train_add 1636
# 1638
# replay_buffer_train_add 1638
# 1640
# replay_buffer_train_add 1640
# 1642
# replay_buffer_eval_add 1642
# 1644
# replay_buffer_train_add 1644
# 1646
# replay_buffer_train_add 1646
# 1648
# replay_buffer_train_add 1648
# 1650
# replay_buffer_train_add 1650
# 1652
# replay_buffer_train_add 1652
# 1654
# replay_buffer_train_add 1654
# 1656
# replay_buffer_train_add 1656
# 1658
# replay_buffer_train_add 1658
# 1660
# replay_buffer_train_add 1660
# 1662
# replay_buffer_train_add 1662
# 1664
# replay_buffer_train_add 1664
# 1666
# replay_buffer_train_add 1666
# 1668
# replay_buffer_train_add 1668
# 1670
# replay_buffer_train_add 1670
# 1672
# replay_buffer_eval_add 1672
# 1674
# replay_buffer_eval_add 1674
# 1676
# replay_buffer_train_add 1676
# 1678
# replay_buffer_train_add 1678
# 1680
# replay_buffer_train_add 1680
# 1682
# replay_buffer_train_add 1682
# 1684
# replay_buffer_train_add 1684
# 1686
# replay_buffer_train_add 1686
# 1688
# replay_buffer_train_add 1688
# 1690
# replay_buffer_train_add 1690
# 1692
# replay_buffer_eval_add 1692
# 1694
# replay_buffer_train_add 1694
# 1696
# replay_buffer_train_add 1696
# 1698
# replay_buffer_eval_add 1698
# 1700
# replay_buffer_train_add 1700
# 1702
# replay_buffer_eval_add 1702
# 1704
# replay_buffer_train_add 1704
# 1706
# replay_buffer_train_add 1706
# 1708
# replay_buffer_eval_add 1708
# 1710
# replay_buffer_train_add 1710
# 1712
# replay_buffer_train_add 1712
# 1714
# replay_buffer_eval_add 1714
# 1716
# replay_buffer_train_add 1716
# 1718
# replay_buffer_train_add 1718
# 1720
# replay_buffer_train_add 1720
# 1722
# replay_buffer_train_add 1722
# 1724
# replay_buffer_train_add 1724
# 1726
# replay_buffer_train_add 1726
# 1728
# replay_buffer_train_add 1728
# 1730
# replay_buffer_train_add 1730
# 1732
# replay_buffer_train_add 1732
# 1734
# replay_buffer_eval_add 1734
# 1736
# replay_buffer_train_add 1736
# 1738
# replay_buffer_train_add 1738
# 1740
# replay_buffer_train_add 1740
# 1742
# replay_buffer_train_add 1742
# 1744
# replay_buffer_eval_add 1744
# 1746
# replay_buffer_eval_add 1746
# 1748
# replay_buffer_eval_add 1748
# 1750
# replay_buffer_train_add 1750
# 1752
# replay_buffer_train_add 1752
# 1754
# replay_buffer_train_add 1754
# 1756
# replay_buffer_eval_add 1756
# 1758
# replay_buffer_train_add 1758
# 1760
# replay_buffer_train_add 1760
# 1762
# replay_buffer_train_add 1762
# 1764
# replay_buffer_train_add 1764
# 1766
# replay_buffer_train_add 1766
# 1768
# replay_buffer_train_add 1768
# 1770
# replay_buffer_train_add 1770
# 1772
# replay_buffer_train_add 1772
# 1774
# replay_buffer_train_add 1774
# 1776
# replay_buffer_train_add 1776
# 1778
# replay_buffer_train_add 1778
# 1780
# replay_buffer_train_add 1780
# 1782
# replay_buffer_train_add 1782
# 1784
# replay_buffer_train_add 1784
# 1786
# replay_buffer_eval_add 1786
# 1788
# replay_buffer_train_add 1788
# 1790
# replay_buffer_eval_add 1790
# 1792
# replay_buffer_train_add 1792
# 1794
# replay_buffer_train_add 1794
# 1796
# replay_buffer_eval_add 1796
# 1798
# replay_buffer_eval_add 1798
# 1800
# replay_buffer_eval_add 1800
# 1802
# replay_buffer_eval_add 1802
# 1804
# replay_buffer_train_add 1804
# 1806
# replay_buffer_eval_add 1806
# 1808
# replay_buffer_train_add 1808
# 1810
# replay_buffer_eval_add 1810
# 1812
# replay_buffer_train_add 1812
# 1814
# replay_buffer_train_add 1814
# 1816
# replay_buffer_eval_add 1816
# 1818
# replay_buffer_train_add 1818
# 1820
# replay_buffer_train_add 1820
# 1822
# replay_buffer_train_add 1822
# 1824
# replay_buffer_train_add 1824
# 1826
# replay_buffer_train_add 1826
# 1828
# replay_buffer_train_add 1828
# 1830
# replay_buffer_train_add 1830
# 1832
# replay_buffer_train_add 1832
# 1834
# replay_buffer_train_add 1834
# 1836
# replay_buffer_train_add 1836
# 1838
# replay_buffer_eval_add 1838
# 1840
# replay_buffer_train_add 1840
# 1842
# replay_buffer_train_add 1842
# 1844
# replay_buffer_train_add 1844
# 1846
# replay_buffer_train_add 1846
# 1848
# replay_buffer_eval_add 1848
# 1850
# replay_buffer_train_add 1850
# 1852
# replay_buffer_eval_add 1852
# 1854
# replay_buffer_eval_add 1854
# 1856
# replay_buffer_train_add 1856
# 1858
# replay_buffer_train_add 1858
# 1860
# replay_buffer_train_add 1860
# 1862
# replay_buffer_train_add 1862
# 1864
# replay_buffer_eval_add 1864
# 1866
# replay_buffer_train_add 1866
# 1868
# replay_buffer_train_add 1868
# 1870
# replay_buffer_train_add 1870
# 1872
# replay_buffer_train_add 1872
# 1874
# replay_buffer_eval_add 1874
# 1876
# replay_buffer_eval_add 1876
# 1878
# replay_buffer_train_add 1878
# 1880
# replay_buffer_train_add 1880
# 1882
# replay_buffer_train_add 1882
# 1884
# replay_buffer_train_add 1884
# 1886
# replay_buffer_train_add 1886
# 1888
# replay_buffer_train_add 1888
# 1890
# replay_buffer_train_add 1890
# 1892
# replay_buffer_train_add 1892
# 1894
# replay_buffer_train_add 1894
# 1896
# replay_buffer_train_add 1896
# 1898
# replay_buffer_eval_add 1898
# 1900
# replay_buffer_train_add 1900
# 1902
# replay_buffer_eval_add 1902
# 1904
# replay_buffer_train_add 1904
# 1906
# replay_buffer_train_add 1906
# 1908
# replay_buffer_train_add 1908
# 1910
# replay_buffer_train_add 1910
# 1912
# replay_buffer_train_add 1912
# 1914
# replay_buffer_train_add 1914
# 1916
# replay_buffer_train_add 1916
# 1918
# replay_buffer_train_add 1918
# 1920
# replay_buffer_train_add 1920
# 1922
# replay_buffer_eval_add 1922
# 1924
# replay_buffer_train_add 1924
# 1926
# replay_buffer_train_add 1926
# 1928
# replay_buffer_train_add 1928
# 1930
# replay_buffer_train_add 1930
# 1932
# replay_buffer_train_add 1932
# 1934
# replay_buffer_eval_add 1934
# 1936
# replay_buffer_train_add 1936
# 1938
# replay_buffer_eval_add 1938
# 1940
# replay_buffer_eval_add 1940
# 1942
# replay_buffer_train_add 1942
# 1944
# replay_buffer_train_add 1944
# 1946
# replay_buffer_train_add 1946
# 1948
# replay_buffer_train_add 1948
# 1950
# replay_buffer_eval_add 1950
# 1952
# replay_buffer_eval_add 1952
# 1954
# replay_buffer_eval_add 1954
# 1956
# replay_buffer_eval_add 1956
# 1958
# replay_buffer_train_add 1958
# 1960
# replay_buffer_train_add 1960
# 1962
# replay_buffer_eval_add 1962
# 1964
# replay_buffer_train_add 1964
# 1966
# replay_buffer_train_add 1966
# 1968
# replay_buffer_train_add 1968
# 1970
# replay_buffer_train_add 1970
# 1972
# replay_buffer_eval_add 1972
# 1974
# replay_buffer_train_add 1974
# 1976
# replay_buffer_train_add 1976
# 1978
# replay_buffer_eval_add 1978
# 1980
# replay_buffer_train_add 1980
# 1982
# replay_buffer_eval_add 1982
# 1984
# replay_buffer_train_add 1984
# 1986
# replay_buffer_train_add 1986
# 1988
# replay_buffer_eval_add 1988
# 1990
# replay_buffer_train_add 1990
# 1992
# replay_buffer_train_add 1992
# 1994
# replay_buffer_eval_add 1994
# 1996
# replay_buffer_train_add 1996
# 1998
# replay_buffer_train_add 1998
# 2000
# replay_buffer_train_add 2000
# 2002
# replay_buffer_train_add 2002
# 2004
# replay_buffer_train_add 2004
# 2006
# replay_buffer_eval_add 2006
# 2008
# replay_buffer_eval_add 2008
# 2010
# replay_buffer_train_add 2010
# 2012
# replay_buffer_train_add 2012
# 2014
# replay_buffer_train_add 2014
# 2016
# replay_buffer_train_add 2016
# 2018
# replay_buffer_train_add 2018
# 2020
# replay_buffer_train_add 2020
# 2022
# replay_buffer_train_add 2022
# 2024
# replay_buffer_train_add 2024
# 2026
# replay_buffer_eval_add 2026
# 2028
# replay_buffer_train_add 2028
# 2030
# replay_buffer_train_add 2030
# 2032
# replay_buffer_train_add 2032
# 2034
# replay_buffer_train_add 2034
# 2036
# replay_buffer_eval_add 2036
# 2038
# replay_buffer_train_add 2038
# 2040
# replay_buffer_train_add 2040
# 2042
# replay_buffer_train_add 2042
# 2044
# replay_buffer_train_add 2044
# 2046
# replay_buffer_train_add 2046
# 2048
# replay_buffer_train_add 2048
# 2050
# replay_buffer_train_add 2050
# 2052
# replay_buffer_eval_add 2052
# 2054
# replay_buffer_train_add 2054
# 2056
# replay_buffer_train_add 2056
# 2058
# replay_buffer_train_add 2058
# 2060
# replay_buffer_train_add 2060
# 2062
# replay_buffer_train_add 2062
# 2064
# replay_buffer_train_add 2064
# 2066
# replay_buffer_train_add 2066
# 2068
# replay_buffer_eval_add 2068
# 2070
# replay_buffer_train_add 2070
# 2072
# replay_buffer_train_add 2072
# 2074
# replay_buffer_eval_add 2074
# 2076
# replay_buffer_train_add 2076
# 2078
# replay_buffer_eval_add 2078
# 2080
# replay_buffer_train_add 2080
# 2082
# replay_buffer_train_add 2082
# 2084
# replay_buffer_train_add 2084
# 2086
# replay_buffer_eval_add 2086
# 2088
# replay_buffer_train_add 2088
# 2090
# replay_buffer_train_add 2090
# 2092
# replay_buffer_train_add 2092
# 2094
# replay_buffer_eval_add 2094
# 2096
# replay_buffer_eval_add 2096
# 2098
# replay_buffer_train_add 2098
# 2100
# replay_buffer_train_add 2100
# 2102
# replay_buffer_train_add 2102
# 2104
# replay_buffer_train_add 2104
# 2106
# replay_buffer_train_add 2106
# 2108
# replay_buffer_train_add 2108
# 2110
# replay_buffer_train_add 2110
# 2112
# replay_buffer_train_add 2112
# 2114
# replay_buffer_train_add 2114
# 2116
# replay_buffer_train_add 2116
# 2118
# replay_buffer_train_add 2118
# 2120
# replay_buffer_eval_add 2120
# 2122
# replay_buffer_eval_add 2122
# 2124
# replay_buffer_eval_add 2124
# 2126
# replay_buffer_train_add 2126
# 2128
# replay_buffer_eval_add 2128
# 2130
# replay_buffer_eval_add 2130
# 2132
# replay_buffer_train_add 2132
# 2134
# replay_buffer_train_add 2134
# 2136
# replay_buffer_train_add 2136
# 2138
# replay_buffer_train_add 2138
# 2140
# replay_buffer_train_add 2140
# 2142
# replay_buffer_train_add 2142
# 2144
# replay_buffer_train_add 2144
# 2146
# replay_buffer_train_add 2146
# 2148
# replay_buffer_train_add 2148
# 2150
# replay_buffer_train_add 2150
# 2152
# replay_buffer_train_add 2152
# 2154
# replay_buffer_eval_add 2154
# 2156
# replay_buffer_eval_add 2156
# 2158
# replay_buffer_train_add 2158
# 2160
# replay_buffer_train_add 2160
# 2162
# replay_buffer_train_add 2162
# 2164
# replay_buffer_train_add 2164
# 2166
# replay_buffer_train_add 2166
# 2168
# replay_buffer_train_add 2168
# 2170
# replay_buffer_train_add 2170
# 2172
# replay_buffer_train_add 2172
# 2174
# replay_buffer_train_add 2174
# 2176
# replay_buffer_eval_add 2176
# 2178
# replay_buffer_eval_add 2178
# 2180
# replay_buffer_eval_add 2180
# 2182
# replay_buffer_train_add 2182
# 2184
# replay_buffer_eval_add 2184
# 2186
# replay_buffer_train_add 2186
# 2188
# replay_buffer_train_add 2188
# 2190
# replay_buffer_train_add 2190
# 2192
# replay_buffer_train_add 2192
# 2194
# replay_buffer_train_add 2194
# 2196
# replay_buffer_train_add 2196
# 2198
# replay_buffer_train_add 2198
# 2200
# replay_buffer_train_add 2200
# 2202
# replay_buffer_train_add 2202
# 2204
# replay_buffer_train_add 2204
# 2206
# replay_buffer_train_add 2206
# 2208
# replay_buffer_train_add 2208
# 2210
# replay_buffer_train_add 2210
# 2212
# replay_buffer_train_add 2212
# 2214
# replay_buffer_train_add 2214
# 2216
# replay_buffer_train_add 2216
# 2218
# replay_buffer_train_add 2218
# 2220
# replay_buffer_eval_add 2220
# 2222
# replay_buffer_train_add 2222
# 2224
# replay_buffer_eval_add 2224
# 2226
# replay_buffer_eval_add 2226
# 2228
# replay_buffer_train_add 2228
# 2230
# replay_buffer_eval_add 2230
# 2232
# replay_buffer_train_add 2232
# 2234
# replay_buffer_train_add 2234
# 2236
# replay_buffer_train_add 2236
# 2238
# replay_buffer_train_add 2238
# 2240
# replay_buffer_eval_add 2240
# 2242
# replay_buffer_eval_add 2242
# 2244
# replay_buffer_train_add 2244
# 2246
# replay_buffer_train_add 2246
# 2248
# replay_buffer_train_add 2248
# 2250
# replay_buffer_eval_add 2250
# 2252
# replay_buffer_eval_add 2252
# 2254
# replay_buffer_train_add 2254
# 2256
# replay_buffer_train_add 2256
# 2258
# replay_buffer_train_add 2258
# 2260
# replay_buffer_eval_add 2260
# 2262
# replay_buffer_train_add 2262
# 2264
# replay_buffer_train_add 2264
# 2266
# replay_buffer_train_add 2266
# 2268
# replay_buffer_train_add 2268
# 2270
# replay_buffer_train_add 2270
# 2272
# replay_buffer_eval_add 2272
# 2274
# replay_buffer_train_add 2274
# 2276
# replay_buffer_train_add 2276
# 2278
# replay_buffer_train_add 2278
# 2280
# replay_buffer_train_add 2280
# 2282
# replay_buffer_train_add 2282
# 2284
# replay_buffer_train_add 2284
# 2286
# replay_buffer_train_add 2286
# 2288
# replay_buffer_train_add 2288
# 2290
# replay_buffer_eval_add 2290
# 2292
# replay_buffer_train_add 2292
# 2294
# replay_buffer_eval_add 2294
# 2296
# replay_buffer_train_add 2296
# 2298
# replay_buffer_train_add 2298
# 2300
# replay_buffer_train_add 2300
# 2302
# replay_buffer_train_add 2302
# 2304
# replay_buffer_train_add 2304
# 2306
# replay_buffer_train_add 2306
# 2308
# replay_buffer_train_add 2308
# 2310
# replay_buffer_train_add 2310
# 2312
# replay_buffer_train_add 2312
# 2314
# replay_buffer_train_add 2314
# 2316
# replay_buffer_train_add 2316
# 2318
# replay_buffer_train_add 2318
# 2320
# replay_buffer_train_add 2320
# 2322
# replay_buffer_train_add 2322
# 2324
# replay_buffer_train_add 2324
# 2326
# replay_buffer_train_add 2326
# 2328
# replay_buffer_train_add 2328
# 2330
# replay_buffer_eval_add 2330
# 2332
# replay_buffer_train_add 2332
# 2334
# replay_buffer_train_add 2334
# 2336
# replay_buffer_train_add 2336
# 2338
# replay_buffer_eval_add 2338
# 2340
# replay_buffer_train_add 2340
# 2342
# replay_buffer_eval_add 2342
# 2344
# replay_buffer_train_add 2344
# 2346
# replay_buffer_train_add 2346
# 2348
# replay_buffer_eval_add 2348
# 2350
# replay_buffer_train_add 2350
# 2352
# replay_buffer_eval_add 2352
# 2354
# replay_buffer_train_add 2354
# 2356
# replay_buffer_train_add 2356
# 2358
# replay_buffer_eval_add 2358
# 2360
# replay_buffer_train_add 2360
# 2362
# replay_buffer_train_add 2362
# 2364
# replay_buffer_train_add 2364
# 2366
# replay_buffer_train_add 2366
# 2368
# replay_buffer_train_add 2368
# 2370
# replay_buffer_train_add 2370
# 2372
# replay_buffer_eval_add 2372
# 2374
# replay_buffer_eval_add 2374
# 2376
# replay_buffer_eval_add 2376
# 2378
# replay_buffer_eval_add 2378
# 2380
# replay_buffer_eval_add 2380
# 2382
# replay_buffer_train_add 2382
# 2384
# replay_buffer_train_add 2384
# 2386
# replay_buffer_train_add 2386
# 2388
# replay_buffer_eval_add 2388
# 2390
# replay_buffer_eval_add 2390
# 2392
# replay_buffer_train_add 2392
# 2394
# replay_buffer_train_add 2394
# 2396
# replay_buffer_train_add 2396
# 2398
# replay_buffer_train_add 2398
# 2400
# replay_buffer_train_add 2400
# 2402
# replay_buffer_train_add 2402
# 2404
# replay_buffer_train_add 2404
# 2406
# replay_buffer_train_add 2406
# 2408
# replay_buffer_train_add 2408
# 2410
# replay_buffer_train_add 2410
# 2412
# replay_buffer_train_add 2412
# 2414
# replay_buffer_train_add 2414
# 2416
# replay_buffer_train_add 2416
# 2418
# replay_buffer_eval_add 2418
# 2420
# replay_buffer_train_add 2420
# 2422
# replay_buffer_train_add 2422
# 2424
# replay_buffer_train_add 2424
# 2426
# replay_buffer_train_add 2426
# 2428
# replay_buffer_train_add 2428
# 2430
# replay_buffer_train_add 2430
# 2432
# replay_buffer_train_add 2432
# 2434
# replay_buffer_train_add 2434
# 2436
# replay_buffer_eval_add 2436
# 2438
# replay_buffer_train_add 2438
# 2440
# replay_buffer_eval_add 2440
# 2442
# replay_buffer_eval_add 2442
# 2444
# replay_buffer_train_add 2444
# 2446
# replay_buffer_train_add 2446
# 2448
# replay_buffer_eval_add 2448
# 2450
# replay_buffer_train_add 2450
# 2452
# replay_buffer_train_add 2452
# 2454
# replay_buffer_train_add 2454
# 2456
# replay_buffer_train_add 2456
# 2458
# replay_buffer_train_add 2458
# 2460
# replay_buffer_eval_add 2460
# 2462
# replay_buffer_eval_add 2462
# 2464
# replay_buffer_eval_add 2464
# 2466
# replay_buffer_train_add 2466
# 2468
# replay_buffer_eval_add 2468
# 2470
# replay_buffer_train_add 2470
# 2472
# replay_buffer_eval_add 2472
# 2474
# replay_buffer_eval_add 2474
# 2476
# replay_buffer_eval_add 2476
# 2478
# replay_buffer_eval_add 2478
# 2480
# replay_buffer_train_add 2480
# 2482
# replay_buffer_train_add 2482
# 2484
# replay_buffer_train_add 2484
# 2486
# replay_buffer_train_add 2486
# 2488
# replay_buffer_train_add 2488
# 2490
# replay_buffer_train_add 2490
# 2492
# replay_buffer_eval_add 2492
# 2494
# replay_buffer_train_add 2494
# 2496
# replay_buffer_train_add 2496
# 2498
# replay_buffer_train_add 2498
# 2500
# replay_buffer_train_add 2500
# 2502
# replay_buffer_eval_add 2502
# 2504
# replay_buffer_train_add 2504
# 2506
# replay_buffer_eval_add 2506
# 2508
# replay_buffer_eval_add 2508
# 2510
# replay_buffer_eval_add 2510
# 2512
# replay_buffer_train_add 2512
# 2514
# replay_buffer_eval_add 2514
# 2516
# replay_buffer_train_add 2516
# 2518
# replay_buffer_train_add 2518
# 2520
# replay_buffer_train_add 2520
# 2522
# replay_buffer_eval_add 2522
# 2524
# replay_buffer_train_add 2524
# 2526
# replay_buffer_eval_add 2526
# 2528
# replay_buffer_train_add 2528
# 2530
# replay_buffer_train_add 2530
# 2532
# replay_buffer_train_add 2532
# 2534
# replay_buffer_train_add 2534
# 2536
# replay_buffer_train_add 2536
# 2538
# replay_buffer_train_add 2538
# 2540
# replay_buffer_train_add 2540
# 2542
# replay_buffer_eval_add 2542
# 2544
# replay_buffer_eval_add 2544
# 2546
# replay_buffer_train_add 2546
# 2548
# replay_buffer_train_add 2548
# 2550
# replay_buffer_eval_add 2550
# 2552
# replay_buffer_train_add 2552
# 2554
# replay_buffer_train_add 2554
# 2556
# replay_buffer_train_add 2556
# 2558
# replay_buffer_train_add 2558
# 2560
# replay_buffer_train_add 2560
# 2562
# replay_buffer_train_add 2562
# 2564
# replay_buffer_train_add 2564
# 2566
# replay_buffer_train_add 2566
# 2568
# replay_buffer_train_add 2568
# 2570
# replay_buffer_eval_add 2570
# 2572
# replay_buffer_train_add 2572
# 2574
# replay_buffer_train_add 2574
# 2576
# replay_buffer_train_add 2576
# 2578
# replay_buffer_train_add 2578
# 2580
# replay_buffer_train_add 2580
# 2582
# replay_buffer_train_add 2582
# 2584
# replay_buffer_eval_add 2584
# 2586
# replay_buffer_eval_add 2586
# 2588
# replay_buffer_train_add 2588
# 2590
# replay_buffer_train_add 2590
# 2592
# replay_buffer_train_add 2592
# 2594
# replay_buffer_eval_add 2594
# 2596
# replay_buffer_train_add 2596
# 2598
# replay_buffer_train_add 2598
# 2600
# replay_buffer_train_add 2600
# 2602
# replay_buffer_train_add 2602
# 2604
# replay_buffer_train_add 2604
# 2606
# replay_buffer_eval_add 2606
# 2608
# replay_buffer_train_add 2608
# 2610
# replay_buffer_eval_add 2610
# 2612
# replay_buffer_train_add 2612
# 2614
# replay_buffer_eval_add 2614
# 2616
# replay_buffer_train_add 2616
# 2618
# replay_buffer_eval_add 2618
# 2620
# replay_buffer_train_add 2620
# 2622
# replay_buffer_eval_add 2622
# 2624
# replay_buffer_train_add 2624
# 2626
# replay_buffer_eval_add 2626
# 2628
# replay_buffer_train_add 2628
# 2630
# replay_buffer_train_add 2630
# 2632
# replay_buffer_train_add 2632
# 2634
# replay_buffer_train_add 2634
# 2636
# replay_buffer_train_add 2636
# 2638
# replay_buffer_eval_add 2638
# 2640
# replay_buffer_train_add 2640
# 2642
# replay_buffer_train_add 2642
# 2644
# replay_buffer_train_add 2644
# 2646
# replay_buffer_train_add 2646
# 2648
# replay_buffer_train_add 2648
# 2650
# replay_buffer_eval_add 2650
# 2652
# replay_buffer_eval_add 2652
# 2654
# replay_buffer_train_add 2654
# 2656
# replay_buffer_train_add 2656
# 2658
# replay_buffer_train_add 2658
# 2660
# replay_buffer_train_add 2660
# 2662
# replay_buffer_eval_add 2662
# 2664
# replay_buffer_train_add 2664
# 2666
# replay_buffer_train_add 2666
# 2668
# replay_buffer_train_add 2668
# 2670
# replay_buffer_train_add 2670
# 2672
# replay_buffer_train_add 2672
# 2674
# replay_buffer_train_add 2674
# 2676
# replay_buffer_train_add 2676
# 2678
# replay_buffer_eval_add 2678
# 2680
# replay_buffer_train_add 2680
# 2682
# replay_buffer_eval_add 2682
# 2684
# replay_buffer_eval_add 2684
# 2686
# replay_buffer_train_add 2686
# 2688
# replay_buffer_train_add 2688
# 2690
# replay_buffer_eval_add 2690
# 2692
# replay_buffer_train_add 2692
# 2694
# replay_buffer_eval_add 2694
# 2696
# replay_buffer_train_add 2696
# 2698
# replay_buffer_eval_add 2698
# 2700
# replay_buffer_eval_add 2700
# 2702
# replay_buffer_train_add 2702
# 2704
# replay_buffer_train_add 2704
# 2706
# replay_buffer_train_add 2706
# 2708
# replay_buffer_eval_add 2708
# 2710
# replay_buffer_train_add 2710
# 2712
# replay_buffer_train_add 2712
# 2714
# replay_buffer_train_add 2714
# 2716
# replay_buffer_train_add 2716
# 2718
# replay_buffer_eval_add 2718
# 2720
# replay_buffer_train_add 2720
# 2722
# replay_buffer_train_add 2722
# 2724
# replay_buffer_eval_add 2724
# 2726
# replay_buffer_train_add 2726
# 2728
# replay_buffer_train_add 2728
# 2730
# replay_buffer_eval_add 2730
# 2732
# replay_buffer_eval_add 2732
# 2734
# replay_buffer_train_add 2734
# 2736
# replay_buffer_eval_add 2736
# 2738
# replay_buffer_eval_add 2738
# 2740
# replay_buffer_train_add 2740
# 2742
# replay_buffer_train_add 2742
# 2744
# replay_buffer_eval_add 2744
# 2746
# replay_buffer_train_add 2746
# 2748
# replay_buffer_train_add 2748
# 2750
# replay_buffer_eval_add 2750
# 2752
# replay_buffer_train_add 2752
# 2754
# replay_buffer_train_add 2754
# 2756
# replay_buffer_eval_add 2756
# 2758
# replay_buffer_train_add 2758
# 2760
# replay_buffer_train_add 2760
# 2762
# replay_buffer_train_add 2762
# 2764
# replay_buffer_train_add 2764
# 2766
# replay_buffer_eval_add 2766
# 2768
# replay_buffer_eval_add 2768
# 2770
# replay_buffer_train_add 2770
# 2772
# replay_buffer_train_add 2772
# 2774
# replay_buffer_train_add 2774
# 2776
# replay_buffer_train_add 2776
# 2778
# replay_buffer_train_add 2778
# 2780
# replay_buffer_train_add 2780
# 2782
# replay_buffer_eval_add 2782
# 2784
# replay_buffer_train_add 2784
# 2786
# replay_buffer_eval_add 2786
# 2788
# replay_buffer_eval_add 2788
# 2790
# replay_buffer_train_add 2790
# 2792
# replay_buffer_train_add 2792
# 2794
# replay_buffer_eval_add 2794
# 2796
# replay_buffer_eval_add 2796
# 2798
# replay_buffer_train_add 2798
# 2800
# replay_buffer_train_add 2800
# 2802
# replay_buffer_train_add 2802
# 2804
# replay_buffer_train_add 2804
# 2806
# replay_buffer_eval_add 2806
# 2808
# replay_buffer_train_add 2808
# 2810
# replay_buffer_train_add 2810
# 2812
# replay_buffer_eval_add 2812
# 2814
# replay_buffer_train_add 2814
# 2816
# replay_buffer_train_add 2816
# 2818
# replay_buffer_train_add 2818
# 2820
# replay_buffer_train_add 2820
# 2822
# replay_buffer_train_add 2822
# 2824
# replay_buffer_train_add 2824
# 2826
# replay_buffer_train_add 2826
# 2828
# replay_buffer_eval_add 2828
# 2830
# replay_buffer_train_add 2830
# 2832
# replay_buffer_train_add 2832
# 2834
# replay_buffer_train_add 2834
# 2836
# replay_buffer_train_add 2836
# 2838
# replay_buffer_train_add 2838
# 2840
# replay_buffer_train_add 2840
# 2842
# replay_buffer_train_add 2842
# 2844
# replay_buffer_eval_add 2844
# 2846
# replay_buffer_eval_add 2846
# 2848
# replay_buffer_eval_add 2848
# 2850
# replay_buffer_train_add 2850
# 2852
# replay_buffer_eval_add 2852
# 2854
# replay_buffer_eval_add 2854
# 2856
# replay_buffer_train_add 2856
# 2858
# replay_buffer_train_add 2858
# 2860
# replay_buffer_train_add 2860
# 2862
# replay_buffer_train_add 2862
# 2864
# replay_buffer_eval_add 2864
# 2866
# replay_buffer_train_add 2866
# 2868
# replay_buffer_train_add 2868
# 2870
# replay_buffer_train_add 2870
# 2872
# replay_buffer_eval_add 2872
# 2874
# replay_buffer_train_add 2874
# 2876
# replay_buffer_train_add 2876
# 2878
# replay_buffer_train_add 2878
# 2880
# replay_buffer_train_add 2880
# 2882
# replay_buffer_eval_add 2882
# 2884
# replay_buffer_train_add 2884
# 2886
# replay_buffer_train_add 2886
# 2888
# replay_buffer_train_add 2888
# 2890
# replay_buffer_train_add 2890
# 2892
# replay_buffer_train_add 2892
# 2894
# replay_buffer_eval_add 2894
# 2896
# replay_buffer_train_add 2896
# 2898
# replay_buffer_train_add 2898
# 2900
# replay_buffer_eval_add 2900
# 2902
# replay_buffer_train_add 2902
# 2904
# replay_buffer_train_add 2904
# 2906
# replay_buffer_train_add 2906
# 2908
# replay_buffer_train_add 2908
# 2910
# ...
# 99106
# replay_buffer_train_add 99106
# 99108
# replay_buffer_train_add 99108
# 99110
# replay_buffer_eval_add 99110
# 99112
# replay_buffer_train_add 99112
# 99114
# replay_buffer_train_add 99114
# 99116
# replay_buffer_eval_add 99116
# 99118
# replay_buffer_train_add 99118
# 99120
# replay_buffer_eval_add 99120
# 99122
# replay_buffer_train_add 99122
# 99124
# replay_buffer_eval_add 99124
# 99126
# replay_buffer_train_add 99126
# 99128
# replay_buffer_eval_add 99128
# 99130
# replay_buffer_train_add 99130
# 99132
# replay_buffer_train_add 99132
# 99134
# replay_buffer_train_add 99134
# 99136
# replay_buffer_train_add 99136
# 99138
# replay_buffer_train_add 99138
# 99140
# replay_buffer_train_add 99140
# 99142
# replay_buffer_train_add 99142
# 99144
# replay_buffer_eval_add 99144
# 99146
# replay_buffer_train_add 99146
# 99148
# replay_buffer_eval_add 99148
# 99150
# replay_buffer_train_add 99150
# 99152
# replay_buffer_eval_add 99152
# 99154
# replay_buffer_train_add 99154
# 99156
# replay_buffer_train_add 99156
# 99158
# replay_buffer_train_add 99158
# 99160
# replay_buffer_train_add 99160
# 99162
# replay_buffer_eval_add 99162
# 99164
# replay_buffer_train_add 99164
# 99166
# replay_buffer_eval_add 99166
# 99168
# replay_buffer_train_add 99168
# 99170
# replay_buffer_train_add 99170
# 99172
# replay_buffer_train_add 99172
# 99174
# replay_buffer_train_add 99174
# 99176
# replay_buffer_train_add 99176
# 99178
# replay_buffer_train_add 99178
# 99180
# replay_buffer_train_add 99180
# 99182
# replay_buffer_train_add 99182
# 99184
# replay_buffer_train_add 99184
# 99186
# replay_buffer_train_add 99186
# 99188
# replay_buffer_train_add 99188
# 99190
# replay_buffer_train_add 99190
# 99192
# replay_buffer_eval_add 99192
# 99194
# replay_buffer_train_add 99194
# 99196
# replay_buffer_train_add 99196
# 99198
# replay_buffer_eval_add 99198
# 99200
# replay_buffer_train_add 99200
# 99202
# replay_buffer_train_add 99202
# 99204
# replay_buffer_train_add 99204
# 99206
# replay_buffer_eval_add 99206
# 99208
# replay_buffer_train_add 99208
# 99210
# replay_buffer_eval_add 99210
# 99212
# replay_buffer_train_add 99212
# 99214
# replay_buffer_train_add 99214
# 99216
# replay_buffer_train_add 99216
# 99218
# replay_buffer_train_add 99218
# 99220
# replay_buffer_train_add 99220
# 99222
# replay_buffer_train_add 99222
# 99224
# replay_buffer_train_add 99224
# 99226
# replay_buffer_train_add 99226
# 99228
# replay_buffer_train_add 99228
# 99230
# replay_buffer_eval_add 99230
# 99232
# replay_buffer_eval_add 99232
# 99234
# replay_buffer_eval_add 99234
# 99236
# replay_buffer_train_add 99236
# 99238
# replay_buffer_eval_add 99238
# 99240
# replay_buffer_train_add 99240
# 99242
# replay_buffer_train_add 99242
# 99244
# replay_buffer_train_add 99244
# 99246
# replay_buffer_train_add 99246
# 99248
# replay_buffer_train_add 99248
# 99250
# replay_buffer_train_add 99250
# 99252
# replay_buffer_eval_add 99252
# 99254
# replay_buffer_train_add 99254
# 99256
# replay_buffer_train_add 99256
# 99258
# replay_buffer_train_add 99258
# 99260
# replay_buffer_eval_add 99260
# 99262
# replay_buffer_train_add 99262
# 99264
# replay_buffer_train_add 99264
# 99266
# replay_buffer_train_add 99266
# 99268
# replay_buffer_train_add 99268
# 99270
# replay_buffer_train_add 99270
# 99272
# replay_buffer_eval_add 99272
# 99274
# replay_buffer_train_add 99274
# 99276
# replay_buffer_train_add 99276
# 99278
# replay_buffer_eval_add 99278
# 99280
# replay_buffer_train_add 99280
# 99282
# replay_buffer_train_add 99282
# 99284
# replay_buffer_eval_add 99284
# 99286
# replay_buffer_train_add 99286
# 99288
# replay_buffer_train_add 99288
# 99290
# replay_buffer_eval_add 99290
# 99292
# replay_buffer_train_add 99292
# 99294
# replay_buffer_train_add 99294
# 99296
# replay_buffer_eval_add 99296
# 99298
# replay_buffer_train_add 99298
# 99300
# replay_buffer_train_add 99300
# 99302
# replay_buffer_train_add 99302
# 99304
# replay_buffer_train_add 99304
# 99306
# replay_buffer_train_add 99306
# 99308
# replay_buffer_train_add 99308
# 99310
# replay_buffer_eval_add 99310
# 99312
# replay_buffer_train_add 99312
# 99314
# replay_buffer_eval_add 99314
# 99316
# replay_buffer_train_add 99316
# 99318
# replay_buffer_eval_add 99318
# 99320
# replay_buffer_eval_add 99320
# 99322
# replay_buffer_train_add 99322
# 99324
# replay_buffer_train_add 99324
# 99326
# replay_buffer_train_add 99326
# 99328
# replay_buffer_eval_add 99328
# 99330
# replay_buffer_train_add 99330
# 99332
# replay_buffer_train_add 99332
# 99334
# replay_buffer_train_add 99334
# 99336
# replay_buffer_train_add 99336
# 99338
# replay_buffer_train_add 99338
# 99340
# replay_buffer_eval_add 99340
# 99342
# replay_buffer_train_add 99342
# 99344
# replay_buffer_eval_add 99344
# 99346
# replay_buffer_train_add 99346
# 99348
# replay_buffer_train_add 99348
# 99350
# replay_buffer_train_add 99350
# 99352
# replay_buffer_eval_add 99352
# 99354
# replay_buffer_eval_add 99354
# 99356
# replay_buffer_eval_add 99356
# 99358
# replay_buffer_train_add 99358
# 99360
# replay_buffer_eval_add 99360
# 99362
# replay_buffer_train_add 99362
# 99364
# replay_buffer_train_add 99364
# 99366
# replay_buffer_eval_add 99366
# 99368
# replay_buffer_train_add 99368
# 99370
# replay_buffer_train_add 99370
# 99372
# replay_buffer_train_add 99372
# 99374
# replay_buffer_train_add 99374
# 99376
# replay_buffer_train_add 99376
# 99378
# replay_buffer_train_add 99378
# 99380
# replay_buffer_eval_add 99380
# 99382
# replay_buffer_train_add 99382
# 99384
# replay_buffer_train_add 99384
# 99386
# replay_buffer_eval_add 99386
# 99388
# replay_buffer_eval_add 99388
# 99390
# replay_buffer_train_add 99390
# 99392
# replay_buffer_train_add 99392
# 99394
# replay_buffer_train_add 99394
# 99396
# replay_buffer_train_add 99396
# 99398
# replay_buffer_train_add 99398
# 99400
# replay_buffer_eval_add 99400
# 99402
# replay_buffer_train_add 99402
# 99404
# replay_buffer_eval_add 99404
# 99406
# replay_buffer_train_add 99406
# 99408
# replay_buffer_eval_add 99408
# 99410
# replay_buffer_train_add 99410
# 99412
# replay_buffer_train_add 99412
# 99414
# replay_buffer_train_add 99414
# 99416
# replay_buffer_train_add 99416
# 99418
# replay_buffer_eval_add 99418
# 99420
# replay_buffer_train_add 99420
# 99422
# replay_buffer_train_add 99422
# 99424
# replay_buffer_train_add 99424
# 99426
# replay_buffer_train_add 99426
# 99428
# replay_buffer_eval_add 99428
# 99430
# replay_buffer_train_add 99430
# 99432
# replay_buffer_eval_add 99432
# 99434
# replay_buffer_train_add 99434
# 99436
# replay_buffer_train_add 99436
# 99438
# replay_buffer_train_add 99438
# 99440
# replay_buffer_train_add 99440
# 99442
# replay_buffer_train_add 99442
# 99444
# replay_buffer_eval_add 99444
# 99446
# replay_buffer_train_add 99446
# 99448
# replay_buffer_train_add 99448
# 99450
# replay_buffer_train_add 99450
# 99452
# replay_buffer_train_add 99452
# 99454
# replay_buffer_train_add 99454
# 99456
# replay_buffer_train_add 99456
# 99458
# replay_buffer_train_add 99458
# 99460
# replay_buffer_train_add 99460
# 99462
# replay_buffer_train_add 99462
# 99464
# replay_buffer_train_add 99464
# 99466
# replay_buffer_train_add 99466
# 99468
# replay_buffer_eval_add 99468
# 99470
# replay_buffer_train_add 99470
# 99472
# replay_buffer_train_add 99472
# 99474
# replay_buffer_eval_add 99474
# 99476
# replay_buffer_train_add 99476
# 99478
# replay_buffer_eval_add 99478
# 99480
# replay_buffer_eval_add 99480
# 99482
# replay_buffer_train_add 99482
# 99484
# replay_buffer_train_add 99484
# 99486
# replay_buffer_train_add 99486
# 99488
# replay_buffer_train_add 99488
# 99490
# replay_buffer_train_add 99490
# 99492
# replay_buffer_train_add 99492
# 99494
# replay_buffer_eval_add 99494
# 99496
# replay_buffer_eval_add 99496
# 99498
# replay_buffer_train_add 99498
# 99500
# replay_buffer_eval_add 99500
# 99502
# replay_buffer_train_add 99502
# 99504
# replay_buffer_eval_add 99504
# 99506
# replay_buffer_train_add 99506
# 99508
# replay_buffer_train_add 99508
# 99510
# replay_buffer_train_add 99510
# 99512
# replay_buffer_train_add 99512
# 99514
# replay_buffer_eval_add 99514
# 99516
# replay_buffer_eval_add 99516
# 99518
# replay_buffer_train_add 99518
# 99520
# replay_buffer_train_add 99520
# 99522
# replay_buffer_train_add 99522
# 99524
# replay_buffer_train_add 99524
# 99526
# replay_buffer_eval_add 99526
# 99528
# replay_buffer_train_add 99528
# 99530
# replay_buffer_train_add 99530
# 99532
# replay_buffer_train_add 99532
# 99534
# replay_buffer_train_add 99534
# 99536
# replay_buffer_eval_add 99536
# 99538
# replay_buffer_train_add 99538
# 99540
# replay_buffer_train_add 99540
# 99542
# replay_buffer_train_add 99542
# 99544
# replay_buffer_train_add 99544
# 99546
# replay_buffer_train_add 99546
# 99548
# replay_buffer_train_add 99548
# 99550
# replay_buffer_train_add 99550
# 99552
# replay_buffer_train_add 99552
# 99554
# replay_buffer_eval_add 99554
# 99556
# replay_buffer_train_add 99556
# 99558
# replay_buffer_train_add 99558
# 99560
# replay_buffer_train_add 99560
# 99562
# replay_buffer_train_add 99562
# 99564
# replay_buffer_train_add 99564
# 99566
# replay_buffer_eval_add 99566
# 99568
# replay_buffer_train_add 99568
# 99570
# replay_buffer_eval_add 99570
# 99572
# replay_buffer_train_add 99572
# 99574
# replay_buffer_train_add 99574
# 99576
# replay_buffer_train_add 99576
# 99578
# replay_buffer_train_add 99578
# 99580
# replay_buffer_train_add 99580
# 99582
# replay_buffer_train_add 99582
# 99584
# replay_buffer_eval_add 99584
# 99586
# replay_buffer_train_add 99586
# 99588
# replay_buffer_train_add 99588
# 99590
# replay_buffer_train_add 99590
# 99592
# replay_buffer_train_add 99592
# 99594
# replay_buffer_train_add 99594
# 99596
# replay_buffer_train_add 99596
# 99598
# replay_buffer_train_add 99598
# 99600
# replay_buffer_train_add 99600
# 99602
# replay_buffer_eval_add 99602
# 99604
# replay_buffer_eval_add 99604
# 99606
# replay_buffer_train_add 99606
# 99608
# replay_buffer_train_add 99608
# 99610
# replay_buffer_train_add 99610
# 99612
# replay_buffer_train_add 99612
# 99614
# replay_buffer_eval_add 99614
# 99616
# replay_buffer_train_add 99616
# 99618
# replay_buffer_eval_add 99618
# 99620
# replay_buffer_train_add 99620
# 99622
# replay_buffer_train_add 99622
# 99624
# replay_buffer_train_add 99624
# 99626
# replay_buffer_train_add 99626
# 99628
# replay_buffer_train_add 99628
# 99630
# replay_buffer_eval_add 99630
# 99632
# replay_buffer_train_add 99632
# 99634
# replay_buffer_train_add 99634
# 99636
# replay_buffer_eval_add 99636
# 99638
# replay_buffer_eval_add 99638
# 99640
# replay_buffer_train_add 99640
# 99642
# replay_buffer_eval_add 99642
# 99644
# replay_buffer_eval_add 99644
# 99646
# replay_buffer_train_add 99646
# 99648
# replay_buffer_eval_add 99648
# 99650
# replay_buffer_train_add 99650
# 99652
# replay_buffer_train_add 99652
# 99654
# replay_buffer_train_add 99654
# 99656
# replay_buffer_eval_add 99656
# 99658
# replay_buffer_eval_add 99658
# 99660
# replay_buffer_train_add 99660
# 99662
# replay_buffer_train_add 99662
# 99664
# replay_buffer_train_add 99664
# 99666
# replay_buffer_train_add 99666
# 99668
# replay_buffer_train_add 99668
# 99670
# replay_buffer_train_add 99670
# 99672
# replay_buffer_train_add 99672
# 99674
# replay_buffer_train_add 99674
# 99676
# replay_buffer_train_add 99676
# 99678
# replay_buffer_eval_add 99678
# 99680
# replay_buffer_train_add 99680
# 99682
# replay_buffer_train_add 99682
# 99684
# replay_buffer_train_add 99684
# 99686
# replay_buffer_train_add 99686
# 99688
# replay_buffer_train_add 99688
# 99690
# replay_buffer_train_add 99690
# 99692
# replay_buffer_train_add 99692
# 99694
# replay_buffer_eval_add 99694
# 99696
# replay_buffer_eval_add 99696
# 99698
# replay_buffer_train_add 99698
# 99700
# replay_buffer_train_add 99700
# 99702
# replay_buffer_train_add 99702
# 99704
# replay_buffer_train_add 99704
# 99706
# replay_buffer_train_add 99706
# 99708
# replay_buffer_train_add 99708
# 99710
# replay_buffer_eval_add 99710
# 99712
# replay_buffer_train_add 99712
# 99714
# replay_buffer_train_add 99714
# 99716
# replay_buffer_train_add 99716
# 99718
# replay_buffer_train_add 99718
# 99720
# replay_buffer_train_add 99720
# 99722
# replay_buffer_train_add 99722
# 99724
# replay_buffer_eval_add 99724
# 99726
# replay_buffer_train_add 99726
# 99728
# replay_buffer_eval_add 99728
# 99730
# replay_buffer_train_add 99730
# 99732
# replay_buffer_train_add 99732
# 99734
# replay_buffer_train_add 99734
# 99736
# replay_buffer_train_add 99736
# 99738
# replay_buffer_eval_add 99738
# 99740
# replay_buffer_eval_add 99740
# 99742
# replay_buffer_train_add 99742
# 99744
# replay_buffer_train_add 99744
# 99746
# replay_buffer_train_add 99746
# 99748
# replay_buffer_train_add 99748
# 99750
# replay_buffer_train_add 99750
# 99752
# replay_buffer_eval_add 99752
# 99754
# replay_buffer_eval_add 99754
# 99756
# replay_buffer_train_add 99756
# 99758
# replay_buffer_eval_add 99758
# 99760
# replay_buffer_train_add 99760
# 99762
# replay_buffer_eval_add 99762
# 99764
# replay_buffer_train_add 99764
# 99766
# replay_buffer_eval_add 99766
# 99768
# replay_buffer_eval_add 99768
# 99770
# replay_buffer_train_add 99770
# 99772
# replay_buffer_train_add 99772
# 99774
# replay_buffer_eval_add 99774
# 99776
# replay_buffer_train_add 99776
# 99778
# replay_buffer_eval_add 99778
# 99780
# replay_buffer_train_add 99780
# 99782
# replay_buffer_train_add 99782
# 99784
# replay_buffer_train_add 99784
# 99786
# replay_buffer_train_add 99786
# 99788
# replay_buffer_train_add 99788
# 99790
# replay_buffer_eval_add 99790
# 99792
# replay_buffer_train_add 99792
# 99794
# replay_buffer_train_add 99794
# 99796
# replay_buffer_train_add 99796
# 99798
# replay_buffer_train_add 99798
# 99800
# replay_buffer_eval_add 99800
# 99802
# replay_buffer_train_add 99802
# 99804
# replay_buffer_train_add 99804
# 99806
# replay_buffer_eval_add 99806
# 99808
# replay_buffer_train_add 99808
# 99810
# replay_buffer_train_add 99810
# 99812
# replay_buffer_train_add 99812
# 99814
# replay_buffer_eval_add 99814
# 99816
# replay_buffer_train_add 99816
# 99818
# replay_buffer_train_add 99818
# 99820
# replay_buffer_train_add 99820
# 99822
# replay_buffer_eval_add 99822
# 99824
# replay_buffer_train_add 99824
# 99826
# replay_buffer_train_add 99826
# 99828
# replay_buffer_train_add 99828
# 99830
# replay_buffer_train_add 99830
# 99832
# replay_buffer_train_add 99832
# 99834
# replay_buffer_train_add 99834
# 99836
# replay_buffer_train_add 99836
# 99838
# replay_buffer_train_add 99838
# 99840
# replay_buffer_train_add 99840
# 99842
# replay_buffer_train_add 99842
# 99844
# replay_buffer_train_add 99844
# 99846
# replay_buffer_eval_add 99846
# 99848
# replay_buffer_train_add 99848
# 99850
# replay_buffer_train_add 99850
# 99852
# replay_buffer_train_add 99852
# 99854
# replay_buffer_train_add 99854
# 99856
# replay_buffer_train_add 99856
# 99858
# replay_buffer_eval_add 99858
# 99860
# replay_buffer_train_add 99860
# 99862
# replay_buffer_train_add 99862
# 99864
# replay_buffer_train_add 99864
# 99866
# replay_buffer_train_add 99866
# 99868
# replay_buffer_train_add 99868
# 99870
# replay_buffer_eval_add 99870
# 99872
# replay_buffer_eval_add 99872
# 99874
# replay_buffer_eval_add 99874
# 99876
# replay_buffer_eval_add 99876
# 99878
# replay_buffer_train_add 99878
# 99880
# replay_buffer_eval_add 99880
# 99882
# replay_buffer_train_add 99882
# 99884
# replay_buffer_eval_add 99884
# 99886
# replay_buffer_train_add 99886
# 99888
# replay_buffer_train_add 99888
# 99890
# replay_buffer_eval_add 99890
# 99892
# replay_buffer_train_add 99892
# 99894
# replay_buffer_eval_add 99894
# 99896
# replay_buffer_eval_add 99896
# 99898
# replay_buffer_eval_add 99898
# 99900
# replay_buffer_eval_add 99900
# 99902
# replay_buffer_train_add 99902
# 99904
# replay_buffer_train_add 99904
# 99906
# replay_buffer_train_add 99906
# 99908
# replay_buffer_train_add 99908
# 99910
# replay_buffer_train_add 99910
# 99912
# replay_buffer_eval_add 99912
# 99914
# replay_buffer_train_add 99914
# 99916
# replay_buffer_train_add 99916
# 99918
# replay_buffer_train_add 99918
# 99920
# replay_buffer_train_add 99920
# 99922
# replay_buffer_train_add 99922
# 99924
# replay_buffer_train_add 99924
# 99926
# replay_buffer_train_add 99926
# 99928
# replay_buffer_train_add 99928
# 99930
# replay_buffer_train_add 99930
# 99932
# replay_buffer_train_add 99932
# 99934
# replay_buffer_train_add 99934
# 99936
# replay_buffer_eval_add 99936
# 99938
# replay_buffer_eval_add 99938
# 99940
# replay_buffer_train_add 99940
# 99942
# replay_buffer_eval_add 99942
# 99944
# replay_buffer_train_add 99944
# 99946
# replay_buffer_train_add 99946
# 99948
# replay_buffer_train_add 99948
# 99950
# replay_buffer_train_add 99950
# 99952
# replay_buffer_train_add 99952
# 99954
# replay_buffer_eval_add 99954
# 99956
# replay_buffer_train_add 99956
# 99958
# replay_buffer_eval_add 99958
# 99960
# replay_buffer_train_add 99960
# 99962
# replay_buffer_train_add 99962
# 99964
# replay_buffer_train_add 99964
# 99966
# replay_buffer_train_add 99966
# 99968
# replay_buffer_train_add 99968
# 99970
# replay_buffer_eval_add 99970
# 99972
# replay_buffer_eval_add 99972
# 99974
# replay_buffer_train_add 99974
# 99976
# replay_buffer_eval_add 99976
# 99978
# replay_buffer_train_add 99978
# 99980
# replay_buffer_train_add 99980
# 99982
# replay_buffer_train_add 99982
# 99984
# replay_buffer_train_add 99984
# 99986
# replay_buffer_train_add 99986
# 99988
# replay_buffer_train_add 99988
# 99990
# replay_buffer_train_add 99990
# 99992
# replay_buffer_eval_add 99992
# 99994
# replay_buffer_train_add 99994
# 99996
# replay_buffer_eval_add 99996
# 99998
# replay_buffer_train_add 99998

# %%
# # 训练集
# for t in range(len(data_train[:-1])):
#     state = data[t][0:-4]
#     action = data[t][-2]
#     next_state = data[t+1][0:-4]
#     reward = data[t+1][-3]
#     done = data[t][-1]
#     replay_buffer_train.add(state, action, next_state, reward, done)
# # 验证集
# for t in range(len(data_eval[:-1])):
#     state = data[t][0:-4]
#     action = data[t][-2]
#     next_state = data[t+1][0:-4]
#     reward = data[t+1][-3]
#     done = data[t][-1]
#     replay_buffer_eval.add(state, action, next_state, reward, done)

# %%
buffer_name = "replay_buffer_ib"
replay_buffer_train.save(f"./buffers/{buffer_name}_train")
replay_buffer_eval.save(f"./buffers/{buffer_name}_eval")
