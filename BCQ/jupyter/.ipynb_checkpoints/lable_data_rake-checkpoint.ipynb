# %%
import numpy as np
import os
import random
import pandas as pd
import datetime
import math
from math import e
import datetime
from scipy.interpolate import interp1d
import time, datetime
from pandas.core.frame import DataFrame
from db_models import GmsMonitor

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
def pd_aggregation(data):
    dense_series_1s = data.resample('1S').interpolate("linear")
    series_1m = dense_series_1s.groupby(pd.Grouper(freq='5Min')).aggregate(np.mean)
    return series_1m

# %%
def mongodb_connect():
    import mongoengine
    mongoengine
    mongoengine.connect('nfca_db', host='dgx.server.ustb-ai3d.cn', port=27017, username='nfca', password='nfca')

mongodb_connect()

# %%
def queryset2df(query_data):
    """
    queryset转dataframe
    :return:
    """
    dic = {"time":[], "value":[]}
    for q in query_data:
        dic["time"].append(q['time'])
        dic["value"].append(q['Monitoring_value'])
    # 存在数据库多条目同一时间同一值、多条目同一时间不同值的情况，仅保留首条数据
    df = pd.DataFrame(dic).drop_duplicates(subset=['time'])
    return df

# %%
df = pd.read_csv('2023_label_1.csv', low_memory=False)

# %%
df['time'] = pd.to_datetime(df['time'], format='%Y/%m/%d %H:%M')
df['time'][0]
# Out:
# Timestamp('2022-01-22 23:20:00')

# %%
df = df.set_index(['time'], drop=True)
df
# Out:
#                      feed_c  out_c   feed_f  out_f  pressure  overflow_t  \
# time
# 2022-01-22 23:20:00   42.50   62.2  635.000  170.0      50.3       0.231
# 2022-01-22 23:21:00   42.40   61.7  536.000  185.0      51.2       0.231
# 2022-01-22 23:22:00   36.90   62.0  450.000  176.0      49.0       0.224
# 2022-01-22 23:23:00   32.20   63.6  551.000  164.0      48.8       0.224
# 2022-01-22 23:24:00   32.60   63.2  731.000  186.0      49.0       0.231
# ...                     ...    ...      ...    ...       ...         ...
# 2023-01-19 23:09:00    6.20   55.5    0.434  184.0      32.6       0.109
# 2023-01-19 23:10:00    6.17   56.4    0.434  175.0      32.4       0.101
# 2023-01-19 23:11:00    6.25   56.0    0.434  190.0      32.9       0.101
# 2023-01-19 23:12:00    5.72   56.4    0.434  166.0      32.5       0.101
# 2023-01-19 23:13:00    5.70   56.5    0.488  183.0      32.7       0.101
#
#                      rake_s  rake_1  rake_2  rake_3  rake_4  label
# time
# 2022-01-22 23:20:00    45.0    25.6    26.5    26.1    26.0      1
# 2022-01-22 23:21:00    45.0    26.4    26.0    26.4    26.7      1
# 2022-01-22 23:22:00    45.0    26.4    25.9    26.6    27.1      1
# 2022-01-22 23:23:00    45.0    25.4    26.1    26.9    27.8      1
# 2022-01-22 23:24:00    45.0    25.6    26.0    26.9    26.3      1
# ...                     ...     ...     ...     ...     ...    ...
# 2023-01-19 23:09:00    45.0    19.2    20.4    24.2    20.8      1
# 2023-01-19 23:10:00    45.0    19.1    20.1    24.2    21.0      1
# 2023-01-19 23:11:00    45.0    18.7    20.3    24.5    20.7      1
# 2023-01-19 23:12:00    45.0    18.6    20.0    22.4    20.8      1
# 2023-01-19 23:13:00    45.0    18.6    20.0    22.2    20.1      1
#
# [56878 rows x 12 columns]

# %%
df_1 = df.resample('5Min').interpolate("zero")
df_1 = df_1.drop(df_1.index[0])
df_1
# Out:
#                      feed_c  out_c   feed_f  out_f  pressure  overflow_t  \
# time
# 2022-01-22 23:25:00   37.30   63.0  769.000  174.0      49.3       0.224
# 2022-01-22 23:30:00   34.00   62.7  470.000  186.0      49.5       5.870
# 2022-01-22 23:35:00   39.90   62.4  721.000  185.0      49.9       0.224
# 2022-01-22 23:40:00   35.10   62.6  774.000  179.0      51.0       0.224
# 2022-01-22 23:45:00   35.10   62.0  776.000  199.0      50.3       0.224
# ...                     ...    ...      ...    ...       ...         ...
# 2023-01-19 22:50:00    8.98   55.4    0.434  179.0      35.6       0.109
# 2023-01-19 22:55:00    6.97   56.7    0.434  176.0      33.5       0.109
# 2023-01-19 23:00:00    7.13   57.2    0.434  188.0      31.1       0.109
# 2023-01-19 23:05:00    8.05   54.9  555.000  179.0      32.3       0.101
# 2023-01-19 23:10:00    6.17   56.4    0.434  175.0      32.4       0.101
#
#                      rake_s  rake_1  rake_2  rake_3  rake_4  label
# time
# 2022-01-22 23:25:00    45.0    25.7    25.1    26.0    25.8    1.0
# 2022-01-22 23:30:00    45.0    25.0    24.6    25.0    25.4    1.0
# 2022-01-22 23:35:00    45.0    24.1    25.4    25.0    25.2    1.0
# 2022-01-22 23:40:00    45.0    24.4    24.0    24.4    25.4    1.0
# 2022-01-22 23:45:00    45.0    24.7    24.6    24.9    24.7    1.0
# ...                     ...     ...     ...     ...     ...    ...
# 2023-01-19 22:50:00    45.0    19.7    20.3    23.3    21.0    1.0
# 2023-01-19 22:55:00    45.0    19.0    19.7    23.6    19.6    1.0
# 2023-01-19 23:00:00    45.0    20.3    20.2    23.7    20.7    1.0
# 2023-01-19 23:05:00    45.0    21.2    21.6    24.2    22.3    2.0
# 2023-01-19 23:10:00    45.0    19.1    20.1    24.2    21.0    1.0
#
# [104254 rows x 12 columns]

# %%
out_f_setting_query = (GmsMonitor.objects.filter(
    time__gte=df_1.index[0],
    time__lt=df_1.index[-1],
    point_id=73
).order_by("time"))
out_f_setting = []
for query in out_f_setting_query:
    out_f_setting.append(query.to_mongo().to_dict())
out_f_setting = queryset2df(out_f_setting).set_index(['time'], drop=False)

# 最后时间的前一个时间
past_set_point =  GmsMonitor.objects.filter(
    time__lt=df_1.index[0],
    point_id=73
).order_by("-time").limit(1)[0].to_mongo().to_dict()
past_time = past_set_point['time']
past_set_value = past_set_point['Monitoring_value']
out_f_setting.loc[past_time] = [past_time, past_set_value]

# 最新时间
last_set_point = GmsMonitor.objects.filter(
    point_id=73
).order_by("-time").limit(1)[0].to_mongo().to_dict()
last_time = datetime.datetime.now()
last_set_value = last_set_point['Monitoring_value']
out_f_setting.loc[last_time] = [last_time, last_set_value]

# 0阶插值\pad上采样
out_f_setting = out_f_setting.sort_index()
out_f_setting = out_f_setting.resample('1S').pad().groupby(pd.Grouper(freq='5Min')).aggregate(np.mean)


out_f_setting = out_f_setting.loc[df_1.index[0]: df_1.index[-1]]   # 和out_c区间保持一致
out_f_setting.rename(columns={"value":"out_f_setting"}, inplace=True)

# %%
out_f_setting
df_1 = pd.concat([df_1, out_f_setting],axis=1)

# %%
out_c_setting_query = (GmsMonitor.objects.filter(
    time__gte=df_1.index[0],
    time__lt=df_1.index[-1],
    point_id=70
).order_by("time"))
out_c_setting = []
for query in out_c_setting_query:
    out_c_setting.append(query.to_mongo().to_dict())
out_c_setting = queryset2df(out_c_setting).set_index(['time'], drop=False)

# 最后时间的前一个时间
past_set_point =  GmsMonitor.objects.filter(
    time__lt=df_1.index[0],
    point_id=70
).order_by("-time").limit(1)[0].to_mongo().to_dict()
past_time = past_set_point['time']
past_set_value = past_set_point['Monitoring_value']
out_c_setting.loc[past_time] = [past_time, past_set_value]

# 最新时间
last_set_point = GmsMonitor.objects.filter(
    point_id=73
).order_by("-time").limit(1)[0].to_mongo().to_dict()
last_time = datetime.datetime.now()
last_set_value = last_set_point['Monitoring_value']
out_c_setting.loc[last_time] = [last_time, last_set_value]

# 0阶插值\pad上采样
out_c_setting = out_c_setting.sort_index()
out_c_setting = out_c_setting.resample('1S').pad().groupby(pd.Grouper(freq='5Min')).aggregate(np.mean)


out_c_setting = out_c_setting.loc[df_1.index[0]: df_1.index[-1]]   # 和out_c区间保持一致
out_c_setting.rename(columns={"value":"out_c_setting"}, inplace=True)

# %%
out_c_setting
df_1 = pd.concat([df_1, out_c_setting],axis=1)

# %%
df_1
# Out:
#                      feed_c  out_c   feed_f  out_f  pressure  overflow_t  \
# time
# 2022-01-22 23:25:00   37.30   63.0  769.000  174.0      49.3       0.224
# 2022-01-22 23:30:00   34.00   62.7  470.000  186.0      49.5       5.870
# 2022-01-22 23:35:00   39.90   62.4  721.000  185.0      49.9       0.224
# 2022-01-22 23:40:00   35.10   62.6  774.000  179.0      51.0       0.224
# 2022-01-22 23:45:00   35.10   62.0  776.000  199.0      50.3       0.224
# ...                     ...    ...      ...    ...       ...         ...
# 2023-01-19 22:50:00    8.98   55.4    0.434  179.0      35.6       0.109
# 2023-01-19 22:55:00    6.97   56.7    0.434  176.0      33.5       0.109
# 2023-01-19 23:00:00    7.13   57.2    0.434  188.0      31.1       0.109
# 2023-01-19 23:05:00    8.05   54.9  555.000  179.0      32.3       0.101
# 2023-01-19 23:10:00    6.17   56.4    0.434  175.0      32.4       0.101
#
#                      rake_s  rake_1  rake_2  rake_3  rake_4  label  \
# time
# 2022-01-22 23:25:00    45.0    25.7    25.1    26.0    25.8    1.0
# 2022-01-22 23:30:00    45.0    25.0    24.6    25.0    25.4    1.0
# 2022-01-22 23:35:00    45.0    24.1    25.4    25.0    25.2    1.0
# 2022-01-22 23:40:00    45.0    24.4    24.0    24.4    25.4    1.0
# 2022-01-22 23:45:00    45.0    24.7    24.6    24.9    24.7    1.0
# ...                     ...     ...     ...     ...     ...    ...
# 2023-01-19 22:50:00    45.0    19.7    20.3    23.3    21.0    1.0
# 2023-01-19 22:55:00    45.0    19.0    19.7    23.6    19.6    1.0
# 2023-01-19 23:00:00    45.0    20.3    20.2    23.7    20.7    1.0
# 2023-01-19 23:05:00    45.0    21.2    21.6    24.2    22.3    2.0
# 2023-01-19 23:10:00    45.0    19.1    20.1    24.2    21.0    1.0
#
#                      out_f_setting  out_c_setting
# time
# 2022-01-22 23:25:00          150.0           62.5
# 2022-01-22 23:30:00          150.0           62.5
# 2022-01-22 23:35:00          150.0           62.5
# 2022-01-22 23:40:00          150.0           62.5
# 2022-01-22 23:45:00          150.0           62.5
# ...                            ...            ...
# 2023-01-19 22:50:00          180.0           62.0
# 2023-01-19 22:55:00          180.0           62.0
# 2023-01-19 23:00:00          180.0           62.0
# 2023-01-19 23:05:00          180.0           62.0
# 2023-01-19 23:10:00          180.0           62.0
#
# [104254 rows x 14 columns]

# %%
# i = 0
# while True:
#     if i == (len(df_1)-1):
#         print('drop over')
#         break
#     # print(i)
#     if (df_1['out_f'][i] == df_1['out_f'][i-1]) or (df_1['label'][i] != 1.0):
#         print('repeat drop ', i)
#         df_1 = df_1.drop(df_1.index[i])
#         i = i - 1
#         # df_1.reset_index(drop=True, inplace=True)
#     i = i + 1

# %%
df_2 = df_1
len(df_2)
# Out:
# 104254

# %%
# df_2 = df_2.drop(df_2.index[1])

# %%
# df_2

# %%
i = 0
while i < len(df_2):
    if i == 0: 
        i = i + 1
    elif i == len(df_2):
        print("Data delete over!")
        break
    elif df_2['pressure'][i] == df_2['pressure'][i-1]:
        df_2 = df_2.drop(df_2.index[i])
        print("Empty time_range", i)
    elif df_2['label'][i] != 1:
        df_2 = df_2.drop(df_2.index[i])
        print("label error", i)
    else:
        i = i + 1
# Out:
# label error 23
# label error 28
# label error 29
# label error 29
# label error 30
# label error 30
# label error 30
# label error 30
# label error 33
# label error 33
# label error 35
# label error 35
# label error 43
# Empty time_range 51
# Empty time_range 66
# Empty time_range 71
# Empty time_range 74
# Empty time_range 76
# Empty time_range 85
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 102
# Empty time_range 116
# Empty time_range 128
# Empty time_range 135
# Empty time_range 144
# Empty time_range 199
# label error 202
# label error 204
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# Empty time_range 215
# ...
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9325
# label error 9335
# label error 9338
# label error 9343
# label error 9345
# label error 9347
# label error 9350
# label error 9356
# label error 9356
# Empty time_range 9356
# label error 9356
# label error 9356
# label error 9356
# label error 9356
# label error 9356
# label error 9356
# label error 9356
# label error 9356
# label error 9357
# label error 9357
# label error 9358
# label error 9358
# label error 9358
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# Empty time_range 9360
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9364
# label error 9367
# label error 9367
# label error 9367
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9369
# Empty time_range 9376
# label error 9377
# label error 9382
# label error 9384
# label error 9390
# label error 9391
# label error 9392
# label error 9392
# Empty time_range 9392
# label error 9394
# label error 9395
# label error 9398
# label error 9400
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9402
# Empty time_range 9418
# Empty time_range 9429
# label error 9430
# label error 9437
# label error 9438
# Empty time_range 9450
# label error 9466
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# Empty time_range 9470
# label error 9480
# label error 9486
# label error 9486
# Empty time_range 9486
# label error 9487
# label error 9487
# label error 9487
# label error 9487
# label error 9487
# label error 9487
# label error 9489
# label error 9489
# label error 9491
# label error 9491
# label error 9494
# label error 9497
# label error 9498
# label error 9499
# label error 9500
# label error 9501
# label error 9501
# label error 9501
# label error 9502
# label error 9502
# label error 9502
# label error 9502
# label error 9502
# label error 9502
# label error 9502
# label error 9502
# label error 9502
# label error 9502
# label error 9505

# %%
df_2
# Out:
#                      feed_c  out_c   feed_f  out_f  pressure  overflow_t  \
# time
# 2022-01-22 23:25:00   37.30   63.0  769.000  174.0      49.3       0.224
# 2022-01-22 23:30:00   34.00   62.7  470.000  186.0      49.5       5.870
# 2022-01-22 23:35:00   39.90   62.4  721.000  185.0      49.9       0.224
# 2022-01-22 23:40:00   35.10   62.6  774.000  179.0      51.0       0.224
# 2022-01-22 23:45:00   35.10   62.0  776.000  199.0      50.3       0.224
# ...                     ...    ...      ...    ...       ...         ...
# 2023-01-19 21:55:00   16.10   55.1    0.760  179.0      35.4       0.123
# 2023-01-19 22:50:00    8.98   55.4    0.434  179.0      35.6       0.109
# 2023-01-19 22:55:00    6.97   56.7    0.434  176.0      33.5       0.109
# 2023-01-19 23:00:00    7.13   57.2    0.434  188.0      31.1       0.109
# 2023-01-19 23:10:00    6.17   56.4    0.434  175.0      32.4       0.101
#
#                      rake_s  rake_1  rake_2  rake_3  rake_4  label  \
# time
# 2022-01-22 23:25:00    45.0    25.7    25.1    26.0    25.8    1.0
# 2022-01-22 23:30:00    45.0    25.0    24.6    25.0    25.4    1.0
# 2022-01-22 23:35:00    45.0    24.1    25.4    25.0    25.2    1.0
# 2022-01-22 23:40:00    45.0    24.4    24.0    24.4    25.4    1.0
# 2022-01-22 23:45:00    45.0    24.7    24.6    24.9    24.7    1.0
# ...                     ...     ...     ...     ...     ...    ...
# 2023-01-19 21:55:00    45.0    18.2    18.8    22.1    18.4    1.0
# 2023-01-19 22:50:00    45.0    19.7    20.3    23.3    21.0    1.0
# 2023-01-19 22:55:00    45.0    19.0    19.7    23.6    19.6    1.0
# 2023-01-19 23:00:00    45.0    20.3    20.2    23.7    20.7    1.0
# 2023-01-19 23:10:00    45.0    19.1    20.1    24.2    21.0    1.0
#
#                      out_f_setting  out_c_setting
# time
# 2022-01-22 23:25:00          150.0           62.5
# 2022-01-22 23:30:00          150.0           62.5
# 2022-01-22 23:35:00          150.0           62.5
# 2022-01-22 23:40:00          150.0           62.5
# 2022-01-22 23:45:00          150.0           62.5
# ...                            ...            ...
# 2023-01-19 21:55:00          180.0           62.0
# 2023-01-19 22:50:00          180.0           62.0
# 2023-01-19 22:55:00          180.0           62.0
# 2023-01-19 23:00:00          180.0           62.0
# 2023-01-19 23:10:00          180.0           62.0
#
# [9506 rows x 14 columns]

# %%
df_2.to_csv("df_test.csv", index=True)

# %%
df_3 = df_2

# %%
df_3.drop(columns = ['label'],inplace = True)

# %%
df_3
# Out:
#                      feed_c  out_c   feed_f  out_f  pressure  overflow_t  \
# time
# 2022-01-22 23:25:00   37.30   63.0  769.000  174.0      49.3       0.224
# 2022-01-22 23:30:00   34.00   62.7  470.000  186.0      49.5       5.870
# 2022-01-22 23:35:00   39.90   62.4  721.000  185.0      49.9       0.224
# 2022-01-22 23:40:00   35.10   62.6  774.000  179.0      51.0       0.224
# 2022-01-22 23:45:00   35.10   62.0  776.000  199.0      50.3       0.224
# ...                     ...    ...      ...    ...       ...         ...
# 2023-01-19 21:55:00   16.10   55.1    0.760  179.0      35.4       0.123
# 2023-01-19 22:50:00    8.98   55.4    0.434  179.0      35.6       0.109
# 2023-01-19 22:55:00    6.97   56.7    0.434  176.0      33.5       0.109
# 2023-01-19 23:00:00    7.13   57.2    0.434  188.0      31.1       0.109
# 2023-01-19 23:10:00    6.17   56.4    0.434  175.0      32.4       0.101
#
#                      rake_s  rake_1  rake_2  rake_3  rake_4  out_f_setting  \
# time
# 2022-01-22 23:25:00    45.0    25.7    25.1    26.0    25.8          150.0
# 2022-01-22 23:30:00    45.0    25.0    24.6    25.0    25.4          150.0
# 2022-01-22 23:35:00    45.0    24.1    25.4    25.0    25.2          150.0
# 2022-01-22 23:40:00    45.0    24.4    24.0    24.4    25.4          150.0
# 2022-01-22 23:45:00    45.0    24.7    24.6    24.9    24.7          150.0
# ...                     ...     ...     ...     ...     ...            ...
# 2023-01-19 21:55:00    45.0    18.2    18.8    22.1    18.4          180.0
# 2023-01-19 22:50:00    45.0    19.7    20.3    23.3    21.0          180.0
# 2023-01-19 22:55:00    45.0    19.0    19.7    23.6    19.6          180.0
# 2023-01-19 23:00:00    45.0    20.3    20.2    23.7    20.7          180.0
# 2023-01-19 23:10:00    45.0    19.1    20.1    24.2    21.0          180.0
#
#                      out_c_setting
# time
# 2022-01-22 23:25:00           62.5
# 2022-01-22 23:30:00           62.5
# 2022-01-22 23:35:00           62.5
# 2022-01-22 23:40:00           62.5
# 2022-01-22 23:45:00           62.5
# ...                            ...
# 2023-01-19 21:55:00           62.0
# 2023-01-19 22:50:00           62.0
# 2023-01-19 22:55:00           62.0
# 2023-01-19 23:00:00           62.0
# 2023-01-19 23:10:00           62.0
#
# [9506 rows x 13 columns]

# %%
reward_1 = - pow((df_3['out_c'] - df_3['out_c_setting']), 2)
reward_2 = -1/(1-(df_3['rake_1'] / 55)) + -1/(1-(df_3['rake_2'] / 55)) + -1/(1-(df_3['rake_3'] / 55)) + -1/(1-(df_3['rake_4'] / 55))
df_3['reward'] = reward_1 + 0.5*reward_2
df_3
# Out:
#                      feed_c  out_c   feed_f  out_f  pressure  overflow_t  \
# time
# 2022-01-22 23:25:00   37.30   63.0  769.000  174.0      49.3       0.224
# 2022-01-22 23:30:00   34.00   62.7  470.000  186.0      49.5       5.870
# 2022-01-22 23:35:00   39.90   62.4  721.000  185.0      49.9       0.224
# 2022-01-22 23:40:00   35.10   62.6  774.000  179.0      51.0       0.224
# 2022-01-22 23:45:00   35.10   62.0  776.000  199.0      50.3       0.224
# ...                     ...    ...      ...    ...       ...         ...
# 2023-01-19 21:55:00   16.10   55.1    0.760  179.0      35.4       0.123
# 2023-01-19 22:50:00    8.98   55.4    0.434  179.0      35.6       0.109
# 2023-01-19 22:55:00    6.97   56.7    0.434  176.0      33.5       0.109
# 2023-01-19 23:00:00    7.13   57.2    0.434  188.0      31.1       0.109
# 2023-01-19 23:10:00    6.17   56.4    0.434  175.0      32.4       0.101
#
#                      rake_s  rake_1  rake_2  rake_3  rake_4  out_f_setting  \
# time
# 2022-01-22 23:25:00    45.0    25.7    25.1    26.0    25.8          150.0
# 2022-01-22 23:30:00    45.0    25.0    24.6    25.0    25.4          150.0
# 2022-01-22 23:35:00    45.0    24.1    25.4    25.0    25.2          150.0
# 2022-01-22 23:40:00    45.0    24.4    24.0    24.4    25.4          150.0
# 2022-01-22 23:45:00    45.0    24.7    24.6    24.9    24.7          150.0
# ...                     ...     ...     ...     ...     ...            ...
# 2023-01-19 21:55:00    45.0    18.2    18.8    22.1    18.4          180.0
# 2023-01-19 22:50:00    45.0    19.7    20.3    23.3    21.0          180.0
# 2023-01-19 22:55:00    45.0    19.0    19.7    23.6    19.6          180.0
# 2023-01-19 23:00:00    45.0    20.3    20.2    23.7    20.7          180.0
# 2023-01-19 23:10:00    45.0    19.1    20.1    24.2    21.0          180.0
#
#                      out_c_setting     reward  done
# time
# 2022-01-22 23:25:00           62.5  -3.998356     0
# 2022-01-22 23:30:00           62.5  -3.706993     0
# 2022-01-22 23:35:00           62.5  -3.668507     0
# 2022-01-22 23:40:00           62.5  -3.623536     0
# 2022-01-22 23:45:00           62.5  -3.883408     0
# ...                            ...        ...   ...
# 2023-01-19 21:55:00           62.0 -50.704183     0
# 2023-01-19 22:50:00           62.0 -46.807875     0
# 2023-01-19 22:55:00           62.0 -31.285558     0
# 2023-01-19 23:00:00           62.0 -26.303081     0
# 2023-01-19 23:10:00           62.0 -34.615663     0
#
# [9506 rows x 15 columns]

# %%
df_3['error'] = df_3['reward']

# %%
df_3['sum_error'] = df_3['error']

# %%
df_3['done'] = 0

# %%
df_3
# Out:
#                      feed_c  out_c   feed_f  out_f  pressure  overflow_t  \
# time
# 2022-01-22 23:25:00   37.30   63.0  769.000  174.0      49.3       0.224
# 2022-01-22 23:30:00   34.00   62.7  470.000  186.0      49.5       5.870
# 2022-01-22 23:35:00   39.90   62.4  721.000  185.0      49.9       0.224
# 2022-01-22 23:40:00   35.10   62.6  774.000  179.0      51.0       0.224
# 2022-01-22 23:45:00   35.10   62.0  776.000  199.0      50.3       0.224
# ...                     ...    ...      ...    ...       ...         ...
# 2023-01-19 21:55:00   16.10   55.1    0.760  179.0      35.4       0.123
# 2023-01-19 22:50:00    8.98   55.4    0.434  179.0      35.6       0.109
# 2023-01-19 22:55:00    6.97   56.7    0.434  176.0      33.5       0.109
# 2023-01-19 23:00:00    7.13   57.2    0.434  188.0      31.1       0.109
# 2023-01-19 23:10:00    6.17   56.4    0.434  175.0      32.4       0.101
#
#                      rake_s  rake_1  rake_2  rake_3  rake_4  out_f_setting  \
# time
# 2022-01-22 23:25:00    45.0    25.7    25.1    26.0    25.8          150.0
# 2022-01-22 23:30:00    45.0    25.0    24.6    25.0    25.4          150.0
# 2022-01-22 23:35:00    45.0    24.1    25.4    25.0    25.2          150.0
# 2022-01-22 23:40:00    45.0    24.4    24.0    24.4    25.4          150.0
# 2022-01-22 23:45:00    45.0    24.7    24.6    24.9    24.7          150.0
# ...                     ...     ...     ...     ...     ...            ...
# 2023-01-19 21:55:00    45.0    18.2    18.8    22.1    18.4          180.0
# 2023-01-19 22:50:00    45.0    19.7    20.3    23.3    21.0          180.0
# 2023-01-19 22:55:00    45.0    19.0    19.7    23.6    19.6          180.0
# 2023-01-19 23:00:00    45.0    20.3    20.2    23.7    20.7          180.0
# 2023-01-19 23:10:00    45.0    19.1    20.1    24.2    21.0          180.0
#
#                      out_c_setting     reward  done      error  sum_error
# time
# 2022-01-22 23:25:00           62.5  -3.998356     0  -3.998356  -3.998356
# 2022-01-22 23:30:00           62.5  -3.706993     0  -3.706993  -3.706993
# 2022-01-22 23:35:00           62.5  -3.668507     0  -3.668507  -3.668507
# 2022-01-22 23:40:00           62.5  -3.623536     0  -3.623536  -3.623536
# 2022-01-22 23:45:00           62.5  -3.883408     0  -3.883408  -3.883408
# ...                            ...        ...   ...        ...        ...
# 2023-01-19 21:55:00           62.0 -50.704183     0 -50.704183 -50.704183
# 2023-01-19 22:50:00           62.0 -46.807875     0 -46.807875 -46.807875
# 2023-01-19 22:55:00           62.0 -31.285558     0 -31.285558 -31.285558
# 2023-01-19 23:00:00           62.0 -26.303081     0 -26.303081 -26.303081
# 2023-01-19 23:10:00           62.0 -34.615663     0 -34.615663 -34.615663
#
# [9506 rows x 17 columns]

# %%
for i in range(len(df_3) - 1):
    df_3['sum_error'][i+1] = df_3['error'][i+1] + 0.8 * df_3['sum_error'][i]
# Out:
# <ipython-input-79-d533cea76a52>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['sum_error'][i+1] = df_3['error'][i+1] + 0.8 * df_3['sum_error'][i]

# %%
df_3
# Out:
#                      feed_c  out_c   feed_f  out_f  pressure  overflow_t  \
# time
# 2022-01-22 23:25:00   37.30   63.0  769.000  174.0      49.3       0.224
# 2022-01-22 23:30:00   34.00   62.7  470.000  186.0      49.5       5.870
# 2022-01-22 23:35:00   39.90   62.4  721.000  185.0      49.9       0.224
# 2022-01-22 23:40:00   35.10   62.6  774.000  179.0      51.0       0.224
# 2022-01-22 23:45:00   35.10   62.0  776.000  199.0      50.3       0.224
# ...                     ...    ...      ...    ...       ...         ...
# 2023-01-19 21:55:00   16.10   55.1    0.760  179.0      35.4       0.123
# 2023-01-19 22:50:00    8.98   55.4    0.434  179.0      35.6       0.109
# 2023-01-19 22:55:00    6.97   56.7    0.434  176.0      33.5       0.109
# 2023-01-19 23:00:00    7.13   57.2    0.434  188.0      31.1       0.109
# 2023-01-19 23:10:00    6.17   56.4    0.434  175.0      32.4       0.101
#
#                      rake_s  rake_1  rake_2  rake_3  rake_4  out_f_setting  \
# time
# 2022-01-22 23:25:00    45.0    25.7    25.1    26.0    25.8          150.0
# 2022-01-22 23:30:00    45.0    25.0    24.6    25.0    25.4          150.0
# 2022-01-22 23:35:00    45.0    24.1    25.4    25.0    25.2          150.0
# 2022-01-22 23:40:00    45.0    24.4    24.0    24.4    25.4          150.0
# 2022-01-22 23:45:00    45.0    24.7    24.6    24.9    24.7          150.0
# ...                     ...     ...     ...     ...     ...            ...
# 2023-01-19 21:55:00    45.0    18.2    18.8    22.1    18.4          180.0
# 2023-01-19 22:50:00    45.0    19.7    20.3    23.3    21.0          180.0
# 2023-01-19 22:55:00    45.0    19.0    19.7    23.6    19.6          180.0
# 2023-01-19 23:00:00    45.0    20.3    20.2    23.7    20.7          180.0
# 2023-01-19 23:10:00    45.0    19.1    20.1    24.2    21.0          180.0
#
#                      out_c_setting     reward  done      error   sum_error
# time
# 2022-01-22 23:25:00           62.5  -3.998356     0  -3.998356   -3.998356
# 2022-01-22 23:30:00           62.5  -3.706993     0  -3.706993   -6.905677
# 2022-01-22 23:35:00           62.5  -3.668507     0  -3.668507   -9.193049
# 2022-01-22 23:40:00           62.5  -3.623536     0  -3.623536  -10.977976
# 2022-01-22 23:45:00           62.5  -3.883408     0  -3.883408  -12.665789
# ...                            ...        ...   ...        ...         ...
# 2023-01-19 21:55:00           62.0 -50.704183     0 -50.704183 -197.320543
# 2023-01-19 22:50:00           62.0 -46.807875     0 -46.807875 -204.664310
# 2023-01-19 22:55:00           62.0 -31.285558     0 -31.285558 -195.017006
# 2023-01-19 23:00:00           62.0 -26.303081     0 -26.303081 -182.316685
# 2023-01-19 23:10:00           62.0 -34.615663     0 -34.615663 -180.469011
#
# [9506 rows x 17 columns]

# %%
df_3.to_csv("df_thickener1_20230201.csv", index=True)
